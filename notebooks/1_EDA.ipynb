# %% [markdown]
# # 1 Exploratory Data Analysis

# %%
import json
import numpy as np

from collections import defaultdict as dd

# %% [markdown]
# ### Read in data

# %%
with open ('../data/raw/train-claims.json') as f:
    train_claims = json.load(f)

with open ('../data/raw/dev-claims.json') as f:
    dev_claims = json.load(f)

with open ('../data/raw/dev-claims-baseline.json') as f:
    dev_claims_baseline = json.load(f)

with open ('../data/raw/evidence.json') as f:
    evidence = json.load(f)

with open ('../data/raw/test-claims-unlabelled.json') as f:
    test_claims_unlabelled = json.load(f)

# %% [markdown]
# ### Have a look at structure of train_claims and how many there are

# %%
train_claims
# Out:
# {'claim-1937': {'claim_text': 'Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-442946', 'evidence-1194317', 'evidence-12171']},
#  'claim-126': {'claim_text': 'El Niño drove record highs in global temperatures suggesting rise may not be down to man-made emissions.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-338219', 'evidence-1127398']},
#  'claim-2510': {'claim_text': 'In 1946, PDO switched to a cool phase.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-530063', 'evidence-984887']},
#  'claim-2021': {'claim_text': 'Weather Channel co-founder John Coleman provided evidence that convincingly refutes the concept of anthropogenic global warming.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1177431',
#    'evidence-782448',
#    'evidence-540069',
#    'evidence-352655',
#    'evidence-1007867']},
#  'claim-2449': {'claim_text': '"January 2008 capped a 12 month period of global temperature drops on all of the major well respected indicators.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1010750',
#    'evidence-91661',
#    'evidence-722725',
#    'evidence-554161',
#    'evidence-430839']},
#  'claim-851': {'claim_text': 'The last time the planet was even four degrees warmer, Peter Brannen points out in The Ends of the World, his new history of the planet’s major extinction events, the oceans were hundreds of feet higher.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-226174',
#    'evidence-1049316',
#    'evidence-358301',
#    'evidence-493329',
#    'evidence-610497']},
#  'claim-2773': {'claim_text': 'Tree-ring proxy reconstructions are reliable before 1960, tracking closely with the instrumental record and other independent proxies.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-974673', 'evidence-602109']},
#  'claim-949': {'claim_text': 'Under the most ambitious scenarios, they found a strong likelihood that Antarctica would remain fairly stable.”',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-707654', 'evidence-28478', 'evidence-491579']},
#  'claim-1019': {'claim_text': 'An additional kick was supplied by an El Niño weather pattern that peaked in 2016 and temporarily warmed much of the surface of the planet, causing the hottest year in a historical record dating to 1880.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-863309',
#    'evidence-61462',
#    'evidence-639818',
#    'evidence-757821',
#    'evidence-263527']},
#  'claim-2834': {'claim_text': 'When stomata-derived CO2 (red) is compared to ice core-derived CO2 (blue), the stomata generally show much more variability in the atmospheric CO2 level and often show levels much higher than the ice cores.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-439640']},
#  'claim-1441': {'claim_text': '195 countries signed the 2015 Paris Agreement, agreeing to limit global warming and adapt to climate change, partly by protecting nature.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-217743']},
#  'claim-1181': {'claim_text': 'However, there is a process of accretion, where coral broken up by the waves washes up on these low-lying islands as sand, counteracting the reduction in land mass.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-222694',
#    'evidence-905909',
#    'evidence-600745',
#    'evidence-337702',
#    'evidence-1015241']},
#  'claim-2417': {'claim_text': 'Mars, Triton, Pluto and Jupiter all show global warming, pointing to the Sun as the dominating influence in determining climate throughout the solar system."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-386828',
#    'evidence-535248',
#    'evidence-1078011',
#    'evidence-975483',
#    'evidence-177166']},
#  'claim-2152': {'claim_text': "Venus doesn't have a runaway greenhouse effect",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-515817',
#    'evidence-1018575',
#    'evidence-791159',
#    'evidence-1009205',
#    'evidence-878835']},
#  'claim-826': {'claim_text': 'The latest NOAA report is “a reminder that climate change has not, despite the insistence of climate contrarians ‘paused’ or even slowed down,” Mann said..',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-497197']},
#  'claim-1066': {'claim_text': '[…] in fact this pattern is already emerging, with the conditions that create extremely warm dry years and extremely wet years both becoming more frequent.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-876634']},
#  'claim-3003': {'claim_text': 'Venus is not hot because of a runaway greenhouse.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-175982', 'evidence-515817', 'evidence-1009205']},
#  'claim-3059': {'claim_text': 'Models and direct observations find that CFCs only contribute a fraction of the warming supplied by other greenhouse gases.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-368192',
#    'evidence-1148684',
#    'evidence-457889',
#    'evidence-91026',
#    'evidence-813877']},
#  'claim-568': {'claim_text': 'The research also revealed how large areas of the polar ice caps could collapse and significant changes to ecosystems could see the Sahara Desert become green and the edges of tropical forests turn into fire-dominated savanna.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-555453']},
#  'claim-60': {'claim_text': 'So that means that probably about half, maybe half of that nine-tenths of the degree [of total warming] might be caused by greenhouse gases',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-741089',
#    'evidence-251138',
#    'evidence-510852',
#    'evidence-1202023']},
#  'claim-378': {'claim_text': 'for thousands of millions of years the Earth has been changing, with cycles\xad and one-off events such as an asteroid impact, super-volcano or a supernova explosion.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-594594', 'evidence-184401']},
#  'claim-2486': {'claim_text': 'The minute increase of anthropogenic CO2\xa0in the atmosphere (0.008%) was not the cause of the warming—it was a continuation of natural cycles that occurred over the past 500 years."',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-881808', 'evidence-510852']},
#  'claim-1782': {'claim_text': 'Thousands of coral atolls have "drowned" when unable to grow fast enough to survive at sea level.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1144381',
#    'evidence-124990',
#    'evidence-915986',
#    'evidence-308548']},
#  'claim-1235': {'claim_text': '“During ice ages, caused by wobbles in the Earth’s orbit, sea levels dropped more than 400 feet as ice piled up on land.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-843672', 'evidence-1109588', 'evidence-284300']},
#  'claim-2065': {'claim_text': 'Global warming is causing snow to disappear.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-88825',
#    'evidence-1184933',
#    'evidence-292592',
#    'evidence-618094']},
#  'claim-1390': {'claim_text': '“Lyme Disease is much more common in northern, cooler regions of the United States than in southern, warmer regions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1094006', 'evidence-307215']},
#  'claim-2789': {'claim_text': 'At that time, Hansen also produced a model of the future behavior of the globe’s temperature, which he had turned into a video movie that was heavily shopped in Congress.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1011994']},
#  'claim-1414': {'claim_text': 'The earth is 15 years from a “mini ice-age” that will cause bitterly cold winters during which rivers such as the Thames freeze over, scientists have predicted.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-601898',
#    'evidence-1116043',
#    'evidence-93627',
#    'evidence-1088241',
#    'evidence-16120']},
#  'claim-377': {'claim_text': 'If we halve the carbon dioxide content of the atmosphere, all life dies.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-765194']},
#  'claim-558': {'claim_text': 'Species that have a lot of plasticity tend to be generalists.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-738531']},
#  'claim-1447': {'claim_text': 'Flights departing airports in the United States and its territories emitted about one-quarter (24%) of global passenger transport-related CO2, two-thirds of which came from domestic flights.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-331238']},
#  'claim-1038': {'claim_text': '(Multiplying .95 by itself 15 times yields 46.3 percent.)”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-935810',
#    'evidence-997014',
#    'evidence-724362',
#    'evidence-1052470',
#    'evidence-56420']},
#  'claim-2794': {'claim_text': 'But his results are evidence that the actual climate sensitivity is about 3°C for a doubling of atmospheric CO2.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-269431', 'evidence-950248', 'evidence-725977']},
#  'claim-930': {'claim_text': '“Right now, the shelf works like a giant bottle-stopper that slows down ice trying to flow from the land into the sea.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1005403',
#    'evidence-69047',
#    'evidence-630900',
#    'evidence-1199599',
#    'evidence-1150464']},
#  'claim-2763': {'claim_text': 'The long term trend from albedo is of cooling.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-695602', 'evidence-458452', 'evidence-1075210']},
#  'claim-1920': {'claim_text': 'Melting of Arctic sea ice and polar icecaps is not occurring at unnatural rates and does not constitute evidence of a human impact on the climate.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-379278',
#    'evidence-118577',
#    'evidence-896442',
#    'evidence-780167',
#    'evidence-869636']},
#  'claim-2961': {'claim_text': 'Cooks ’97% consensus’ disproven by a new peer',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-364120', 'evidence-608883']},
#  'claim-1395': {'claim_text': 'Severe storms, floods and agricultural losses may cost a great deal of money, but such extreme weather events—and their resulting costs—are dramatically declining as the Earth modestly warms.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-789848']},
#  'claim-1404': {'claim_text': 'receding polar ice caps have little if any negative impact on human health and welfare, and likely a positive benefit',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-183320', 'evidence-634003']},
#  'claim-2257': {'claim_text': "'Our harmless emissions of trifling quantities of carbon dioxide cannot possibly acidify the oceans.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-123975', 'evidence-763909', 'evidence-973268']},
#  'claim-646': {'claim_text': 'If Houlton’s finding about these vast, previously unknown nitrogen stores holds true, then it would have an enormous impact on global warming predictions.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1127656',
#    'evidence-661614',
#    'evidence-1068819',
#    'evidence-1036643',
#    'evidence-51841']},
#  'claim-1545': {'claim_text': 'Increasing CO2 in the atmosphere has little to no effect.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-368192', 'evidence-66273', 'evidence-481658']},
#  'claim-1317': {'claim_text': '“…climate change will also reduce the number of cold days and cold spells.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-512115',
#    'evidence-1025337',
#    'evidence-130644',
#    'evidence-1126075',
#    'evidence-53757']},
#  'claim-1547': {'claim_text': 'Water vapor is the most powerful greenhouse gas.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-677405', 'evidence-706949', 'evidence-699826']},
#  'claim-2280': {'claim_text': 'While there are minor errors in An Inconvenient Truth, the main truths presented - evidence to show mankind is causing global warming and its various impacts is consistent with peer reviewed science.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1109658',
#    'evidence-926139',
#    'evidence-539110',
#    'evidence-742898']},
#  'claim-118': {'claim_text': 'more than 100 per cent of the warming over the past century is due to human actions',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1170178',
#    'evidence-281484',
#    'evidence-483558',
#    'evidence-1180647']},
#  'claim-1357': {'claim_text': '“The notion that world-wide weather is becoming more extreme is just that: a notion, or a testable hypothesis.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1032156',
#    'evidence-748405',
#    'evidence-516535',
#    'evidence-241739',
#    'evidence-884622']},
#  'claim-69': {'claim_text': 'Sea level rise is not going to happen.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-639299', 'evidence-287438', 'evidence-365963']},
#  'claim-2849': {'claim_text': '"by the 2001 [IPCC] climate assessment...the Medieval Warm Period had been ingeniously wiped out.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-298630', 'evidence-1052408']},
#  'claim-499': {'claim_text': 'The monetary cost of damages has increased dramatically in recent decades, but that is due to increasing population, wealth and the amount of vulnerable infrastructure.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-630162',
#    'evidence-394340',
#    'evidence-95950',
#    'evidence-564718',
#    'evidence-1153500']},
#  'claim-749': {'claim_text': '“The worldwide temperature record has been changed.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-219865', 'evidence-770232']},
#  'claim-428': {'claim_text': 'Brooks added that Antarctic ice is growing.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-403151', 'evidence-427121']},
#  'claim-1837': {'claim_text': 'A major part of the climate change bill sponsored by Sens. John Kerry and Joe Lieberman "was essentially written by BP."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-606697']},
#  'claim-1875': {'claim_text': 'Doubling the concentration of atmospheric CO2 from its pre-industrial level, in the absence of other forcings and feedbacks, would likely cause a warming of ~0.3Â°C to 1.1Â°C',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-843608',
#    'evidence-714864',
#    'evidence-219780',
#    'evidence-481658']},
#  'claim-1324': {'claim_text': 'cold deaths actually occur during moderate temperatures',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-946873']},
#  'claim-1980': {'claim_text': 'and three Nobel economic laureates support "direct investment in technology" rather than a carbon tax.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-385259',
#    'evidence-891871',
#    'evidence-955609',
#    'evidence-141679',
#    'evidence-620224']},
#  'claim-409': {'claim_text': 'as time progresses and fossil fuel emissions increase, the number of record highs should increase and record lows should decrease.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-131765',
#    'evidence-478058',
#    'evidence-158965',
#    'evidence-493954',
#    'evidence-845416']},
#  'claim-2193': {'claim_text': 'In the last 35 years of global warming, the sun has shown a slight cooling trend.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-311416', 'evidence-996913']},
#  'claim-3084': {'claim_text': '"the temperature increase in the second half of the 20th century could have taken place in steps driven by major ENSO events" (Jens Raunsø Jensen)',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-350901', 'evidence-417371']},
#  'claim-1227': {'claim_text': 'These tidal floods are often just a foot or two deep, but they can stop traffic, swamp basements, damage cars, kill lawns and forests, and poison wells with salt.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-378560',
#    'evidence-1116066',
#    'evidence-703743',
#    'evidence-974319',
#    'evidence-821236']},
#  'claim-1499': {'claim_text': 'Sea-level rise does not seem to depend on ocean temperature, and certainly not on CO2.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-835367',
#    'evidence-1179193',
#    'evidence-1127398',
#    'evidence-382866',
#    'evidence-722761']},
#  'claim-1790': {'claim_text': 'Study finds low probability of both very low and very high climate sensitivities, and its lower estimate (as compared to the IPCC) is based on a new temperature reconstruction of the Last Glacial Maximum that may or may not withstand the test of time.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-68232']},
#  'claim-2090': {'claim_text': 'Arctic icemelt is a natural cycle',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-824669']},
#  'claim-2199': {'claim_text': 'The consequences of climate change become increasingly bad after each additional degree of warming, with the consequences of 2°C being quite damaging and the consequences of 4°C being potentially catastrophic.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-91685', 'evidence-349143']},
#  'claim-1498': {'claim_text': 'carbon dioxide has had a minuscule effect on global climate.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-368192',
#    'evidence-185746',
#    'evidence-814790',
#    'evidence-1040875',
#    'evidence-950498']},
#  'claim-1792': {'claim_text': "Greenland's ice loss is accelerating & will add metres of sea level rise in upcoming centuries.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-173281',
#    'evidence-59240',
#    'evidence-264761',
#    'evidence-123917']},
#  'claim-2540': {'claim_text': 'In other words, there is as yet no incontrovertible  proof either of the greenhouse effect, or its connection with alleged  global warming.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1177431', 'evidence-256785']},
#  'claim-2474': {'claim_text': 'Warming trends agree well with surface temperatures and model predictions except near the Poles.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-447033', 'evidence-474587']},
#  'claim-2741': {'claim_text': '\'Phil Jones\xa0said that for the past 15 years there has been no "statistically significant" warming.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1142444',
#    'evidence-657030',
#    'evidence-734024',
#    'evidence-416007']},
#  'claim-3102': {'claim_text': '...there [is] anecdotal and other evidence suggesting similar melts from 1938-43 and on other occasions.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-556592',
#    'evidence-365488',
#    'evidence-48733',
#    'evidence-523036',
#    'evidence-31950']},
#  'claim-1112': {'claim_text': '“The jet stream forms a boundary between the cold north and the warmer south, but the lower temperature difference means the winds are now weaker.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-686575',
#    'evidence-427299',
#    'evidence-66896',
#    'evidence-921243']},
#  'claim-2488': {'claim_text': 'However, it is unable to explain the long term warming trend over the past few decades.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-742898', 'evidence-529426', 'evidence-508793']},
#  'claim-1802': {'claim_text': 'The temporary drop in sea level in 2010 was due to intense land flooding caused by a strong La Nina.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-792643', 'evidence-969261']},
#  'claim-815': {'claim_text': 'Evidence is growing that the comparatively cold zone within the Northern Atlantic could be due to a slowdown of this global ocean water circulation.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-16682', 'evidence-250766', 'evidence-931237']},
#  'claim-2698': {'claim_text': "The Review concluded that CRU's actions were normal and did not threaten the integrity of peer review.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-961541',
#    'evidence-519557',
#    'evidence-386060',
#    'evidence-1167663']},
#  'claim-1142': {'claim_text': 'Even as sea ice in the Arctic has seen a rapid and consistent decline over the past decade, its counterpart in the Southern Hemisphere has seen its extent increasing.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-353752',
#    'evidence-616091',
#    'evidence-799326',
#    'evidence-858052']},
#  'claim-2707': {'claim_text': 'The full data for latitudes 64-90°N reveal the Arctic is warmer today than in 1940.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-240134', 'evidence-776385']},
#  'claim-1260': {'claim_text': 'The contrast in precipitation between wet and dry regions and between wet and dry seasons will increase, although there may be regional exceptions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-607447', 'evidence-615494', 'evidence-897807']},
#  'claim-1163': {'claim_text': '“Global warming and climate change, even if it is 100% caused by humans, is so slow that it cannot be observed by anyone in their lifetime.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-896442']},
#  'claim-740': {'claim_text': '“To revisit the ocean’s paleotemperatures now, we need to carefully quantify this re-equilibration, which has been overlooked for too long.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-246600',
#    'evidence-42590',
#    'evidence-196285',
#    'evidence-49789',
#    'evidence-344340']},
#  'claim-1061': {'claim_text': 'warmer oceans have also begun to destabilize glaciers in Greenland and Antarctica',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-5928',
#    'evidence-647077',
#    'evidence-1127398',
#    'evidence-1154195',
#    'evidence-885328']},
#  'claim-2283': {'claim_text': 'In fact, the global melt rate has been accelerating since the mid-1970s.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-292592',
#    'evidence-646192',
#    'evidence-775820',
#    'evidence-363960']},
#  'claim-1822': {'claim_text': "Trudeau's carbon tax will raise gas prices by 11 cents/litre.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-63736',
#    'evidence-548936',
#    'evidence-150674',
#    'evidence-707048',
#    'evidence-751210']},
#  'claim-332': {'claim_text': 'Shelters in poorer countries are not repainted as often, and darker stations absorb more of the sun’s energy.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1157165', 'evidence-877387']},
#  'claim-258': {'claim_text': 'But the period has caused a headache for climate scientists because clearly there was no upswell in carbon dioxide that could account for such swift warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-942403', 'evidence-17867']},
#  'claim-774': {'claim_text': 'The warming is extremely rapid on the geologic time scale, and no other factor can explain it as well as human emissions of greenhouse gases.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-814790', 'evidence-742898', 'evidence-17867']},
#  'claim-207': {'claim_text': 'Each of the six major past ice ages began when the atmospheric carbon dioxide content was far higher than at present.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-683138', 'evidence-444501']},
#  'claim-2966': {'claim_text': "Over the three years from 1979 to 1982 when CO2 emissions were decreasing due to the rapid increase in the price of oil that drastically reduced consumption, there was no change in the rate of increase in atmospheric concentration of CO2 proving that humans were not the primary source for the increase in concentration.'",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-196937',
#    'evidence-1184104',
#    'evidence-998171',
#    'evidence-1180647']},
#  'claim-450': {'claim_text': 'If we double atmospheric carbon dioxide[…] we’d only raise global surface temperatures by about a degree Celsius.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-834978', 'evidence-725977']},
#  'claim-362': {'claim_text': 'North America suffers extreme weather events including wildfires, drought, and heatwaves.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-990422', 'evidence-920671']},
#  'claim-2547': {'claim_text': 'The modelers confused cause and effect, thereby getting the feedback in the wrong direction."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-460782',
#    'evidence-152353',
#    'evidence-461362',
#    'evidence-1004849',
#    'evidence-254876']},
#  'claim-716': {'claim_text': 'Pollard and DeConto are the first to admit that their model is still crude, but its results have pushed the entire scientific community into emergency mode.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-716968',
#    'evidence-546008',
#    'evidence-934789',
#    'evidence-1184148',
#    'evidence-510573']},
#  'claim-1708': {'claim_text': "The 'decline' refers to a decline in northern tree-rings, not global temperature, and is openly discussed in papers and the IPCC reports.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-224185']},
#  'claim-1678': {'claim_text': 'No known natural forcing fits the fingerprints of observed warming except anthropogenic greenhouse gases.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-110835']},
#  'claim-1334': {'claim_text': 'We simply could never release enough CO2 into the atmosphere to cause the pH to go below 7 [the point in the pH scale at which a solution becomes acidic].”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-923136', 'evidence-1082891']},
#  'claim-61': {'claim_text': '[NASA] has been adjusting temperatures from the past[...]',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-343576',
#    'evidence-664095',
#    'evidence-524585',
#    'evidence-175285',
#    'evidence-548643']},
#  'claim-1826': {'claim_text': 'Every year air pollution protections are delayed, another 34,000 people will die prematurely.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-28365',
#    'evidence-32112',
#    'evidence-933503',
#    'evidence-1101246',
#    'evidence-162471']},
#  'claim-157': {'claim_text': 'Contemporary Global Warming placed in geological context.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-498301',
#    'evidence-889933',
#    'evidence-742898',
#    'evidence-898633',
#    'evidence-461050']},
#  'claim-1481': {'claim_text': 'Based on the increase of solar activity during the twentieth century, it should account for between half to two-thirds of all climate change.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-282556',
#    'evidence-95610',
#    'evidence-24687',
#    'evidence-979414',
#    'evidence-5606']},
#  'claim-1796': {'claim_text': 'Natural cycles superimposed on a linear warming trend can be mistaken for step changes, but the underlying warming is caused by the external radiative forcing.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-374021', 'evidence-215702', 'evidence-1087907']},
#  'claim-807': {'claim_text': 'the total area burned in the western United States over the past 33 years was double the size it would have been without any human-caused warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-230808']},
#  'claim-1658': {'claim_text': 'Rising CO2 increases atmospheric water vapor, which makes global warming much worse.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-368192',
#    'evidence-801082',
#    'evidence-814790',
#    'evidence-66273',
#    'evidence-1107524']},
#  'claim-493': {'claim_text': 'Coastal lake sediments along the Gulf of Mexico shoreline from 1,000 to 2,000 years ago suggest more frequent and intense hurricanes than occur today.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-479543',
#    'evidence-908316',
#    'evidence-885836',
#    'evidence-1164287',
#    'evidence-604307']},
#  'claim-2485': {'claim_text': 'A natural cycle requires a forcing, and no known forcing exists that fits the fingerprints of observed warming - except anthropogenic greenhouse gases.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1150379', 'evidence-110835']},
#  'claim-2222': {'claim_text': 'A large number of ancient mass extinction events have been strongly linked to global climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-196427', 'evidence-340866', 'evidence-759230']},
#  'claim-2606': {'claim_text': '...Livestock are responsible for 18 per cent of the  greenhouse gases that cause global warming, more than cars, planes and  all other forms of transport put together.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-977818']},
#  'claim-534': {'claim_text': 'Domino-effect of climate events could move Earth into a ‘hothouse’ state',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-397392',
#    'evidence-950065',
#    'evidence-37705',
#    'evidence-1084600',
#    'evidence-122651']},
#  'claim-1313': {'claim_text': 'Coral bleaching has devastated 93% of the Great Barrier Reef',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-513559', 'evidence-670186']},
#  'claim-1505': {'claim_text': 'according, again, to the official figures—during this past 10 years, if anything, mean global temperature, average world temperature, has slightly declined.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-430060', 'evidence-1120350', 'evidence-742898']},
#  'claim-282': {'claim_text': 'The panel was forced to retract a statement in its 2007 report saying all Himalayan glaciers could melt entirely by 2035.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-907084', 'evidence-138717', 'evidence-281372']},
#  'claim-957': {'claim_text': 'ever since December temperatures in the Arctic have consistently been lower than minus 20\u2005C',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-991749']},
#  'claim-132': {'claim_text': 'Climate change is not making natural disasters worse',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-430914',
#    'evidence-943395',
#    'evidence-332246',
#    'evidence-288399',
#    'evidence-299877']},
#  'claim-1814': {'claim_text': 'The amount of heat energy coming out of the Earth is too small to even be worth considering.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-845692', 'evidence-1069448', 'evidence-247653']},
#  'claim-363': {'claim_text': 'Monsoons in China fail, the great rivers of Asia virtually dry up, and rainfall in central America falls by half.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-220758',
#    'evidence-547557',
#    'evidence-724033',
#    'evidence-883011',
#    'evidence-164938']},
#  'claim-2687': {'claim_text': 'It seems scientists have noticed recently that quite a few planets in our solar system seem to be heating up a bit, including Pluto."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-172484',
#    'evidence-803448',
#    'evidence-958716',
#    'evidence-818422',
#    'evidence-422200']},
#  'claim-1294': {'claim_text': '“Because CO₂ acts as a fertilizer, as much as half of all vegetated land is persistently greener today.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-760556',
#    'evidence-300355',
#    'evidence-143611',
#    'evidence-806394',
#    'evidence-1007539']},
#  'claim-649': {'claim_text': '“Houlton has been exploring this possibility for years.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1033596',
#    'evidence-482584',
#    'evidence-223394',
#    'evidence-106373',
#    'evidence-843198']},
#  'claim-2868': {'claim_text': '"I mean, it - I mean - and I tell somebody, I said, just because you have a group of scientists that have stood up and said here is the fact, Galileo got outvoted for a spell" (Texas Governor Rick Perry)',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-952385', 'evidence-945592']},
#  'claim-1562': {'claim_text': 'Methane is the only cause of climate change.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1187937',
#    'evidence-211727',
#    'evidence-520753',
#    'evidence-1068751',
#    'evidence-58791']},
#  'claim-1620': {'claim_text': 'Great Barrier Reef is in good shape.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-460724', 'evidence-629924', 'evidence-1115646']},
#  'claim-1327': {'claim_text': 'Migration patterns show people heading for warm states like Texas and Florida, not snowy Minnesota and Michigan.”',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-315268', 'evidence-1134131']},
#  'claim-3103': {'claim_text': '"Disasters Cost More Than Ever — But Not Because of Climate Change" (Roger Pielke Jr.)',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1163186']},
#  'claim-195': {'claim_text': 'Carbon dioxide is a non-condensable atmospheric gas like nitrogen and oxygen',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-29224',
#    'evidence-1046804',
#    'evidence-244109',
#    'evidence-26809',
#    'evidence-370555']},
#  'claim-642': {'claim_text': 'Some experts think we’re on track to hit 550 ppm by the end of the century, which would cause average global temperatures to rise by 6 degrees Celsius',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1120350', 'evidence-28478', 'evidence-1117164']},
#  'claim-2494': {'claim_text': "There is ample evidence that Earth's average temperature has increased in the past 100 years and the decline of mid- and high-latitude glaciers is a major piece of evidence.",
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-742898',
#    'evidence-17867',
#    'evidence-758691',
#    'evidence-1000569']},
#  'claim-1116': {'claim_text': 'Severe ‘snowmageddon’ winters are now strongly linked to soaring polar temperatures, say researchers, with deadly summer heatwaves and torrential floods also probably linked.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-611438',
#    'evidence-392043',
#    'evidence-236630',
#    'evidence-516337',
#    'evidence-717735']},
#  'claim-3048': {'claim_text': 'There is no question whatsoever that the CO2 increase is human-caused.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-196937',
#    'evidence-916975',
#    'evidence-449314',
#    'evidence-699212']},
#  'claim-1115': {'claim_text': 'This “blocking” effect means extreme events can unfold.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-495526']},
#  'claim-1614': {'claim_text': 'Arctic sea ice extent was lower in the past.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1159446', 'evidence-1144991', 'evidence-1017320']},
#  'claim-1580': {'claim_text': 'Plant stomata show higher and more variable CO2 levels.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-774652',
#    'evidence-935793',
#    'evidence-220309',
#    'evidence-1049076',
#    'evidence-511878']},
#  'claim-593': {'claim_text': 'It shows that ECS is probably between two and 4.5 degrees, possibly as low as 1.5 but not lower, and possibly as high as nine degrees.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-141522',
#    'evidence-389381',
#    'evidence-128705',
#    'evidence-989969',
#    'evidence-82012']},
#  'claim-2560': {'claim_text': 'In the 11,400 years since the end of the last Ice Age, sea  level has risen at an average of 4 feet/century, though it is now rising  much more slowly because very nearly all of the land-based ice that is  at low enough latitudes and altitudes to melt has long since gone."',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-374701']},
#  'claim-11': {'claim_text': 'They tell us that we are the primary forces controlling earth temperatures by the burning of fossil fuels and releasing their carbon dioxide.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-723964',
#    'evidence-814790',
#    'evidence-1064868',
#    'evidence-715109']},
#  'claim-1339': {'claim_text': '“Dr Browman, a marine scientist for 35 years, said he was not saying that ocean acidification posed no threat, but that he believed that “a higher level of academic scepticism” should be applied to the topic.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1116180', 'evidence-510034', 'evidence-433622']},
#  'claim-1878': {'claim_text': 'During the 2013 election campaign the Coalition said its first legislative priority in government would be to scrap the carbon tax.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-321813',
#    'evidence-912560',
#    'evidence-592258',
#    'evidence-452145']},
#  'claim-2120': {'claim_text': 'Phil Jones says no global warming since 1995',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-555300',
#    'evidence-889933',
#    'evidence-70660',
#    'evidence-843935',
#    'evidence-1142444']},
#  'claim-1098': {'claim_text': 'Marine life has nothing whatsoever to fear from ocean acidification.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-30044',
#    'evidence-276290',
#    'evidence-957349',
#    'evidence-345042',
#    'evidence-403020']},
#  'claim-2078': {'claim_text': 'Droughts and floods have not changed since we\x92ve been using fossil fuels',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-589118',
#    'evidence-613426',
#    'evidence-707408',
#    'evidence-317487']},
#  'claim-797': {'claim_text': 'Climate Models Have Overestimated Global Warming',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-427639', 'evidence-934400', 'evidence-1205331']},
#  'claim-1667': {'claim_text': 'Mars and Jupiter are not warming, and anyway the sun has recently been cooling slightly.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1129945',
#    'evidence-743577',
#    'evidence-695975',
#    'evidence-1010222',
#    'evidence-1106331']},
#  'claim-2553': {'claim_text': 'The climate debate is, in reality, about a 1.6 watts per square metre or 0.5 per cent discrepancy in the poorly known planetary energy balance."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-631423',
#    'evidence-755676',
#    'evidence-1122132',
#    'evidence-78654',
#    'evidence-1015594']},
#  'claim-2029': {'claim_text': "Bill Gates claims pandemic's 'misery' will 'happen regularly' if climate change is not stopped",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-269919']},
#  'claim-1049': {'claim_text': 'So far this month, there have been nearly 5,000 daily record highs set or tied, compared to just 42 daily record lows.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1180692',
#    'evidence-1089020',
#    'evidence-268799',
#    'evidence-269824',
#    'evidence-190984']},
#  'claim-1744': {'claim_text': 'The claim sea level isn’t rising is based on blatantly doctored graphs contradicted by observations.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-399273']},
#  'claim-2782': {'claim_text': '"NASA satellite data from the years 2000 through 2011 show the Earth\'s atmosphere is allowing far more heat to be released into space than alarmist computer models have predicted, reports a new study in the peer-reviewed science journal Remote Sensing.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-736108']},
#  'claim-2432': {'claim_text': 'The sun was warming up then, but the sun hasn’t been warming since 1970.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-941241',
#    'evidence-283290',
#    'evidence-1025186',
#    'evidence-479642',
#    'evidence-509144']},
#  'claim-2805': {'claim_text': 'Arctic sea ice loss is three times greater than Antarctic sea ice gain, and the amount of solar energy absorbed by the Earth is increasing as a result.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-702474', 'evidence-99465', 'evidence-189776']},
#  'claim-821': {'claim_text': 'Societies do fall apart from war, disease or chaos.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-319789', 'evidence-8367']},
#  'claim-1931': {'claim_text': 'New Jersey is "losing 50 football fields of open space to development every day and the more we develop upstream the more flooding we have downstream."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-606356']},
#  'claim-1084': {'claim_text': '[Jonathan Overpeck:] ‘No doubt about it anymore — humans, mainly by burning fossil fuels, are cooking the planet,’ Overpeck said.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1064868',
#    'evidence-715109',
#    'evidence-35538',
#    'evidence-358708']},
#  'claim-2788': {'claim_text': '\'On June 23, 1988, NASA scientist James Hansen testified before the House of Representatives that there was a strong "cause and effect relationship" between observed temperatures and human emissions into the atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-256785', 'evidence-27377']},
#  'claim-1465': {'claim_text': 'Since the beginning of the Industrial Revolution, the acidity of surface ocean waters has increased by about 30 percent.13,14',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-599485', 'evidence-637096', 'evidence-542607']},
#  'claim-1938': {'claim_text': "Obama administration's Clean Power Plan would have little or no effect on carbon dioxide emissions.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-310175', 'evidence-1185776']},
#  'claim-2123': {'claim_text': 'Tree-rings diverge from temperature after 1960',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-94196',
#    'evidence-92456',
#    'evidence-255113',
#    'evidence-713207',
#    'evidence-487458']},
#  'claim-1406': {'claim_text': 'Yet, according to NASA, only one temperature sensing station is necessary for the two cities and the vast area between them to be adequately represented in their network.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-119255',
#    'evidence-308147',
#    'evidence-198065',
#    'evidence-195959',
#    'evidence-9205']},
#  'claim-2444': {'claim_text': 'There are a number of forcings which affect climate (eg - stratospheric aerosols, solar variations).',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-139375',
#    'evidence-9075',
#    'evidence-927438',
#    'evidence-631347',
#    'evidence-1017229']},
#  'claim-320': {'claim_text': 'Globally averaged thermometers show two periods of warming since 1900: a half-degree from natural causes in the first half of the 20th century, before there was an increase in industrial carbon dioxide that was enough to produce it, and another half-degree in the last quarter of the century.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-697238',
#    'evidence-534165',
#    'evidence-368192',
#    'evidence-814790',
#    'evidence-94670']},
#  'claim-1880': {'claim_text': 'Electricity rates are 40 percent higher in states that have required utility companies to use a certain amount of renewable energy such as solar power.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-625549']},
#  'claim-263': {'claim_text': 'it later emerged that its creator Dr Michael Mann had spliced too [sic] datasets together – tree-rings showing temperatures going back hundreds of years, then recent thermometer readings for the more recent decades.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1000787', 'evidence-707918']},
#  'claim-663': {'claim_text': '“For example, Canadian polar bear biologist Ian Stirling learned in the 1970s that spring sea ice in the southern Beaufort Sea periodically gets so thick that seals depart, depriving local polar bears of their prey and causing their numbers to plummet.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1178891', 'evidence-565971', 'evidence-862997']},
#  'claim-1995': {'claim_text': 'There are about 120,000 solar energy jobs in the United States, but only 1,700 of them are in Georgia.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1130962', 'evidence-341764', 'evidence-70694']},
#  'claim-2780': {'claim_text': 'The United States has been restricting soot emissions  in Draconian fashion since the Clean Air Act of 1963.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-510174',
#    'evidence-625241',
#    'evidence-955891',
#    'evidence-249780',
#    'evidence-831777']},
#  'claim-2369': {'claim_text': 'The public understand it, in that if  you get a fall evening or spring evening and the sky is clear the heat  will escape and the temperature will drop and you get frost.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-364822']},
#  'claim-2627': {'claim_text': "Neptune's orbit is 164 years so observations (1950 to present day) span less than a third of a Neptunian year.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-874431', 'evidence-683543', 'evidence-724346']},
#  'claim-1077': {'claim_text': 'Antarctic ice fluctuates wildly year to year, and the link to man-made global warming there is not clear, NASA ice expert Walt Meier said.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1117137', 'evidence-1020939']},
#  'claim-828': {'claim_text': 'Famine, economic collapse, a sun that cooks us: What climate change could wreak — sooner than you think.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1178287',
#    'evidence-589361',
#    'evidence-463557',
#    'evidence-274178']},
#  'claim-2461': {'claim_text': 'Early 20th century warming was in large part due to rising solar activity and relatively quiet volcanic activity.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-697238']},
#  'claim-2945': {'claim_text': 'But that conclusion holds true only if there are no other sources of c12 increases which are not human caused.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-467792',
#    'evidence-1019038',
#    'evidence-489930',
#    'evidence-1034835',
#    'evidence-338219']},
#  'claim-2633': {'claim_text': "Jupiter's climate change is due to shifts in internal turbulence fueled from an internal heat source - the planet radiates twice as much energy as it receives from the sun.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1103766']},
#  'claim-353': {'claim_text': 'The bottom line is there’s no solid connection between climate change and the major indicators of extreme weather',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-833979', 'evidence-1102346', 'evidence-653981']},
#  'claim-1829': {'claim_text': '"the cascading effects" of climate change contributed to the rise of ISIS.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-580497',
#    'evidence-852366',
#    'evidence-10951',
#    'evidence-122651',
#    'evidence-1185813']},
#  'claim-1568': {'claim_text': 'Southern sea ice is increasing.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1159446']},
#  'claim-791': {'claim_text': '‘Clean coal’ is an approach in which the emissions from coal-burning power plants would be captured and pumped underground.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1199381',
#    'evidence-659283',
#    'evidence-886223',
#    'evidence-318463']},
#  'claim-1634': {'claim_text': 'Satellites measure Antarctica losing land ice at an accelerating rate.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-591257',
#    'evidence-1110867',
#    'evidence-352317',
#    'evidence-382370',
#    'evidence-158280']},
#  'claim-2202': {'claim_text': 'More specifically, around 95% of active climate researchers actively publishing climate papers endorse the consensus position.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-323097',
#    'evidence-1140472',
#    'evidence-31308',
#    'evidence-116462',
#    'evidence-335835']},
#  'claim-337': {'claim_text': 'temperatures were 6-10C above normal over most of France, Germany and northern Spain during the final days of the month, according to C3S.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-554437',
#    'evidence-728024',
#    'evidence-190023',
#    'evidence-445863',
#    'evidence-77144']},
#  'claim-1674': {'claim_text': 'Early 20th century warming is due to several causes, including rising CO2.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-457314', 'evidence-534165', 'evidence-493616']},
#  'claim-2255': {'claim_text': 'And  since the last ice age ended almost exactly 11,500 years ago…" (Ice Age Now)',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-695000',
#    'evidence-623810',
#    'evidence-932819',
#    'evidence-72337',
#    'evidence-663304']},
# ...
#   'evidences': ['evidence-1161351', 'evidence-700717']},
#  'claim-1952': {'claim_text': 'Scientists project that the Arctic will be ice-free in the summer of 2013.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-731434',
#    'evidence-1107462',
#    'evidence-1192552',
#    'evidence-482196',
#    'evidence-114604']},
#  'claim-2011': {'claim_text': 'U.S. Pays $1 Billion into Green Climate Fund, Top Polluters Pay Nothing',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-33883', 'evidence-581537']},
#  'claim-945': {'claim_text': 'In their worst-case scenario, the sea level could rise by six feet by the end of this century, and the pace could pick up drastically in the 22nd century.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-318640', 'evidence-117469', 'evidence-636423']},
#  'claim-1479': {'claim_text': 'In no way, shape, or form are humans warming or cooling the planet.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-814790', 'evidence-264263', 'evidence-919710']},
#  'claim-1702': {'claim_text': 'CO2 levels are measured by hundreds of stations across the globe, all reporting the same trend.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-494305', 'evidence-454993']},
#  'claim-196': {'claim_text': 'Without carbon dioxide, all life on Earth would die',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-707516']},
#  'claim-2495': {'claim_text': "'Gore claims the snowcap atop Africa's Mt. Kilimanjaro is shrinking and that global warming is to blame.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-661860']},
#  'claim-190': {'claim_text': 'Climate change is normal and continual.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-141026',
#    'evidence-288123',
#    'evidence-956330',
#    'evidence-259736']},
#  'claim-2431': {'claim_text': 'Short term cooling over the last few years is largely due to a strong La Nina phase in the Pacific Ocean and a prolonged solar minimum.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-56331', 'evidence-1097322', 'evidence-263527']},
#  'claim-230': {'claim_text': 'In the early 2000s, ice shelves began disintegrating in several parts of Antarctica, and scientists realized that process could greatly accelerate the demise of the vastly larger ice sheets themselves.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1073893',
#    'evidence-1196208',
#    'evidence-207228',
#    'evidence-414446',
#    'evidence-462080']},
#  'claim-2122': {'claim_text': 'Dropped stations introduce warming bias',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-918756']},
#  'claim-1603': {'claim_text': 'Coral atolls grow as sea levels rise.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-87673',
#    'evidence-568649',
#    'evidence-228201',
#    'evidence-844529',
#    'evidence-613692']},
#  'claim-2538': {'claim_text': 'Satellites and on-site measurements are observing that Himalayan glaciers are disappearing at an accelerating rate.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1075757',
#    'evidence-272489',
#    'evidence-776166',
#    'evidence-1018611',
#    'evidence-775820']},
#  'claim-3024': {'claim_text': 'Unlike the simple example of positive feedback we learned in high school, the increase from every round of feedback gets smaller and smaller, in the case of the enhanced greenhouse effect.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-823982',
#    'evidence-881780',
#    'evidence-1087464',
#    'evidence-380642',
#    'evidence-832459']},
#  'claim-1751': {'claim_text': 'Benny Peiser, the Oreskes critic, retracted his criticism.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-998193', 'evidence-75600', 'evidence-281927']},
#  'claim-880': {'claim_text': 'The peer-reviewed study by two scientists and a veteran statistician looked at the global average temperature datasets[…]',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-341925',
#    'evidence-642214',
#    'evidence-422404',
#    'evidence-770232',
#    'evidence-899588']},
#  'claim-1618': {'claim_text': "We didn't have global warming during the Industrial Revolution.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-697238',
#    'evidence-927151',
#    'evidence-94670',
#    'evidence-950186',
#    'evidence-1143587']},
#  'claim-435': {'claim_text': 'NOAA’s analysis found last month was the 3rd-warmest April on record globally.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-532405',
#    'evidence-505227',
#    'evidence-507554',
#    'evidence-774927',
#    'evidence-39501']},
#  'claim-2323': {'claim_text': 'Now scientists are telling us that Mars is experiencing its own planetary warming: Martian warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-809116']},
#  'claim-1342': {'claim_text': 'The worsening of tidal flooding in American coastal communities is largely a consequence of greenhouse gases from human activity, and the problem will grow far worse in coming decades, scientists reported Monday.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1047395',
#    'evidence-464979',
#    'evidence-881808',
#    'evidence-635378',
#    'evidence-130492']},
#  'claim-1265': {'claim_text': 'Some, however, bristle at the belief that because floods and storms have always occurred, they should not be linked to climate change”',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1046024',
#    'evidence-275823',
#    'evidence-297320',
#    'evidence-815627']},
#  'claim-1946': {'claim_text': "President Obama's proposal calls for serious cuts in our own long-term carbon emissions, but China and India will still be allowed to increase their emissions.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-185634', 'evidence-1080644']},
#  'claim-1503': {'claim_text': 'climate models have overestimated the amount of global warming and failed to predict what climatologists call the warming ‘hiatus’.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-198457', 'evidence-607448', 'evidence-934400']},
#  'claim-2766': {'claim_text': 'The most interesting thing here is that the albedo forcings, in watts/sq meter seem to be fairly large.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1161717']},
#  'claim-1523': {'claim_text': 'Research has found a human influence on the climate of the past several decades ...',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-5055',
#    'evidence-1028174',
#    'evidence-926283',
#    'evidence-777312',
#    'evidence-1180097']},
#  'claim-2024': {'claim_text': 'Wisconsin employers have repeatedly said in surveys that our anti-business litigation climate is one of the most important factors affecting their expansion decisions.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-732260',
#    'evidence-609781',
#    'evidence-880288',
#    'evidence-486683',
#    'evidence-186892']},
#  'claim-2047': {'claim_text': 'contrary to the hypothesis that rising temperature is caused by increasing CO2.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-368192',
#    'evidence-801082',
#    'evidence-278454',
#    'evidence-288193',
#    'evidence-742898']},
#  'claim-2500': {'claim_text': "Believers think the warming is man-made, while the skeptics believe the warming is natural and contributions from man are minimal and certainly not potentially catastrophic à la Al Gore.'",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-812311', 'evidence-241943']},
#  'claim-2935': {'claim_text': 'Claims have recently surfaced in the blogosphere that an increasing number of scientists are warning of an imminent global cooling, some even going so far as to call it a "growing consensus".',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-957593', 'evidence-817759', 'evidence-742898']},
#  'claim-3058': {'claim_text': 'Correspondingly, the global surface temperature has also dropped."',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-951865',
#    'evidence-1146102',
#    'evidence-713207',
#    'evidence-788111']},
#  'claim-1859': {'claim_text': "Big rooftop solar's plan forces Nevada families who don't have solar panels to pay higher power bills to subsidize rooftop solar.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-210985',
#    'evidence-8749',
#    'evidence-276384',
#    'evidence-768643',
#    'evidence-632366']},
#  'claim-1654': {'claim_text': 'Climate scientists could make far more money in other careers - most notably, working for the oil industry.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-844698',
#    'evidence-330356',
#    'evidence-597213',
#    'evidence-798630',
#    'evidence-1066003']},
#  'claim-1186': {'claim_text': 'President Hilda Heine has told reporters that longtime residents are leaving the Marshall Islands because climate change is threatening the nation’s existence.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1036330', 'evidence-926893']},
#  'claim-823': {'claim_text': '’Extremely remarkable’ 2017 heads toward record for hottest year without an El Niño episode.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-319975', 'evidence-714466']},
#  'claim-2918': {'claim_text': 'Temperature errors in the Great Lakes region are not incorporated in any of the global mean temperature records.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1011804',
#    'evidence-266742',
#    'evidence-704658',
#    'evidence-1198416',
#    'evidence-901456']},
#  'claim-1532': {'claim_text': 'Warming of the climate system is unequivocal, and since the 1950s, many of the observed changes are unprecedented over decades to millennia.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-588652',
#    'evidence-734286',
#    'evidence-1159499',
#    'evidence-289908',
#    'evidence-1053862']},
#  'claim-1169': {'claim_text': '“Sea level rise, which was occurring long before humans could be blamed, has not accelerated and still amounts to only 1 inch every ten years.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-71166',
#    'evidence-1018611',
#    'evidence-1192617',
#    'evidence-646192',
#    'evidence-363960']},
#  'claim-2128': {'claim_text': 'Less than half of published scientists endorse global warming',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-503460', 'evidence-116462', 'evidence-1007867']},
#  'claim-3005': {'claim_text': 'About 60% of the warming observed from 1970 to 2000 was very likely caused by the above natural 60-year climatic cycle during its warming phase" (Loehle and Scafetta)',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-126476']},
#  'claim-1921': {'claim_text': 'Miami Congressman Carlos "Curbelo supports drilling offshore" and "repeatedly voted against President Obama\'s ability to fight pollution and combat climate change."',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1048912', 'evidence-686100', 'evidence-1004471']},
#  'claim-2395': {'claim_text': 'While the Greenland interior is in mass balance, the coastlines are losing ice.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1010458', 'evidence-55727']},
#  'claim-2800': {'claim_text': 'Elementary radiative-transfer calculations demonstrate that a natural surface global brightening amounting to ~1.9 Wm–2 over the 18-year period of study would be expected – using the IPCC’s own methodology – to have caused a transient warming of 1 K (1.8 F°).',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-219780',
#    'evidence-963856',
#    'evidence-905191',
#    'evidence-1197833',
#    'evidence-675427']},
#  'claim-3049': {'claim_text': 'that atmospheric CO2 increase that we observe is a product of temperature  increase, and not the other way around, meaning it is a product of  natural variation...',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-368192', 'evidence-423643']},
#  'claim-3008': {'claim_text': "However, more direct comparisons between solar activity and global temperature finds that  as the sun grew hotter or cooler, Earth's climate followed it with a 10 year lag - presumably due to the dampening effect of the ocean.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-651544']},
#  'claim-997': {'claim_text': 'Ever since 2012, scientists have been debating a complex and frankly explosive idea about how a warming planet will alter our weather — one that, if it’s correct, would have profound implications across the Northern Hemisphere and especially in its middle latitudes',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1096724',
#    'evidence-801178',
#    'evidence-319893',
#    'evidence-1102346',
#    'evidence-269919']},
#  'claim-2614': {'claim_text': '"The Keeling curve, which is widely used to show the increase in CO2 emissions, is based on data from the top of Mount Mauna Loa in Hawaii.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-512615', 'evidence-1117728', 'evidence-1092339']},
#  'claim-816': {'claim_text': 'While geologists have studied events in the past similar to what appears to be happening today, scientists are largely unsure of what lies ahead.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-917166', 'evidence-557387']},
#  'claim-1347': {'claim_text': 'Scientists say the recent climate agreement negotiated in Paris is not remotely ambitious enough to forestall a significant melting of Greenland and Antarctica, though if fully implemented, it may slow the pace somewhat.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-225934']},
#  'claim-2843': {'claim_text': 'Together, these two unaltered [sea level] datasets indicate that global mean sea level trend has remained stable over the entire period 1992-2007, altogether eliminating the apparent 3.2 mm/year rate of sea-level rise arising from the “adjusted” data.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1094759',
#    'evidence-811585',
#    'evidence-514779',
#    'evidence-192836']},
#  'claim-1789': {'claim_text': "CO2 limits won't cool the planet, but they can make the difference between continued accelerating global warming to catastrophic levels vs. slowing and eventually stopping the warming at hopefully safe levels.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-812823']},
#  'claim-482': {'claim_text': 'It is expected the report will focus on required changes to the energy system, rather than forests.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-424038']},
#  'claim-805': {'claim_text': 'The answer lies in the summer’s record-breaking heat, say wildfire experts.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-547830', 'evidence-331462', 'evidence-970539']},
#  'claim-2630': {'claim_text': '"A new storm and a new red spot on Jupiter hints at climate change, USA TODAY and dozens of other sources explained yesterday.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1206310',
#    'evidence-406963',
#    'evidence-1192488',
#    'evidence-97974']},
#  'claim-1464': {'claim_text': 'The U.S. has also witnessed increasing numbers of intense rainfall events.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-344657',
#    'evidence-479625',
#    'evidence-761993',
#    'evidence-651486',
#    'evidence-303213']},
#  'claim-2562': {'claim_text': 'When accelerating ice loss from Greenland and Antarctica are factored into sea level projections, the estimated sea level rise by 2100 is between 75cm to 2 metres.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-117469',
#    'evidence-385273',
#    'evidence-1109106',
#    'evidence-654432']},
#  'claim-724': {'claim_text': 'A fast transition away from fossil fuels in the next few decades could be enough to put off rapid sea-level rise for centuries.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-988277', 'evidence-1093172']},
#  'claim-615': {'claim_text': 'If warming temperatures brought on by greenhouse gas emissions make wet years less wet and dry years even drier, as scientists anticipate, year-to-year recovery will become more difficult.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-666050', 'evidence-381374', 'evidence-153356']},
#  ...}

# %%
len(train_claims)
# Out:
# 1228

# %% [markdown]
# ### Have a look at structure of dev_claims and how many there are

# %%
dev_claims
# Out:
# {'claim-752': {'claim_text': '[South Australia] has the most expensive electricity in the world.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-67732', 'evidence-572512']},
#  'claim-375': {'claim_text': 'when 3 per cent of total annual global emissions of carbon dioxide are from humans and Australia prod\xaduces 1.3 per cent of this 3 per cent, then no amount of emissions reductio\xadn here will have any effect on global climate.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-996421',
#    'evidence-1080858',
#    'evidence-208053',
#    'evidence-699212',
#    'evidence-832334']},
#  'claim-1266': {'claim_text': 'This means that the world is now 1C warmer than it was in pre-industrial times',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-889933', 'evidence-694262']},
#  'claim-871': {'claim_text': '“As it happens, Zika may also be a good model of the second worrying effect — disease mutation.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-422399',
#    'evidence-702226',
#    'evidence-286834',
#    'evidence-472751',
#    'evidence-641043']},
#  'claim-2164': {'claim_text': 'Greenland has only lost a tiny fraction of its ice mass',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-52981',
#    'evidence-264761',
#    'evidence-947243',
#    'evidence-424102']},
#  'claim-1607': {'claim_text': "CO2 limits won't cool the planet.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-913997',
#    'evidence-955328',
#    'evidence-401235',
#    'evidence-915569',
#    'evidence-370378']},
#  'claim-761': {'claim_text': '[Riebesell] is a world authority on the topic and has typically communicated cautiously about the effects of acidification.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1129386',
#    'evidence-456747',
#    'evidence-625922',
#    'evidence-590068',
#    'evidence-741718']},
#  'claim-1718': {'claim_text': 'The actual data show high northern latitudes are warmer today than in 1940.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-857561', 'evidence-1150493']},
#  'claim-1273': {'claim_text': 'The rapid changes in the climate may have profound consequences for humans and other species… Severe drought caused food shortages for millions of people in Ethiopia, with a lack of rainfall resulting in “intense and widespread” forest fires in Indonesia that belched out a vast quantity of greenhouse gas',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-659559',
#    'evidence-181656',
#    'evidence-499929',
#    'evidence-354699']},
#  'claim-1786': {'claim_text': 'CFCs contribute to global waerming at a small level.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-845527', 'evidence-105411', 'evidence-323167']},
#  'claim-2796': {'claim_text': 'Had he used the currently accepted value of approximately 3°C warming for a doubling of atmospheric CO2, Hansen would have correctly projected the ensuing global warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-210167']},
#  'claim-2580': {'claim_text': 'Volcanoes emit around 0.3 billion tonnes of CO2 per year.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-15399', 'evidence-243372']},
#  'claim-1219': {'claim_text': 'Global warming is driving major melting on the surface of Greenland’s glaciers and is speeding up their travel into the sea.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-88825', 'evidence-1127398', 'evidence-1115033']},
#  'claim-75': {'claim_text': 'The science is clear, climate change is making extreme weather events, including tornadoes, worse.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-940688',
#    'evidence-985094',
#    'evidence-8304',
#    'evidence-653981',
#    'evidence-789848']},
#  'claim-2813': {'claim_text': 'In fact, the authors go on to estimate climate sensitivity from their findings, calculate a value between 2.3 to 4.1°C.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-679700',
#    'evidence-158204',
#    'evidence-1049371',
#    'evidence-358515',
#    'evidence-920160']},
#  'claim-2335': {'claim_text': 'Satellite measurements of infrared spectra over the past 40 years observe less energy escaping to space at the wavelengths associated with CO2.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-327103',
#    'evidence-740261',
#    'evidence-1085966',
#    'evidence-701021',
#    'evidence-472543']},
#  'claim-161': {'claim_text': 'Extreme melting and changes to the climate like this has released pressure on to the continent, allowing the ground to rise up.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-702708']},
#  'claim-2243': {'claim_text': 'The CO2 amplifies the warming and mixes through the atmosphere, spreading warming throughout the planet.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-993522',
#    'evidence-1007525',
#    'evidence-368192',
#    'evidence-991415']},
#  'claim-1256': {'claim_text': '‘Next year or the year after, the Arctic will be free of ice’',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-731434',
#    'evidence-39028',
#    'evidence-1107462',
#    'evidence-954212',
#    'evidence-957020']},
#  'claim-506': {'claim_text': 'More than 100 climate models over the past 30 years did not predict what actually happened because it was assumed carbon dioxide had the pivotal role in driving climate change and that the effects of clouds, back-radiation and the sun were trivial.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1199931',
#    'evidence-510347',
#    'evidence-1057489',
#    'evidence-100394',
#    'evidence-1197833']},
#  'claim-369': {'claim_text': 'By 2050 there’s a scientific consensus that we reached the tipping point for ice sheets in Greenland and the West Antarctic',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-783884', 'evidence-411817']},
#  'claim-2184': {'claim_text': 'We have had ice ages and warmer periods when alligators were found in Spitzbergen.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-224942', 'evidence-1113919']},
#  'claim-1057': {'claim_text': '“Moreover, the ocean already contains so-called oxygen minimum zones, generally found in the middle depths.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-747577',
#    'evidence-69294',
#    'evidence-754329',
#    'evidence-21184',
#    'evidence-754923']},
#  'claim-104': {'claim_text': 'Increases in atmospheric CO2 followed increases in temperature.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-368192', 'evidence-423643', 'evidence-629358']},
#  'claim-1975': {'claim_text': 'The claim that 97 percent of scientists believe humans are causing climate change has been debunked by the "head" of the United Nations Intergovernmental Panel on Climate Change.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-963115',
#    'evidence-154218',
#    'evidence-503460',
#    'evidence-797793',
#    'evidence-335835']},
#  'claim-139': {'claim_text': 'And in January, one out of five British children told pollsters they were having nightmares about climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-315515']},
#  'claim-2062': {'claim_text': 'Global warming is increasing the magnitude and frequency of droughts and floods.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-657110', 'evidence-553897', 'evidence-1091550']},
#  'claim-1160': {'claim_text': 'With more CO2 in the atmosphere, the challenge [feeding 2.5 billion more people] can and will be met.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-76391']},
#  'claim-2679': {'claim_text': '"The solubility of carbon dioxide in water is listed in the Handbook of Chemistry and Physics as a declining function of temperature. ...',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1082891',
#    'evidence-411794',
#    'evidence-73808',
#    'evidence-558397',
#    'evidence-583134']},
#  'claim-2662': {'claim_text': '"...there is the contention by Wolfgang Knorr of the Department of Earth Sciences at the University of Bristol in England that carbon dioxide levels in the atmosphere are about where they were 160 years ago." (as quoted by Ken Ward Jr.)',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-450316',
#    'evidence-657496',
#    'evidence-962456',
#    'evidence-800880']},
#  'claim-1490': {'claim_text': 'the concentration of carbon dioxide in Earth’s atmosphere has climbed to a level last seen more than 3 million years ago — before humans even appeared on the rocky ball we call home.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-551522']},
#  'claim-2768': {'claim_text': 'The long term trend from albedo is that of cooling.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-695602', 'evidence-458452', 'evidence-1075210']},
#  'claim-2168': {'claim_text': 'IPCC graph showing accelerating trends is misleading',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-41418']},
#  'claim-785': {'claim_text': 'In many other cases, though — hurricanes, for example — the linkage to global warming for particular trends is uncertain or disputed.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-3489',
#    'evidence-202201',
#    'evidence-1038523',
#    'evidence-1041281',
#    'evidence-626239']},
#  'claim-2426': {'claim_text': '"Twentieth century global warming did not start until  1910.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-697238']},
#  'claim-1292': {'claim_text': 'Any reasonable person can recognize both positives and negatives among the policy proposals of both Tories and Labour.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-342343',
#    'evidence-399707',
#    'evidence-1014366',
#    'evidence-462075',
#    'evidence-627910']},
#  'claim-993': {'claim_text': 'While there has been a mean rise of a little more than 3mm per year worldwide since the 1990s, in the last decade, the NOAA Virginia Key tide gauge just south of Miami Beach has measured a 9mm rise annually.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-946255', 'evidence-1049692']},
#  'claim-2593': {'claim_text': '[T]he study indicates “Greenland’s ice may be less susceptible to the massive meltdown predicted by computer models of climate change, the main author ... said in an interview. ...',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-857269', 'evidence-797161']},
#  'claim-1567': {'claim_text': 'IPCC overestimate temperature rise.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-105184']},
#  'claim-1834': {'claim_text': 'A 14 August 1912 article from a New Zealand newspaper contained a brief story about how burning coal might produce future warming by adding carbon dioxide to the atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-173323', 'evidence-477558']},
#  'claim-856': {'claim_text': 'as the pathbreaking work by Rosamond Naylor and David Battisti has shown, the tropics are already too hot to efficiently grow grain, and those places where grain is produced today are already at optimal growing temperature — which means even a small warming will push them down the slope of declining productivity.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1166728', 'evidence-578305']},
#  'claim-540': {'claim_text': 'The heatwave we now have in Europe is not something that was expected with just 1C of warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-353209',
#    'evidence-1194725',
#    'evidence-1067217',
#    'evidence-556258',
#    'evidence-119750']},
#  'claim-757': {'claim_text': 'The grasslands, crops, forests and territorial waters of Australia absorb more carbon dioxide than Australia emits.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-682087',
#    'evidence-744771',
#    'evidence-352796',
#    'evidence-173055']},
#  'claim-1407': {'claim_text': '“In their award winning book, ‘Taken By Storm’ (2007), Canadian researchers Christopher Essex and Ross McKitrick explain: ‘Temperature is not an amount of something [like height or weight].',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-25485',
#    'evidence-189203',
#    'evidence-710700',
#    'evidence-948988',
#    'evidence-179080']},
#  'claim-3070': {'claim_text': 'So this is a government which is proposing to put at risk our manufacturing industry, to penalise struggling families, to make a tough situation worse for millions of households right around Australia.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-137771',
#    'evidence-100483',
#    'evidence-617690',
#    'evidence-462483',
#    'evidence-222747']},
#  'claim-1745': {'claim_text': 'The IPCC simply updated their temperature history graphs to show the best data available at the time.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-660105',
#    'evidence-1197833',
#    'evidence-1052408',
#    'evidence-911855',
#    'evidence-332770']},
#  'claim-1515': {'claim_text': 'no one really knows if last year 2016 was a global temperature record.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-915569',
#    'evidence-742898',
#    'evidence-730599',
#    'evidence-169703',
#    'evidence-64048']},
#  'claim-1519': {'claim_text': 'The Earth’s climate is changing in response to increasing concentrations of greenhouse gases (GHGs) and particulate matter in the atmosphere, largely as the result of human activities.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1059381', 'evidence-1187937', 'evidence-950186']},
#  'claim-3069': {'claim_text': 'Continued greenhouse gas emissions at or above current rates would cause further warming and induce many changes in the global climate system during the 21st century that would very likely be larger than those observed during the 20th century.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-504415']},
#  'claim-677': {'claim_text': '“Which is to say that these beans will be eaten by cows, and the cows will convert the beans to meat, and the humans will eat the meat.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-459277',
#    'evidence-1079220',
#    'evidence-368638',
#    'evidence-1193739',
#    'evidence-474026']},
#  'claim-765': {'claim_text': 'The broader term covers changes beyond warmer temperatures, such as shifting rainfall patterns.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-456747', 'evidence-496267']},
#  'claim-2275': {'claim_text': '[…] Constant 24-7  media coverage of every significant storm worldwide just makes it seem  that way.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-754084', 'evidence-940616']},
#  'claim-1113': {'claim_text': 'This means the jet stream meanders more, with big loops bringing warm air to the frozen north and cold air into warmer southern climes.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-459315']},
#  'claim-2611': {'claim_text': 'The final amount of extra CO2 that remains in the atmosphere stays there on a time scale of centuries.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1205623', 'evidence-620559', 'evidence-20807']},
#  'claim-2060': {'claim_text': 'Global warming is causing more hurricanes and stronger hurricanes.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-553897', 'evidence-8304']},
#  'claim-2326': {'claim_text': '"In 2007, the Northern Hemisphere reached a record low in ice coverage and the Northwest Passage was opened.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1017927',
#    'evidence-956029',
#    'evidence-29644',
#    'evidence-1079662']},
#  'claim-1087': {'claim_text': 'The particular signature of warming in 2016 was also revealing in another way, Overpeck said, noting that the stratosphere… saw record cold temperatures last year',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-382930',
#    'evidence-818951',
#    'evidence-1020939',
#    'evidence-607965',
#    'evidence-541555']},
#  'claim-2867': {'claim_text': "Skeptics who oppose scientific findings that threaten their world view are far closer to Galileo's belief-based critics in the Catholic Church.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-392', 'evidence-1091064', 'evidence-847727']},
#  'claim-2300': {'claim_text': '"Austria is today seeing its earliest snowfall in history with 30 to 40 centimetres already predicted in the mountains.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-163344',
#    'evidence-612818',
#    'evidence-208322',
#    'evidence-776430',
#    'evidence-977782']},
#  'claim-2250': {'claim_text': "Some global warming 'skeptics' argue that the Earth's climate sensitivity is so low that a doubling of atmospheric CO2 will result in a surface temperature change on the order of 1°C or less, and that therefore global warming is nothing to worry about.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-692256', 'evidence-1049371']},
#  'claim-2429': {'claim_text': 'With 32 years of  rapidly increasing global temperatures and only a minor increase in  global CO2 emissions, followed by 33 years of slowly cooling global  temperatures with rapid increases in global CO2 emissions, it was  deceitful for the IPCC to make any claim that CO2 emissions were  primarily responsible for observed 20th century global warming."',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-755175', 'evidence-1202023', 'evidence-483558']},
#  'claim-3051': {'claim_text': 'Once natural influences, in particular the impact of El Niño and La Niña, are removed from the recent termperature record, there is no evidence of a significant change in the human contribution to climate change.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1187937', 'evidence-881808', 'evidence-338219']},
#  'claim-1549': {'claim_text': "There's no empirical evidence for climate change.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1047048', 'evidence-574477']},
#  'claim-261': {'claim_text': 'in 1995 one scientist at the IPCC – Jonathan Overpeck – wrote an email to a colleague claiming ‘we have to get rid of the Medieval Warm Period.’',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-112875',
#    'evidence-33543',
#    'evidence-974202',
#    'evidence-332770',
#    'evidence-32121']},
#  'claim-2230': {'claim_text': '[Ice] is expanding in much of Antarctica, contrary to the widespread public belief that global warming is melting the continental ice cap.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-728645', 'evidence-1170460']},
#  'claim-2579': {'claim_text': 'Over the past 250 years, humans have added just one part of CO2 in 10,000 to the atmosphere.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-861762', 'evidence-788947', 'evidence-252580']},
#  'claim-1416': {'claim_text': 'In recent decades this warming has been accompanied by a constant rise in the sea level and, it would appear, by an increase of extreme weather events, even if a scientifically determinable cause cannot be assigned to each particular phenomenon.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-946255',
#    'evidence-1129603',
#    'evidence-456747',
#    'evidence-1091550']},
#  'claim-2497': {'claim_text': "Without the forests' humidity, previously moisture-laden winds blew dry.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-193559',
#    'evidence-935441',
#    'evidence-1051806',
#    'evidence-482305',
#    'evidence-335697']},
#  'claim-811': {'claim_text': 'But [climate scientists] say that aspects of the case of Hurricane Harvey—and the recent history of tropical cyclones worldwide—suggest global warming is making a bad situation worse.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-604477',
#    'evidence-1055682',
#    'evidence-1047356',
#    'evidence-759337',
#    'evidence-879500']},
#  'claim-1896': {'claim_text': 'Greg Hunt CSIRO research shows carbon emissions can be reduced by 20 per cent over 40 years using nature, soils and trees.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-798121',
#    'evidence-305800',
#    'evidence-108068',
#    'evidence-234076',
#    'evidence-1111240']},
#  'claim-2819': {'claim_text': 'More importantly, the OISM list only contains 39 scientists who specialise in climate science.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-572386',
#    'evidence-596256',
#    'evidence-363528',
#    'evidence-1161865',
#    'evidence-676759']},
#  'claim-2643': {'claim_text': 'The "decline" refers to a decline in northern tree-rings, not global temperature, and is openly discussed in papers and the IPCC reports.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-224185', 'evidence-267910', 'evidence-736392']},
#  'claim-1775': {'claim_text': 'Venus very likely underwent a runaway or ‘moist’ greenhouse phase earlier in its history, and today is kept hot by a dense CO2 atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1043526']},
#  'claim-316': {'claim_text': 'the models predicted seven times as much warming as has been observed',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-733847', 'evidence-980959', 'evidence-368241']},
#  'claim-896': {'claim_text': 'According to the WHO, exposure to particulate matter increases the risk of acute lower respiratory infection, chronic obstructive pulmonary disease, heart disease, stroke and lung cancer.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-534239', 'evidence-1171424', 'evidence-416776']},
#  'claim-331': {'claim_text': 'But each serial adjustment has tended to make the early years colder, which increases the warming trend.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-138622',
#    'evidence-584709',
#    'evidence-1189271',
#    'evidence-561696',
#    'evidence-311416']},
#  'claim-2574': {'claim_text': 'On a world scale coral reefs are in decline.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-369389',
#    'evidence-406279',
#    'evidence-292123',
#    'evidence-886566',
#    'evidence-580567']},
#  'claim-342': {'claim_text': 'While members of the media may nod along to such claims [about changes in weather extremes], the evidence paints a different story',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-817269', 'evidence-246671']},
#  'claim-2034': {'claim_text': 'Latest IPCC Reports (AR5) have shown global mean temperature forecasts from the 2005 IPCC report exceeded actual readings.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-232879', 'evidence-1197833']},
#  'claim-578': {'claim_text': '‘If we do nothing to reduce our greenhouse gas emissions, the kind of extreme heat we saw this past summer will be the norm when my young son is a grown man.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-960067']},
#  'claim-976': {'claim_text': 'The gas builds up in the soil, forming mounds called ‘pingoes.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-350072']},
#  'claim-1097': {'claim_text': '“[…]The impact on calcification, metabolism, growth, fertility and survival of calcifying marine species when pH is lowered up to 0.3 units […] is beneficial, not damaging.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1112531', 'evidence-616116']},
#  'claim-609': {'claim_text': 'That’s because as Antarctica’s mass shrinks, the ice sheet’s gravitational pull on the ocean relaxes somewhat, and the seas travel back across the globe to pile up far away — with U.S. coasts being one prime destination.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-557585']},
#  'claim-173': {'claim_text': 'If there were [carbon emissions], we could not see because most carbon is black.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-142343']},
#  'claim-1222': {'claim_text': 'The melting Greenland ice sheet is already a major contributor to rising sea level and if it was eventually lost entirely, the oceans would rise by six metres around the world, flooding many of the world’s largest cities.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-856068',
#    'evidence-7473',
#    'evidence-952525',
#    'evidence-173281',
#    'evidence-1040612']},
#  'claim-2441': {'claim_text': 'Furthermore, it is physically incorrect to state that the planet is simply "recovering" from the Little Ice Age.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-494148']},
#  'claim-756': {'claim_text': 'Australia’s signed a suicide note [with the Paris Accord] yet didn’t seem to notice that China, India, Indonesia and the US did not commit to reducing their large carbon dioxide emissions.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-901598', 'evidence-719544', 'evidence-229230']},
#  'claim-2577': {'claim_text': '"Three recent articles give us reason to question the alarmists’ claims  that coral reefs are in deep trouble due to the buildup of greenhouse  gases." (World Climate Report)',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-663642',
#    'evidence-463557',
#    'evidence-469998',
#    'evidence-511848',
#    'evidence-338219']},
#  'claim-2890': {'claim_text': 'Heat is continuing to build up in the subsurface ocean.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-742886',
#    'evidence-131135',
#    'evidence-71710',
#    'evidence-1020632',
#    'evidence-674318']},
#  'claim-2478': {'claim_text': '(Kerr 2007) points out that the sunlight-reflecting haze that cools much of the planet seems to have thinned over the past decade or so.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-220532']},
#  'claim-2399': {'claim_text': 'While the greenhouse effect is a natural occurence, too much warming has severe negative impacts on agriculture, health and environment.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1047395',
#    'evidence-398589',
#    'evidence-1122962',
#    'evidence-504446',
#    'evidence-298450']},
#  'claim-3091': {'claim_text': 'Global Warming history completely coincides with the history of artificial satellites and the use of microwave frequencies from outer space.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-917344',
#    'evidence-866933',
#    'evidence-520355',
#    'evidence-927151',
#    'evidence-20748']},
#  'claim-141': {'claim_text': 'Greenpeace didn’t save the whales, switching from whale oil to petroleum and palm oil did',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-51845',
#    'evidence-1025353',
#    'evidence-917144',
#    'evidence-426684',
#    'evidence-784155']},
#  'claim-1933': {'claim_text': 'Newt Gingrich "teamed with Nancy Pelosi and Al Gore on global warming."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-380361',
#    'evidence-977987',
#    'evidence-837633',
#    'evidence-787339',
#    'evidence-971592']},
#  'claim-1689': {'claim_text': 'Evidence is building that net cloud feedback is likely positive and unlikely to be strongly negative.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-95001']},
#  'claim-443': {'claim_text': '“Today climate scientists are obsessed with the level of carbon dioxide in the atmosphere, a very very small part of the overall picture.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-555729']},
#  'claim-2037': {'claim_text': 'The rate of renewable energy installations in the EU in 2018 was less than half the maximum level achieved in 2010.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1113929',
#    'evidence-363747',
#    'evidence-268009',
#    'evidence-90731',
#    'evidence-1065009']},
#  'claim-1734': {'claim_text': 'Jim Hansen had several possible scenarios; his mid-level scenario B was right.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1005240',
#    'evidence-485896',
#    'evidence-147653',
#    'evidence-210167',
#    'evidence-901245']},
#  'claim-2093': {'claim_text': 'Through its impacts on the climate, CO2 presents a danger to public health and welfare, and thus qualifies as an air pollutant',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-743065']},
#  'claim-1400': {'claim_text': 'The late 1970s marked the end of a 30-year cooling trend.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-502252']},
#  'claim-1638': {'claim_text': 'Worry about global warming impacts in the next 100 years, not an ice age in over 10,000 years.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-336096',
#    'evidence-418973',
#    'evidence-142343',
#    'evidence-954212',
#    'evidence-1016625']},
#  'claim-3075': {'claim_text': "Multiple lines of evidence indicate Greenland's ice loss is accelerating and will contribute sea level rise in the order of metres over the next few centuries.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-59240', 'evidence-391045', 'evidence-123917']},
#  'claim-38': {'claim_text': 'Scientists studying Antarctica sea ice warn a rise in accumulation could spark the next ice age.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-591257']},
#  'claim-1643': {'claim_text': "Al Gore's book is quite accurate, and far more accurate than contrarian books.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-506072',
#    'evidence-1109658',
#    'evidence-1087633',
#    'evidence-1033955']},
#  'claim-1259': {'claim_text': 'While the north-east, midwest and upper great plains have experienced a 30% increase in heavy rainfall episodes – considered once-in-every-five year downpours – parts of the west, particularly California, have been parched by drought.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-17722',
#    'evidence-1023411',
#    'evidence-443760',
#    'evidence-948853']},
#  'claim-1605': {'claim_text': 'Scientists retracted claim that sea levels are rising.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-988277',
#    'evidence-1091550',
#    'evidence-98543',
#    'evidence-1121998']},
#  'claim-1711': {'claim_text': "Global warming' and 'climate change' mean different things and have both been used for decades.",
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-59188', 'evidence-1121750']},
#  'claim-2236': {'claim_text': 'The majority of peer reviewed research at the time predicted warming due to increasing CO2.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-976285']},
#  'claim-1040': {'claim_text': 'While evidence that the earth’s orbital variations impact radiation levels and thus global temperatures does not of course mean that man is not in some way impacting the climate, studies like these highlight that the role man plays on the planet is dwarfed by natural phenomena utterly out of our control.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-550422',
#    'evidence-163450',
#    'evidence-1107482',
#    'evidence-1137996',
#    'evidence-720840']},
#  'claim-392': {'claim_text': 'a study that totally debunks the whole concept of man-made Global Warming',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-724010', 'evidence-846906', 'evidence-1007867']},
#  'claim-368': {'claim_text': 'The most recent IPCC report lays out a future if we limit global heating to 1.5°C instead of the Paris Agreement’s 2°C.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-853312',
#    'evidence-839100',
#    'evidence-46356',
#    'evidence-994667']},
#  'claim-559': {'claim_text': 'And there is a lot of evidence that climate change is diminishing biodiversity, which can be seen in these alpine meadows as well.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1047048',
#    'evidence-109104',
#    'evidence-885423',
#    'evidence-942611']},
#  'claim-2583': {'claim_text': '"Each unit of CO2 you put into the atmosphere has less and less of a warming impact.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-827004',
#    'evidence-677057',
#    'evidence-1169593',
#    'evidence-1099186',
#    'evidence-178206']},
#  'claim-2609': {'claim_text': 'Individual carbon dioxide molecules have a short life time of around 5 years in the atmosphere.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-185746', 'evidence-801956', 'evidence-938381']},
#  'claim-492': {'claim_text': 'But like most claims regarding global warming, the real effect is small, probably temporary, and most likely due to natural weather patterns',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-896442',
#    'evidence-504446',
#    'evidence-128422',
#    'evidence-479999',
#    'evidence-1091550']},
#  'claim-1420': {'claim_text': 'Concentrated in the atmosphere, these gases do not allow the warmth of the sun’s rays reflected by the earth to be dispersed in space.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1069448', 'evidence-767961']},
#  'claim-1089': {'claim_text': 'Last year’s warmth was manifested across the planet, from the warm tropical ocean waters off the coast of northeastern Australia, where the Great Barrier Reef experienced its worst coral bleaching event on record and large scale coral death, to the Arctic, where sea ice hit regular monthly record lows and overall temperatures were also the warmest on record, at least from January through September 2016.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-815795',
#    'evidence-197787',
#    'evidence-95039',
#    'evidence-617908']},
#  'claim-1467': {'claim_text': 'The amount of carbon dioxide absorbed by the upper layer of the oceans is increasing by about 2 billion tons per year.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-425667',
#    'evidence-956954',
#    'evidence-923136',
#    'evidence-498380',
#    'evidence-257475']},
#  'claim-444': {'claim_text': 'Carbon dioxide is a trace gas.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1190705']},
#  'claim-803': {'claim_text': 'The team of climate scientists notes that in failing to predict the warming ‘hiatus’ in the beginning of the 21st century, the Intergovernmental Panel on Climate Change (IPCC) models overestimated temperature increases…',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-968233',
#    'evidence-325440',
#    'evidence-1197833',
#    'evidence-657969']},
#  'claim-1668': {'claim_text': 'Thick arctic sea ice is in rapid retreat.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-280204', 'evidence-1200544', 'evidence-629116']},
#  'claim-742': {'claim_text': 'Global human emissions are only 3 per cent of total annual emissions.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-556098', 'evidence-215052']},
#  'claim-846': {'claim_text': 'In other words, we have, trapped in Arctic permafrost, twice as much carbon as is currently wrecking the atmosphere of the planet, all of it scheduled to be released at a date that keeps getting moved up, partially in the form of a gas that multiplies its warming power 86 times over.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1173602', 'evidence-769821', 'evidence-94074']},
#  'claim-2119': {'claim_text': 'Lindzen and Choi find low climate sensitivity',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-127999']},
#  'claim-1167': {'claim_text': 'Lake-bottom sediments in Florida tell us that recent major hurricane activity in the Gulf of Mexico has been less frequent than in centuries past.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1150262']},
#  'claim-623': {'claim_text': 'The noted oceanographer Walter Munk referred to sea-level rise as an “enigma”',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-584943', 'evidence-965161']},
#  'claim-2882': {'claim_text': 'Trenberth\'s views are clarified in the paper "An imperative for climate change planning: tracking Earth\'s global energy".',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-363958']},
#  'claim-1698': {'claim_text': 'Around 97% of climate experts agree that humans are causing global warming.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-503460', 'evidence-797793']},
#  'claim-181': {'claim_text': 'Reefs need carbon dioxide; it’s their basic food.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-881960',
#    'evidence-903942',
#    'evidence-795828',
#    'evidence-218166',
#    'evidence-114903']},
#  'claim-281': {'claim_text': 'In an interview with the BBC after the scandal broke, Dr Jones admitted there had been no statistically significant global warming since 1995',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-18549', 'evidence-298772', 'evidence-509654']},
#  'claim-2809': {'claim_text': 'The motions of the massive oceans where heat is moved between deep layers and the surface provides variability on time scales from years to centuries.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-383714', 'evidence-94747', 'evidence-213245']},
#  'claim-1928': {'claim_text': 'NASA Finds Antarctica is Gaining Ice,',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1099128', 'evidence-529248', 'evidence-591257']},
#  'claim-2787': {'claim_text': "Hansen's 1988 results are evidence that the actual climate sensitivity is about 3°C for a doubling of atmospheric CO2.",
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-632574', 'evidence-918450', 'evidence-692256']},
#  'claim-478': {'claim_text': 'Protecting and restoring forests would reduce 18% of emissions by 2030',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-890810',
#    'evidence-328157',
#    'evidence-347403',
#    'evidence-594952',
#    'evidence-609211']},
#  'claim-988': {'claim_text': 'The unlikely scenarios are now, all of a sudden, becoming more probable than they once were thought to be,’ says Sweet.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-305696',
#    'evidence-444836',
#    'evidence-108865',
#    'evidence-44133',
#    'evidence-459314']},
#  'claim-266': {'claim_text': 'The IPCC no longer includes the ‘Hockey stick’ chart in its reports.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-380933',
#    'evidence-281372',
#    'evidence-327755',
#    'evidence-794055',
#    'evidence-1085447']},
#  'claim-2282': {'claim_text': 'While there are isolated cases of growing glaciers, the overwhelming trend in glaciers worldwide is retreat.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-797867',
#    'evidence-152443',
#    'evidence-272489',
#    'evidence-947076']},
#  'claim-2895': {'claim_text': 'The latest  measurements involve the use of satellite gravimetry, estimating  the mass of terrain beneath by detecting slight changes in gravity as a  satellite passes overhead.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-8627', 'evidence-81511']},
#  'claim-349': {'claim_text': 'Nor is there evidence of an increase in floods globally.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-323541', 'evidence-636631']},
#  'claim-2101': {'claim_text': 'Clouds provide negative feedback',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-207443', 'evidence-1029618', 'evidence-208863']},
#  'claim-897': {'claim_text': 'The report […] found that the United States was one of the most pollution-free nations in the world.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-783786']},
#  'claim-3063': {'claim_text': "'Another global warming myth comes crashing down.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-780841',
#    'evidence-53215',
#    'evidence-240527',
#    'evidence-1068590',
#    'evidence-588917']},
#  'claim-386': {'claim_text': 'Renew\xadables such as wind turbines are environmentally disastrous because they pollute a huge land area, slice and dice birds and bats, kill insects that are bird food, create health problems for humans who live within kilometres of them, leave toxins around the turbine site and despoil the landscape.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-555861']},
#  'claim-2691': {'claim_text': "There are a myriad of other radiative forcings that affect the planet's energy imbalance.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1190716',
#    'evidence-2462',
#    'evidence-814421',
#    'evidence-968110',
#    'evidence-1106814']},
#  'claim-530': {'claim_text': 'South Australia is winning: it has the most unreliable grid in the world outside Africa and the most expensive electricity.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-67732']},
#  'claim-2979': {'claim_text': 'Water vapor helps trap heat, and is a far the strongest of the major greenhouse gases, contributing 36–72 percent of the greenhouse effect.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-909112', 'evidence-706949']},
#  'claim-665': {'claim_text': 'many scientists were surprised when other researchers subsequently found that ringed and bearded seals (the primary prey of polar bears) north of the Bering Strait especially thrived with a longer open-water season, which is particularly conducive to fishing',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1105120',
#    'evidence-143437',
#    'evidence-133419',
#    'evidence-726838',
#    'evidence-578925']},
#  'claim-199': {'claim_text': 'In the past, warming has never been a threat to life on Earth.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-255653', 'evidence-817833']},
#  'claim-490': {'claim_text': 'IPCC report warning last week the world is “nowhere near on track” to meet its Paris commitments',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-225934', 'evidence-432573', 'evidence-1046773']},
#  'claim-2400': {'claim_text': '\'To suddenly label CO2 as a "pollutant" is a disservice to a gas that has played an enormous role in the development and sustainability of all life on this wonderful Earth.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-409365',
#    'evidence-127519',
#    'evidence-852573',
#    'evidence-1022738']},
#  'claim-204': {'claim_text': 'after a natural orbitally driven warming, atmospheric carbon dioxide content increases 800 years later',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-368192',
#    'evidence-261690',
#    'evidence-203533',
#    'evidence-803887',
#    'evidence-890534']},
#  'claim-1426': {'claim_text': 'Many of the world’s coral reefs are already barren or in a state of constant decline.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1124018',
#    'evidence-995813',
#    'evidence-1161994',
#    'evidence-288294',
#    'evidence-946262']},
#  'claim-698': {'claim_text': 'A recent study led by Lawrence Livermore National Laboratory climate scientist Ben Santer found that while the models ran hot, the ‘overestimation’ was ‘partly due to systematic deficiencies in some of the post-2000 external forcings used in the model simulations.’',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-660755']},
#  'claim-1021': {'claim_text': 'The corals may save themselves, as many other creatures are attempting to do, by moving toward the poles as the Earth warms, establishing new reefs in cooler water.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-242575', 'evidence-1175280']}}

# %%
len(dev_claims)
# Out:
# 154

# %% [markdown]
# ### Have a look at structure of test_claims and how many there are

# %%
dev_claims_baseline
# Out:
# {'claim-752': {'claim_text': '[South Australia] has the most expensive electricity in the world.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-67732',
#    'evidence-572512',
#    'evidence-909871',
#    'evidence-596058',
#    'evidence-66394',
#    'evidence-212071']},
#  'claim-375': {'claim_text': 'when 3 per cent of total annual global emissions of carbon dioxide are from humans and Australia prod\xaduces 1.3 per cent of this 3 per cent, then no amount of emissions reductio\xadn here will have any effect on global climate.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-832334',
#    'evidence-699212',
#    'evidence-1080858',
#    'evidence-242107',
#    'evidence-208053',
#    'evidence-996421']},
#  'claim-1266': {'claim_text': 'This means that the world is now 1C warmer than it was in pre-industrial times',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-315434',
#    'evidence-198055',
#    'evidence-694262',
#    'evidence-418670',
#    'evidence-286139',
#    'evidence-889933']},
#  'claim-871': {'claim_text': '“As it happens, Zika may also be a good model of the second worrying effect — disease mutation.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-303245',
#    'evidence-88449',
#    'evidence-385760',
#    'evidence-896701',
#    'evidence-828124',
#    'evidence-558236']},
#  'claim-2164': {'claim_text': 'Greenland has only lost a tiny fraction of its ice mass',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-947243',
#    'evidence-424102',
#    'evidence-911037',
#    'evidence-264761',
#    'evidence-106066',
#    'evidence-176859']},
#  'claim-1607': {'claim_text': "CO2 limits won't cool the planet.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-370378',
#    'evidence-947510',
#    'evidence-706315',
#    'evidence-915569',
#    'evidence-439100',
#    'evidence-955328']},
#  'claim-761': {'claim_text': '[Riebesell] is a world authority on the topic and has typically communicated cautiously about the effects of acidification.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-625922',
#    'evidence-421348',
#    'evidence-590068',
#    'evidence-220940',
#    'evidence-836911',
#    'evidence-456747']},
#  'claim-1718': {'claim_text': 'The actual data show high northern latitudes are warmer today than in 1940.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-28135',
#    'evidence-126025',
#    'evidence-1150493',
#    'evidence-722400',
#    'evidence-207623',
#    'evidence-626961']},
#  'claim-1273': {'claim_text': 'The rapid changes in the climate may have profound consequences for humans and other species… Severe drought caused food shortages for millions of people in Ethiopia, with a lack of rainfall resulting in “intense and widespread” forest fires in Indonesia that belched out a vast quantity of greenhouse gas',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-350619',
#    'evidence-181656',
#    'evidence-785582',
#    'evidence-111188',
#    'evidence-354699',
#    'evidence-437717']},
#  'claim-1786': {'claim_text': 'CFCs contribute to global waerming at a small level.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-166597',
#    'evidence-237344',
#    'evidence-304246',
#    'evidence-659835',
#    'evidence-532653',
#    'evidence-262966']},
#  'claim-2796': {'claim_text': 'Had he used the currently accepted value of approximately 3°C warming for a doubling of atmospheric CO2, Hansen would have correctly projected the ensuing global warming.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-48546',
#    'evidence-114452',
#    'evidence-608065',
#    'evidence-507976',
#    'evidence-155117',
#    'evidence-961963']},
#  'claim-2580': {'claim_text': 'Volcanoes emit around 0.3 billion tonnes of CO2 per year.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-659960',
#    'evidence-964601',
#    'evidence-712005',
#    'evidence-482717',
#    'evidence-111754',
#    'evidence-508397']},
#  'claim-1219': {'claim_text': 'Global warming is driving major melting on the surface of Greenland’s glaciers and is speeding up their travel into the sea.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-705027',
#    'evidence-186850',
#    'evidence-1127398',
#    'evidence-102406',
#    'evidence-413348',
#    'evidence-880547']},
#  'claim-75': {'claim_text': 'The science is clear, climate change is making extreme weather events, including tornadoes, worse.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-985094',
#    'evidence-940688',
#    'evidence-8304',
#    'evidence-789848',
#    'evidence-653981',
#    'evidence-392412']},
#  'claim-2813': {'claim_text': 'In fact, the authors go on to estimate climate sensitivity from their findings, calculate a value between 2.3 to 4.1°C.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-679700',
#    'evidence-1049371',
#    'evidence-484319',
#    'evidence-981395',
#    'evidence-878260',
#    'evidence-158204']},
#  'claim-2335': {'claim_text': 'Satellite measurements of infrared spectra over the past 40 years observe less energy escaping to space at the wavelengths associated with CO2.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-806756',
#    'evidence-77235',
#    'evidence-510120',
#    'evidence-818374',
#    'evidence-857655',
#    'evidence-701021']},
#  'claim-161': {'claim_text': 'Extreme melting and changes to the climate like this has released pressure on to the continent, allowing the ground to rise up.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-333768',
#    'evidence-921218',
#    'evidence-475564',
#    'evidence-37297',
#    'evidence-189439',
#    'evidence-633772']},
#  'claim-2243': {'claim_text': 'The CO2 amplifies the warming and mixes through the atmosphere, spreading warming throughout the planet.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-876853',
#    'evidence-368192',
#    'evidence-258526',
#    'evidence-993522',
#    'evidence-991415',
#    'evidence-576843']},
#  'claim-1256': {'claim_text': '‘Next year or the year after, the Arctic will be free of ice’',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-380014',
#    'evidence-570397',
#    'evidence-201240',
#    'evidence-229849',
#    'evidence-457792',
#    'evidence-924046']},
#  'claim-506': {'claim_text': 'More than 100 climate models over the past 30 years did not predict what actually happened because it was assumed carbon dioxide had the pivotal role in driving climate change and that the effects of clouds, back-radiation and the sun were trivial.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-85245',
#    'evidence-783239',
#    'evidence-753891',
#    'evidence-551806',
#    'evidence-244782',
#    'evidence-119636']},
#  'claim-369': {'claim_text': 'By 2050 there’s a scientific consensus that we reached the tipping point for ice sheets in Greenland and the West Antarctic',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-873547',
#    'evidence-297271',
#    'evidence-411817',
#    'evidence-429019',
#    'evidence-393514',
#    'evidence-175746']},
#  'claim-2184': {'claim_text': 'We have had ice ages and warmer periods when alligators were found in Spitzbergen.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1113919',
#    'evidence-55760',
#    'evidence-307943',
#    'evidence-224942',
#    'evidence-360349',
#    'evidence-969403']},
#  'claim-1057': {'claim_text': '“Moreover, the ocean already contains so-called oxygen minimum zones, generally found in the middle depths.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-69294',
#    'evidence-754923',
#    'evidence-754329',
#    'evidence-21184',
#    'evidence-267715',
#    'evidence-747577']},
#  'claim-104': {'claim_text': 'Increases in atmospheric CO2 followed increases in temperature.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-214045',
#    'evidence-434465',
#    'evidence-914738',
#    'evidence-475505',
#    'evidence-172274',
#    'evidence-599766']},
#  'claim-1975': {'claim_text': 'The claim that 97 percent of scientists believe humans are causing climate change has been debunked by the "head" of the United Nations Intergovernmental Panel on Climate Change.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-556655',
#    'evidence-853114',
#    'evidence-703704',
#    'evidence-637336',
#    'evidence-757190',
#    'evidence-51118']},
#  'claim-139': {'claim_text': 'And in January, one out of five British children told pollsters they were having nightmares about climate change.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-138408',
#    'evidence-617564',
#    'evidence-351218',
#    'evidence-334717',
#    'evidence-15073',
#    'evidence-189865']},
#  'claim-2062': {'claim_text': 'Global warming is increasing the magnitude and frequency of droughts and floods.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1091550',
#    'evidence-533398',
#    'evidence-191520',
#    'evidence-553897',
#    'evidence-198232',
#    'evidence-429891']},
#  'claim-1160': {'claim_text': 'With more CO2 in the atmosphere, the challenge [feeding 2.5 billion more people] can and will be met.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-784416',
#    'evidence-76391',
#    'evidence-127525',
#    'evidence-666017',
#    'evidence-609079',
#    'evidence-650889']},
#  'claim-2679': {'claim_text': '"The solubility of carbon dioxide in water is listed in the Handbook of Chemistry and Physics as a declining function of temperature. ...',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-73808',
#    'evidence-79222',
#    'evidence-922747',
#    'evidence-710394',
#    'evidence-411794',
#    'evidence-847003']},
#  'claim-2662': {'claim_text': '"...there is the contention by Wolfgang Knorr of the Department of Earth Sciences at the University of Bristol in England that carbon dioxide levels in the atmosphere are about where they were 160 years ago." (as quoted by Ken Ward Jr.)',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-778627',
#    'evidence-962456',
#    'evidence-657496',
#    'evidence-800880',
#    'evidence-337366',
#    'evidence-747494']},
#  'claim-1490': {'claim_text': 'the concentration of carbon dioxide in Earth’s atmosphere has climbed to a level last seen more than 3 million years ago — before humans even appeared on the rocky ball we call home.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-105086',
#    'evidence-476913',
#    'evidence-304483',
#    'evidence-387790',
#    'evidence-415513',
#    'evidence-895570']},
#  'claim-2768': {'claim_text': 'The long term trend from albedo is that of cooling.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-852737',
#    'evidence-232780',
#    'evidence-458452',
#    'evidence-961897',
#    'evidence-98413',
#    'evidence-842515']},
#  'claim-2168': {'claim_text': 'IPCC graph showing accelerating trends is misleading',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-22628',
#    'evidence-99603',
#    'evidence-41418',
#    'evidence-811089',
#    'evidence-325573',
#    'evidence-186728']},
#  'claim-785': {'claim_text': 'In many other cases, though — hurricanes, for example — the linkage to global warming for particular trends is uncertain or disputed.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-770769',
#    'evidence-76017',
#    'evidence-497242',
#    'evidence-202201',
#    'evidence-1041281',
#    'evidence-1038523']},
#  'claim-2426': {'claim_text': '"Twentieth century global warming did not start until  1910.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-765231',
#    'evidence-516764',
#    'evidence-121106',
#    'evidence-560303',
#    'evidence-660052',
#    'evidence-667559']},
#  'claim-1292': {'claim_text': 'Any reasonable person can recognize both positives and negatives among the policy proposals of both Tories and Labour.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-627910',
#    'evidence-342343',
#    'evidence-399707',
#    'evidence-462075',
#    'evidence-182625',
#    'evidence-400386']},
#  'claim-993': {'claim_text': 'While there has been a mean rise of a little more than 3mm per year worldwide since the 1990s, in the last decade, the NOAA Virginia Key tide gauge just south of Miami Beach has measured a 9mm rise annually.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-181597',
#    'evidence-162624',
#    'evidence-238210',
#    'evidence-177607',
#    'evidence-456977',
#    'evidence-625938']},
#  'claim-2593': {'claim_text': '[T]he study indicates “Greenland’s ice may be less susceptible to the massive meltdown predicted by computer models of climate change, the main author ... said in an interview. ...',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-256429',
#    'evidence-631149',
#    'evidence-58727',
#    'evidence-930557',
#    'evidence-371418',
#    'evidence-856340']},
#  'claim-1567': {'claim_text': 'IPCC overestimate temperature rise.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-414679',
#    'evidence-105184',
#    'evidence-91875',
#    'evidence-134319',
#    'evidence-671598',
#    'evidence-978388']},
#  'claim-1834': {'claim_text': 'A 14 August 1912 article from a New Zealand newspaper contained a brief story about how burning coal might produce future warming by adding carbon dioxide to the atmosphere.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-204109',
#    'evidence-648136',
#    'evidence-398684',
#    'evidence-484169',
#    'evidence-378218',
#    'evidence-123982']},
#  'claim-856': {'claim_text': 'as the pathbreaking work by Rosamond Naylor and David Battisti has shown, the tropics are already too hot to efficiently grow grain, and those places where grain is produced today are already at optimal growing temperature — which means even a small warming will push them down the slope of declining productivity.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-225077',
#    'evidence-373989',
#    'evidence-692906',
#    'evidence-253388',
#    'evidence-693242',
#    'evidence-1166728']},
#  'claim-540': {'claim_text': 'The heatwave we now have in Europe is not something that was expected with just 1C of warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-556258',
#    'evidence-119750',
#    'evidence-1194725',
#    'evidence-353209',
#    'evidence-975260',
#    'evidence-1067217']},
#  'claim-757': {'claim_text': 'The grasslands, crops, forests and territorial waters of Australia absorb more carbon dioxide than Australia emits.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-94180',
#    'evidence-361103',
#    'evidence-90786',
#    'evidence-594324',
#    'evidence-845978',
#    'evidence-704357']},
#  'claim-1407': {'claim_text': '“In their award winning book, ‘Taken By Storm’ (2007), Canadian researchers Christopher Essex and Ross McKitrick explain: ‘Temperature is not an amount of something [like height or weight].',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-628711',
#    'evidence-607700',
#    'evidence-710700',
#    'evidence-62377',
#    'evidence-326055',
#    'evidence-530330']},
#  'claim-3070': {'claim_text': 'So this is a government which is proposing to put at risk our manufacturing industry, to penalise struggling families, to make a tough situation worse for millions of households right around Australia.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-222747',
#    'evidence-361179',
#    'evidence-100483',
#    'evidence-630652',
#    'evidence-943783',
#    'evidence-639831']},
#  'claim-1745': {'claim_text': 'The IPCC simply updated their temperature history graphs to show the best data available at the time.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-911855',
#    'evidence-332770',
#    'evidence-157762',
#    'evidence-1052408',
#    'evidence-1197833',
#    'evidence-660105']},
#  'claim-1515': {'claim_text': 'no one really knows if last year 2016 was a global temperature record.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-64048',
#    'evidence-915569',
#    'evidence-169703',
#    'evidence-730599',
#    'evidence-413486',
#    'evidence-742898']},
#  'claim-1519': {'claim_text': 'The Earth’s climate is changing in response to increasing concentrations of greenhouse gases (GHGs) and particulate matter in the atmosphere, largely as the result of human activities.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-157024',
#    'evidence-645795',
#    'evidence-486230',
#    'evidence-336731',
#    'evidence-950186',
#    'evidence-452852']},
#  'claim-3069': {'claim_text': 'Continued greenhouse gas emissions at or above current rates would cause further warming and induce many changes in the global climate system during the 21st century that would very likely be larger than those observed during the 20th century.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-872435',
#    'evidence-886024',
#    'evidence-537761',
#    'evidence-213558',
#    'evidence-502506',
#    'evidence-885367']},
#  'claim-677': {'claim_text': '“Which is to say that these beans will be eaten by cows, and the cows will convert the beans to meat, and the humans will eat the meat.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-459277',
#    'evidence-584115',
#    'evidence-649672',
#    'evidence-102424',
#    'evidence-881957',
#    'evidence-853554']},
#  'claim-765': {'claim_text': 'The broader term covers changes beyond warmer temperatures, such as shifting rainfall patterns.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-496267',
#    'evidence-456747',
#    'evidence-90430',
#    'evidence-910921',
#    'evidence-698236',
#    'evidence-639155']},
#  'claim-2275': {'claim_text': '[…] Constant 24-7  media coverage of every significant storm worldwide just makes it seem  that way.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-193377',
#    'evidence-187588',
#    'evidence-940616',
#    'evidence-754084',
#    'evidence-237659',
#    'evidence-811255']},
#  'claim-1113': {'claim_text': 'This means the jet stream meanders more, with big loops bringing warm air to the frozen north and cold air into warmer southern climes.”',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-237848',
#    'evidence-730109',
#    'evidence-344052',
#    'evidence-574556',
#    'evidence-51503',
#    'evidence-67525']},
#  'claim-2611': {'claim_text': 'The final amount of extra CO2 that remains in the atmosphere stays there on a time scale of centuries.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-633102',
#    'evidence-924898',
#    'evidence-452442',
#    'evidence-183305',
#    'evidence-919978',
#    'evidence-764245']},
#  'claim-2060': {'claim_text': 'Global warming is causing more hurricanes and stronger hurricanes.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-371271',
#    'evidence-659643',
#    'evidence-104877',
#    'evidence-72465',
#    'evidence-425767',
#    'evidence-635291']},
#  'claim-2326': {'claim_text': '"In 2007, the Northern Hemisphere reached a record low in ice coverage and the Northwest Passage was opened.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-350262',
#    'evidence-1017927',
#    'evidence-56486',
#    'evidence-314560',
#    'evidence-1079662',
#    'evidence-29644']},
#  'claim-1087': {'claim_text': 'The particular signature of warming in 2016 was also revealing in another way, Overpeck said, noting that the stratosphere… saw record cold temperatures last year',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-410154',
#    'evidence-440064',
#    'evidence-640137',
#    'evidence-887434',
#    'evidence-664805',
#    'evidence-313130']},
#  'claim-2867': {'claim_text': "Skeptics who oppose scientific findings that threaten their world view are far closer to Galileo's belief-based critics in the Catholic Church.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1091064',
#    'evidence-146541',
#    'evidence-889014',
#    'evidence-828832',
#    'evidence-4648',
#    'evidence-847727']},
#  'claim-2300': {'claim_text': '"Austria is today seeing its earliest snowfall in history with 30 to 40 centimetres already predicted in the mountains.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-877231',
#    'evidence-28091',
#    'evidence-74794',
#    'evidence-316930',
#    'evidence-565182',
#    'evidence-208322']},
#  'claim-2250': {'claim_text': "Some global warming 'skeptics' argue that the Earth's climate sensitivity is so low that a doubling of atmospheric CO2 will result in a surface temperature change on the order of 1°C or less, and that therefore global warming is nothing to worry about.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-902603',
#    'evidence-539145',
#    'evidence-896310',
#    'evidence-502147',
#    'evidence-238211',
#    'evidence-588066']},
#  'claim-2429': {'claim_text': 'With 32 years of  rapidly increasing global temperatures and only a minor increase in  global CO2 emissions, followed by 33 years of slowly cooling global  temperatures with rapid increases in global CO2 emissions, it was  deceitful for the IPCC to make any claim that CO2 emissions were  primarily responsible for observed 20th century global warming."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-655523',
#    'evidence-286520',
#    'evidence-225292',
#    'evidence-471196',
#    'evidence-231661',
#    'evidence-375283']},
#  'claim-3051': {'claim_text': 'Once natural influences, in particular the impact of El Niño and La Niña, are removed from the recent termperature record, there is no evidence of a significant change in the human contribution to climate change.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-901697',
#    'evidence-983323',
#    'evidence-36099',
#    'evidence-370421',
#    'evidence-881808',
#    'evidence-338219']},
#  'claim-1549': {'claim_text': "There's no empirical evidence for climate change.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-169834',
#    'evidence-554798',
#    'evidence-296593',
#    'evidence-765573',
#    'evidence-544825',
#    'evidence-718856']},
#  'claim-261': {'claim_text': 'in 1995 one scientist at the IPCC – Jonathan Overpeck – wrote an email to a colleague claiming ‘we have to get rid of the Medieval Warm Period.’',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-974202',
#    'evidence-779369',
#    'evidence-112875',
#    'evidence-32121',
#    'evidence-33543',
#    'evidence-332770']},
#  'claim-2230': {'claim_text': '[Ice] is expanding in much of Antarctica, contrary to the widespread public belief that global warming is melting the continental ice cap.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-180701',
#    'evidence-629114',
#    'evidence-218585',
#    'evidence-239930',
#    'evidence-1170460',
#    'evidence-728645']},
#  'claim-2579': {'claim_text': 'Over the past 250 years, humans have added just one part of CO2 in 10,000 to the atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-788947',
#    'evidence-279895',
#    'evidence-775332',
#    'evidence-564899',
#    'evidence-161989',
#    'evidence-841142']},
#  'claim-1416': {'claim_text': 'In recent decades this warming has been accompanied by a constant rise in the sea level and, it would appear, by an increase of extreme weather events, even if a scientifically determinable cause cannot be assigned to each particular phenomenon.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-456747',
#    'evidence-547510',
#    'evidence-880592',
#    'evidence-132415',
#    'evidence-1091550',
#    'evidence-891619']},
#  'claim-2497': {'claim_text': "Without the forests' humidity, previously moisture-laden winds blew dry.",
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-901486',
#    'evidence-811866',
#    'evidence-696009',
#    'evidence-193642',
#    'evidence-835230',
#    'evidence-482305']},
#  'claim-811': {'claim_text': 'But [climate scientists] say that aspects of the case of Hurricane Harvey—and the recent history of tropical cyclones worldwide—suggest global warming is making a bad situation worse.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803283',
#    'evidence-604477',
#    'evidence-1055682',
#    'evidence-879500',
#    'evidence-759337',
#    'evidence-1047356']},
#  'claim-1896': {'claim_text': 'Greg Hunt CSIRO research shows carbon emissions can be reduced by 20 per cent over 40 years using nature, soils and trees.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1111240',
#    'evidence-305800',
#    'evidence-234076',
#    'evidence-31034',
#    'evidence-108068',
#    'evidence-798121']},
#  'claim-2819': {'claim_text': 'More importantly, the OISM list only contains 39 scientists who specialise in climate science.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-993564',
#    'evidence-319550',
#    'evidence-596256',
#    'evidence-970026',
#    'evidence-430458',
#    'evidence-139329']},
#  'claim-2643': {'claim_text': 'The "decline" refers to a decline in northern tree-rings, not global temperature, and is openly discussed in papers and the IPCC reports.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-862502',
#    'evidence-257200',
#    'evidence-105640',
#    'evidence-42552',
#    'evidence-610833',
#    'evidence-869984']},
#  'claim-1775': {'claim_text': 'Venus very likely underwent a runaway or ‘moist’ greenhouse phase earlier in its history, and today is kept hot by a dense CO2 atmosphere.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-496996',
#    'evidence-520532',
#    'evidence-1043526',
#    'evidence-721610',
#    'evidence-246506',
#    'evidence-276265']},
#  'claim-316': {'claim_text': 'the models predicted seven times as much warming as has been observed',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-699501',
#    'evidence-21670',
#    'evidence-78142',
#    'evidence-65623',
#    'evidence-83212',
#    'evidence-204252']},
#  'claim-896': {'claim_text': 'According to the WHO, exposure to particulate matter increases the risk of acute lower respiratory infection, chronic obstructive pulmonary disease, heart disease, stroke and lung cancer.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-534239',
#    'evidence-634143',
#    'evidence-416776',
#    'evidence-841530',
#    'evidence-602546',
#    'evidence-1171424']},
#  'claim-331': {'claim_text': 'But each serial adjustment has tended to make the early years colder, which increases the warming trend.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-424273',
#    'evidence-584709',
#    'evidence-1189271',
#    'evidence-311416',
#    'evidence-89933',
#    'evidence-561696']},
#  'claim-2574': {'claim_text': 'On a world scale coral reefs are in decline.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-369389',
#    'evidence-292123',
#    'evidence-580567',
#    'evidence-886566',
#    'evidence-23773',
#    'evidence-877088']},
#  'claim-342': {'claim_text': 'While members of the media may nod along to such claims [about changes in weather extremes], the evidence paints a different story',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-666732',
#    'evidence-223728',
#    'evidence-348042',
#    'evidence-13971',
#    'evidence-67867',
#    'evidence-718366']},
#  'claim-2034': {'claim_text': 'Latest IPCC Reports (AR5) have shown global mean temperature forecasts from the 2005 IPCC report exceeded actual readings.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-65986',
#    'evidence-780535',
#    'evidence-493978',
#    'evidence-68736',
#    'evidence-59672',
#    'evidence-967526']},
#  'claim-578': {'claim_text': '‘If we do nothing to reduce our greenhouse gas emissions, the kind of extreme heat we saw this past summer will be the norm when my young son is a grown man.’',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-96545',
#    'evidence-276264',
#    'evidence-758685',
#    'evidence-502687',
#    'evidence-254966',
#    'evidence-702079']},
#  'claim-976': {'claim_text': 'The gas builds up in the soil, forming mounds called ‘pingoes.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-601596',
#    'evidence-96150',
#    'evidence-425986',
#    'evidence-703000',
#    'evidence-896915',
#    'evidence-905237']},
#  'claim-1097': {'claim_text': '“[…]The impact on calcification, metabolism, growth, fertility and survival of calcifying marine species when pH is lowered up to 0.3 units […] is beneficial, not damaging.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-318920',
#    'evidence-665938',
#    'evidence-38518',
#    'evidence-767948',
#    'evidence-251823',
#    'evidence-490971']},
#  'claim-609': {'claim_text': 'That’s because as Antarctica’s mass shrinks, the ice sheet’s gravitational pull on the ocean relaxes somewhat, and the seas travel back across the globe to pile up far away — with U.S. coasts being one prime destination.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-6873',
#    'evidence-108943',
#    'evidence-790170',
#    'evidence-100670',
#    'evidence-995766',
#    'evidence-987736']},
#  'claim-173': {'claim_text': 'If there were [carbon emissions], we could not see because most carbon is black.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-571067',
#    'evidence-300735',
#    'evidence-354106',
#    'evidence-993484',
#    'evidence-90250',
#    'evidence-143922']},
#  'claim-1222': {'claim_text': 'The melting Greenland ice sheet is already a major contributor to rising sea level and if it was eventually lost entirely, the oceans would rise by six metres around the world, flooding many of the world’s largest cities.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-209596',
#    'evidence-173281',
#    'evidence-253707',
#    'evidence-180250',
#    'evidence-856068',
#    'evidence-952525']},
#  'claim-2441': {'claim_text': 'Furthermore, it is physically incorrect to state that the planet is simply "recovering" from the Little Ice Age.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-5671',
#    'evidence-846291',
#    'evidence-14712',
#    'evidence-902650',
#    'evidence-712754',
#    'evidence-81574']},
#  'claim-756': {'claim_text': 'Australia’s signed a suicide note [with the Paris Accord] yet didn’t seem to notice that China, India, Indonesia and the US did not commit to reducing their large carbon dioxide emissions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-949054',
#    'evidence-180274',
#    'evidence-719544',
#    'evidence-901598',
#    'evidence-229230',
#    'evidence-63356']},
#  'claim-2577': {'claim_text': '"Three recent articles give us reason to question the alarmists’ claims  that coral reefs are in deep trouble due to the buildup of greenhouse  gases." (World Climate Report)',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-338219',
#    'evidence-430587',
#    'evidence-663642',
#    'evidence-469998',
#    'evidence-125157',
#    'evidence-511848']},
#  'claim-2890': {'claim_text': 'Heat is continuing to build up in the subsurface ocean.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-674318',
#    'evidence-71710',
#    'evidence-131135',
#    'evidence-280195',
#    'evidence-942555',
#    'evidence-17082']},
#  'claim-2478': {'claim_text': '(Kerr 2007) points out that the sunlight-reflecting haze that cools much of the planet seems to have thinned over the past decade or so.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-220532',
#    'evidence-624376',
#    'evidence-878079',
#    'evidence-553468',
#    'evidence-214975',
#    'evidence-531101']},
#  'claim-2399': {'claim_text': 'While the greenhouse effect is a natural occurence, too much warming has severe negative impacts on agriculture, health and environment.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-675493',
#    'evidence-1122962',
#    'evidence-102573',
#    'evidence-298450',
#    'evidence-600353',
#    'evidence-892059']},
#  'claim-3091': {'claim_text': 'Global Warming history completely coincides with the history of artificial satellites and the use of microwave frequencies from outer space.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-361047',
#    'evidence-866933',
#    'evidence-927151',
#    'evidence-917344',
#    'evidence-712474',
#    'evidence-520355']},
#  'claim-141': {'claim_text': 'Greenpeace didn’t save the whales, switching from whale oil to petroleum and palm oil did',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1025353',
#    'evidence-784155',
#    'evidence-917144',
#    'evidence-281721',
#    'evidence-951392',
#    'evidence-426684']},
#  'claim-1933': {'claim_text': 'Newt Gingrich "teamed with Nancy Pelosi and Al Gore on global warming."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-837633',
#    'evidence-547006',
#    'evidence-728459',
#    'evidence-511503',
#    'evidence-414843',
#    'evidence-571174']},
#  'claim-1689': {'claim_text': 'Evidence is building that net cloud feedback is likely positive and unlikely to be strongly negative.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-354365',
#    'evidence-53156',
#    'evidence-171243',
#    'evidence-283777',
#    'evidence-493500',
#    'evidence-943059']},
#  'claim-443': {'claim_text': '“Today climate scientists are obsessed with the level of carbon dioxide in the atmosphere, a very very small part of the overall picture.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-630220',
#    'evidence-635485',
#    'evidence-233814',
#    'evidence-495643',
#    'evidence-638515',
#    'evidence-555729']},
#  'claim-2037': {'claim_text': 'The rate of renewable energy installations in the EU in 2018 was less than half the maximum level achieved in 2010.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-90731',
#    'evidence-268009',
#    'evidence-1113929',
#    'evidence-1065009',
#    'evidence-591615',
#    'evidence-363747']},
#  'claim-1734': {'claim_text': 'Jim Hansen had several possible scenarios; his mid-level scenario B was right.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-901245',
#    'evidence-485896',
#    'evidence-147653',
#    'evidence-210167',
#    'evidence-375730',
#    'evidence-1005240']},
#  'claim-2093': {'claim_text': 'Through its impacts on the climate, CO2 presents a danger to public health and welfare, and thus qualifies as an air pollutant',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-209895',
#    'evidence-743065',
#    'evidence-411598',
#    'evidence-152535',
#    'evidence-67446',
#    'evidence-130914']},
#  'claim-1400': {'claim_text': 'The late 1970s marked the end of a 30-year cooling trend.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-322447',
#    'evidence-747929',
#    'evidence-578002',
#    'evidence-801782',
#    'evidence-803471',
#    'evidence-502252']},
#  'claim-1638': {'claim_text': 'Worry about global warming impacts in the next 100 years, not an ice age in over 10,000 years.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-142343',
#    'evidence-1016625',
#    'evidence-679756',
#    'evidence-954212',
#    'evidence-97844',
#    'evidence-382313']},
#  'claim-3075': {'claim_text': "Multiple lines of evidence indicate Greenland's ice loss is accelerating and will contribute sea level rise in the order of metres over the next few centuries.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-589436',
#    'evidence-824381',
#    'evidence-163577',
#    'evidence-151655',
#    'evidence-391045',
#    'evidence-432788']},
#  'claim-38': {'claim_text': 'Scientists studying Antarctica sea ice warn a rise in accumulation could spark the next ice age.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-9303',
#    'evidence-298676',
#    'evidence-965272',
#    'evidence-119441',
#    'evidence-591257',
#    'evidence-783228']},
#  'claim-1643': {'claim_text': "Al Gore's book is quite accurate, and far more accurate than contrarian books.",
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-815912',
#    'evidence-19239',
#    'evidence-1033955',
#    'evidence-727826',
#    'evidence-1087633',
#    'evidence-472745']},
#  'claim-1259': {'claim_text': 'While the north-east, midwest and upper great plains have experienced a 30% increase in heavy rainfall episodes – considered once-in-every-five year downpours – parts of the west, particularly California, have been parched by drought.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-443760',
#    'evidence-275334',
#    'evidence-17722',
#    'evidence-815669',
#    'evidence-948853',
#    'evidence-1023411']},
#  'claim-1605': {'claim_text': 'Scientists retracted claim that sea levels are rising.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-470318',
#    'evidence-1121998',
#    'evidence-538657',
#    'evidence-314164',
#    'evidence-65079',
#    'evidence-129859']},
#  'claim-1711': {'claim_text': "Global warming' and 'climate change' mean different things and have both been used for decades.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-877555',
#    'evidence-582165',
#    'evidence-266898',
#    'evidence-258984',
#    'evidence-887354',
#    'evidence-540766']},
#  'claim-2236': {'claim_text': 'The majority of peer reviewed research at the time predicted warming due to increasing CO2.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-711131',
#    'evidence-895528',
#    'evidence-640385',
#    'evidence-956005',
#    'evidence-976285',
#    'evidence-369547']},
#  'claim-1040': {'claim_text': 'While evidence that the earth’s orbital variations impact radiation levels and thus global temperatures does not of course mean that man is not in some way impacting the climate, studies like these highlight that the role man plays on the planet is dwarfed by natural phenomena utterly out of our control.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-999130',
#    'evidence-1137996',
#    'evidence-674177',
#    'evidence-1107482',
#    'evidence-550422',
#    'evidence-758876']},
#  'claim-392': {'claim_text': 'a study that totally debunks the whole concept of man-made Global Warming',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-846906',
#    'evidence-724010',
#    'evidence-140777',
#    'evidence-276612',
#    'evidence-1007867',
#    'evidence-421300']},
#  'claim-368': {'claim_text': 'The most recent IPCC report lays out a future if we limit global heating to 1.5°C instead of the Paris Agreement’s 2°C.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-994667',
#    'evidence-853312',
#    'evidence-639522',
#    'evidence-346319',
#    'evidence-46356',
#    'evidence-415394']},
#  'claim-559': {'claim_text': 'And there is a lot of evidence that climate change is diminishing biodiversity, which can be seen in these alpine meadows as well.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-942611',
#    'evidence-842213',
#    'evidence-187081',
#    'evidence-101187',
#    'evidence-109104',
#    'evidence-1047048']},
#  'claim-2583': {'claim_text': '"Each unit of CO2 you put into the atmosphere has less and less of a warming impact.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-827004',
#    'evidence-178206',
#    'evidence-293708',
#    'evidence-1099186',
#    'evidence-1169593',
#    'evidence-677057']},
#  'claim-2609': {'claim_text': 'Individual carbon dioxide molecules have a short life time of around 5 years in the atmosphere.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-938381',
#    'evidence-866703',
#    'evidence-128273',
#    'evidence-801956',
#    'evidence-185746',
#    'evidence-140101']},
#  'claim-492': {'claim_text': 'But like most claims regarding global warming, the real effect is small, probably temporary, and most likely due to natural weather patterns',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-915718',
#    'evidence-479999',
#    'evidence-816125',
#    'evidence-972954',
#    'evidence-896442',
#    'evidence-322647']},
#  'claim-1420': {'claim_text': 'Concentrated in the atmosphere, these gases do not allow the warmth of the sun’s rays reflected by the earth to be dispersed in space.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-858298',
#    'evidence-767961',
#    'evidence-1069448',
#    'evidence-854438',
#    'evidence-612568',
#    'evidence-60969']},
#  'claim-1089': {'claim_text': 'Last year’s warmth was manifested across the planet, from the warm tropical ocean waters off the coast of northeastern Australia, where the Great Barrier Reef experienced its worst coral bleaching event on record and large scale coral death, to the Arctic, where sea ice hit regular monthly record lows and overall temperatures were also the warmest on record, at least from January through September 2016.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-363828',
#    'evidence-217941',
#    'evidence-959367',
#    'evidence-353423',
#    'evidence-146197',
#    'evidence-212194']},
#  'claim-1467': {'claim_text': 'The amount of carbon dioxide absorbed by the upper layer of the oceans is increasing by about 2 billion tons per year.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-923136',
#    'evidence-498380',
#    'evidence-956954',
#    'evidence-459147',
#    'evidence-425667',
#    'evidence-257475']},
#  'claim-444': {'claim_text': 'Carbon dioxide is a trace gas.”',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-824568',
#    'evidence-1190705',
#    'evidence-537199',
#    'evidence-366108',
#    'evidence-693090',
#    'evidence-978247']},
#  'claim-803': {'claim_text': 'The team of climate scientists notes that in failing to predict the warming ‘hiatus’ in the beginning of the 21st century, the Intergovernmental Panel on Climate Change (IPCC) models overestimated temperature increases…',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-489796',
#    'evidence-210829',
#    'evidence-69455',
#    'evidence-143303',
#    'evidence-83393',
#    'evidence-774115']},
#  'claim-1668': {'claim_text': 'Thick arctic sea ice is in rapid retreat.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1200544',
#    'evidence-333657',
#    'evidence-304281',
#    'evidence-629116',
#    'evidence-941002',
#    'evidence-448709']},
#  'claim-742': {'claim_text': 'Global human emissions are only 3 per cent of total annual emissions.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-862659',
#    'evidence-556098',
#    'evidence-976297',
#    'evidence-197533',
#    'evidence-722106',
#    'evidence-203712']},
#  'claim-846': {'claim_text': 'In other words, we have, trapped in Arctic permafrost, twice as much carbon as is currently wrecking the atmosphere of the planet, all of it scheduled to be released at a date that keeps getting moved up, partially in the form of a gas that multiplies its warming power 86 times over.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1173602',
#    'evidence-94074',
#    'evidence-113250',
#    'evidence-830010',
#    'evidence-657424',
#    'evidence-769821']},
#  'claim-2119': {'claim_text': 'Lindzen and Choi find low climate sensitivity',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-404224',
#    'evidence-398190',
#    'evidence-751912',
#    'evidence-775818',
#    'evidence-363922',
#    'evidence-127999']},
#  'claim-1167': {'claim_text': 'Lake-bottom sediments in Florida tell us that recent major hurricane activity in the Gulf of Mexico has been less frequent than in centuries past.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-525133',
#    'evidence-596895',
#    'evidence-354936',
#    'evidence-54964',
#    'evidence-381188',
#    'evidence-502576']},
#  'claim-623': {'claim_text': 'The noted oceanographer Walter Munk referred to sea-level rise as an “enigma”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-57577',
#    'evidence-552663',
#    'evidence-440061',
#    'evidence-177061',
#    'evidence-448067',
#    'evidence-103712']},
#  'claim-2882': {'claim_text': 'Trenberth\'s views are clarified in the paper "An imperative for climate change planning: tracking Earth\'s global energy".',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-966770',
#    'evidence-434034',
#    'evidence-300041',
#    'evidence-132780',
#    'evidence-698169',
#    'evidence-604289']},
#  'claim-1698': {'claim_text': 'Around 97% of climate experts agree that humans are causing global warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-797793',
#    'evidence-135073',
#    'evidence-7957',
#    'evidence-784893',
#    'evidence-503460',
#    'evidence-50032']},
#  'claim-181': {'claim_text': 'Reefs need carbon dioxide; it’s their basic food.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-950574',
#    'evidence-798748',
#    'evidence-853121',
#    'evidence-725077',
#    'evidence-787011',
#    'evidence-434427']},
#  'claim-281': {'claim_text': 'In an interview with the BBC after the scandal broke, Dr Jones admitted there had been no statistically significant global warming since 1995',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-18549',
#    'evidence-910914',
#    'evidence-509654',
#    'evidence-298772',
#    'evidence-816986',
#    'evidence-2559']},
#  'claim-2809': {'claim_text': 'The motions of the massive oceans where heat is moved between deep layers and the surface provides variability on time scales from years to centuries.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-115088',
#    'evidence-812524',
#    'evidence-383714',
#    'evidence-822101',
#    'evidence-94747',
#    'evidence-700017']},
#  'claim-1928': {'claim_text': 'NASA Finds Antarctica is Gaining Ice,',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-106927',
#    'evidence-971839',
#    'evidence-961610',
#    'evidence-529248',
#    'evidence-407574',
#    'evidence-1099128']},
#  'claim-2787': {'claim_text': "Hansen's 1988 results are evidence that the actual climate sensitivity is about 3°C for a doubling of atmospheric CO2.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-500298',
#    'evidence-36278',
#    'evidence-304156',
#    'evidence-917793',
#    'evidence-632574',
#    'evidence-692256']},
#  'claim-478': {'claim_text': 'Protecting and restoring forests would reduce 18% of emissions by 2030',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-890810',
#    'evidence-594952',
#    'evidence-609211',
#    'evidence-981805',
#    'evidence-347403',
#    'evidence-123562']},
#  'claim-988': {'claim_text': 'The unlikely scenarios are now, all of a sudden, becoming more probable than they once were thought to be,’ says Sweet.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-647897',
#    'evidence-44133',
#    'evidence-43593',
#    'evidence-563099',
#    'evidence-459314',
#    'evidence-711659']},
#  'claim-266': {'claim_text': 'The IPCC no longer includes the ‘Hockey stick’ chart in its reports.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-685512',
#    'evidence-327755',
#    'evidence-971301',
#    'evidence-281372',
#    'evidence-102834',
#    'evidence-602385']},
#  'claim-2282': {'claim_text': 'While there are isolated cases of growing glaciers, the overwhelming trend in glaciers worldwide is retreat.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-820477',
#    'evidence-144396',
#    'evidence-683849',
#    'evidence-744640',
#    'evidence-635991',
#    'evidence-788556']},
#  'claim-2895': {'claim_text': 'The latest  measurements involve the use of satellite gravimetry, estimating  the mass of terrain beneath by detecting slight changes in gravity as a  satellite passes overhead.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-179123',
#    'evidence-213629',
#    'evidence-286825',
#    'evidence-81511',
#    'evidence-156924',
#    'evidence-658048']},
#  'claim-349': {'claim_text': 'Nor is there evidence of an increase in floods globally.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-673572',
#    'evidence-104767',
#    'evidence-997924',
#    'evidence-636631',
#    'evidence-240950',
#    'evidence-323541']},
#  'claim-2101': {'claim_text': 'Clouds provide negative feedback',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-679595',
#    'evidence-640259',
#    'evidence-647027',
#    'evidence-754876',
#    'evidence-989211',
#    'evidence-679588']},
#  'claim-897': {'claim_text': 'The report […] found that the United States was one of the most pollution-free nations in the world.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-676258',
#    'evidence-783786',
#    'evidence-970636',
#    'evidence-663031',
#    'evidence-746019',
#    'evidence-221041']},
#  'claim-3063': {'claim_text': "'Another global warming myth comes crashing down.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-139227',
#    'evidence-780841',
#    'evidence-604459',
#    'evidence-240527',
#    'evidence-604195',
#    'evidence-465864']},
#  'claim-386': {'claim_text': 'Renew\xadables such as wind turbines are environmentally disastrous because they pollute a huge land area, slice and dice birds and bats, kill insects that are bird food, create health problems for humans who live within kilometres of them, leave toxins around the turbine site and despoil the landscape.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-346547',
#    'evidence-198732',
#    'evidence-624457',
#    'evidence-585204',
#    'evidence-684551',
#    'evidence-365456']},
#  'claim-2691': {'claim_text': "There are a myriad of other radiative forcings that affect the planet's energy imbalance.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1190716',
#    'evidence-420830',
#    'evidence-1106814',
#    'evidence-968110',
#    'evidence-814421',
#    'evidence-2462']},
#  'claim-530': {'claim_text': 'South Australia is winning: it has the most unreliable grid in the world outside Africa and the most expensive electricity.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-574843',
#    'evidence-396641',
#    'evidence-15879',
#    'evidence-67732',
#    'evidence-152925',
#    'evidence-438083']},
#  'claim-2979': {'claim_text': 'Water vapor helps trap heat, and is a far the strongest of the major greenhouse gases, contributing 36–72 percent of the greenhouse effect.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-306908',
#    'evidence-706949',
#    'evidence-104290',
#    'evidence-785159',
#    'evidence-572837',
#    'evidence-168029']},
#  'claim-665': {'claim_text': 'many scientists were surprised when other researchers subsequently found that ringed and bearded seals (the primary prey of polar bears) north of the Bering Strait especially thrived with a longer open-water season, which is particularly conducive to fishing',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-984463',
#    'evidence-114740',
#    'evidence-739796',
#    'evidence-785530',
#    'evidence-230868',
#    'evidence-751236']},
#  'claim-199': {'claim_text': 'In the past, warming has never been a threat to life on Earth.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-402399',
#    'evidence-610285',
#    'evidence-255653',
#    'evidence-117471',
#    'evidence-817833',
#    'evidence-886577']},
#  'claim-490': {'claim_text': 'IPCC report warning last week the world is “nowhere near on track” to meet its Paris commitments',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-225934',
#    'evidence-432573',
#    'evidence-25536',
#    'evidence-70949',
#    'evidence-529593',
#    'evidence-238003']},
#  'claim-2400': {'claim_text': '\'To suddenly label CO2 as a "pollutant" is a disservice to a gas that has played an enormous role in the development and sustainability of all life on this wonderful Earth.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1022738',
#    'evidence-852573',
#    'evidence-409365',
#    'evidence-127519',
#    'evidence-107077',
#    'evidence-553485']},
#  'claim-204': {'claim_text': 'after a natural orbitally driven warming, atmospheric carbon dioxide content increases 800 years later',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-30998',
#    'evidence-926717',
#    'evidence-922929',
#    'evidence-604578',
#    'evidence-75032',
#    'evidence-507551']},
#  'claim-1426': {'claim_text': 'Many of the world’s coral reefs are already barren or in a state of constant decline.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-293637',
#    'evidence-305944',
#    'evidence-3651',
#    'evidence-858908',
#    'evidence-221453',
#    'evidence-962337']},
#  'claim-698': {'claim_text': 'A recent study led by Lawrence Livermore National Laboratory climate scientist Ben Santer found that while the models ran hot, the ‘overestimation’ was ‘partly due to systematic deficiencies in some of the post-2000 external forcings used in the model simulations.’',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-519720',
#    'evidence-445144',
#    'evidence-828753',
#    'evidence-69023',
#    'evidence-656835',
#    'evidence-441331']},
#  'claim-1021': {'claim_text': 'The corals may save themselves, as many other creatures are attempting to do, by moving toward the poles as the Earth warms, establishing new reefs in cooler water.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-128925',
#    'evidence-766771',
#    'evidence-810332',
#    'evidence-646030',
#    'evidence-683145',
#    'evidence-1175280']}}

# %%
len(dev_claims_baseline)
# Out:
# 154

# %% [markdown]
# ### Have a look at structure of evidence and how many there are

# %%
evidence
# Out:
# {'evidence-0': 'John Bennet Lawes, English entrepreneur and agricultural scientist',
#  'evidence-1': 'Lindberg began his professional career at the age of 16, eventually moving to New York City in 1977.',
#  'evidence-2': "``Boston (Ladies of Cambridge)'' by Vampire Weekend",
#  'evidence-3': 'Gerald Francis Goyer (born October 20, 1936) was a professional ice hockey player who played 40 games in the National Hockey League.',
#  'evidence-4': 'He detected abnormalities of oxytocinergic function in schizoaffective mania, post-partum psychosis and how ECT modified oxytocin release.',
#  'evidence-5': 'With peak winds of 110 mph (175 km/h) and a minimum pressure of 972 mbar (hPa ; 28.71 inHg), Florence was the strongest storm of the 1994 Atlantic hurricane season.',
#  'evidence-6': 'He is currently a professor of piano at the University of Wisconsin -- Madison since August 2000.',
#  'evidence-7': 'In addition to known and tangible risks, unforeseeable black swan extinction events may occur, presenting an additional methodological problem.',
#  'evidence-8': 'Sir John Sherbrooke was able to hold her off for some five hours until Robson suffered a severe wound that almost killed him.',
#  'evidence-9': 'Aslan Tlebzu (Аслъан ЛIыбзэу [- adyaːsɬaːn ɬʼəbzaw], Russian : Аслан Тлебзу), born 24 February 1981, Teuchezhsk, Adygea, USSR ; is a Russian Adyghe folk musician.',
#  'evidence-10': 'Matroid duals go back to the original paper by Hassler Whitney defining matroids.',
#  'evidence-11': 'Associazioni, nomi e numeri contro le mafie, Italian association against mafias',
#  'evidence-12': 'He is the current AIDA Individual World Champion Constant Weight (September 2005).',
#  'evidence-13': 'His forced recusal from the case brought by the widow of Giuseppe Pinelli against the police commissioner Luigi Calabresi in 1971 became a cause célèbre.',
#  'evidence-14': "The war was possibly the single most important event in the Blake 's 7 series, shifting the series emphasis and seeing the largest turnover in the cast.",
#  'evidence-15': 'When employees click on something in their computers, the criminals get access to the computers.',
#  'evidence-16': 'He is best known as author of The Prize : The Epic Quest for Oil, Money, and Power (1991) and The Quest : Energy, Security, and the Remaking of the Modern World (2011).',
#  'evidence-17': 'Yoper Linux -- Your Operating System -- was a Linux distribution for PCs with i686 (Pentium Pro) or higher processor types.',
#  'evidence-18': 'Formally, Contact Improvisation is a movement improvisation mainly explored in duets.',
#  'evidence-19': "The Academic Chronicle (Московско-Академическая летопись, Moskovskaya akademicheskaya letopis) or Suzdal ' Chronicle (Суздальская летопись, Suzdalskaya Letopis) is a late 15th-century compilation of other Russian-language chronicles.",
#  'evidence-20': 'Diéouzon was a commune until March 2012, when it became one of 1126 communes nationwide that were abolished.',
#  'evidence-21': 'People who live in slums or informal settlements often have minimal or no access to education, healthcare, or the urban economy.',
#  'evidence-22': 'Jason Barnard is a Search engine marketing consultant, musician, cartoon-maker, and voice actor.',
#  'evidence-23': 'It did not chart in the United States, despite receiving airplay in several markets.',
#  'evidence-24': 'TRAF proteins connect IL-1R / Toll and TNF receptors with signaling factors that lead to the activation of NF-κB and mitogen-activated protein kinases.',
#  'evidence-25': 'Enosmaeus cubanus is a species of beetle in the family Cerambycidae, the only species in the genus Enosmaeus.',
#  'evidence-26': 'I Shall Never Return is available in English on the Internet from the Netcomics publisher.',
#  'evidence-27': 'At the 2006 census, its population was 27, in 4 families.',
#  'evidence-28': 'In the area of mathematical logic and computer science known as type theory, a type constructor is a feature of a typed formal language that builds new types from old ones.',
#  'evidence-29': 'Christopher Paul Stebbings MBE is an actor and the artistic director of TNT music theatre and The American Drama Group Europe.',
#  'evidence-30': "The Spain men 's national volleyball team is the national team of Spain.",
#  'evidence-31': 'Hama Bridge (Sancha Zijin), Heicheng Village, Hebei, China',
#  'evidence-32': 'Many reports influence policy decisions; some are instrumental in enabling new research programs; others provide independent program reviews.',
#  'evidence-33': "``Calypso'' is a song written by John Denver in 1975 as a tribute to Jacques-Yves Cousteau and his research ship, the Calypso.",
#  'evidence-34': 'Fires started by lightning can burn down Foxtail Grass, but the grass has roots underground that allow it to grow back.',
#  'evidence-35': 'Jack Jumping, also known as Skibock in Europe, is an action sport that involves descending a slope that is covered with snow on a Jackjumper.',
#  'evidence-36': 'Zygmuntów [zyg ` muntuf] is a village in the administrative district of Gmina Fałków, within Końskie County, Świętokrzyskie Voivodeship, in south-central Poland.',
#  'evidence-37': 'The results of the 2008 Little League World Series were determined between August 15 and August 24, 2008 in South Williamsport, Pennsylvania.',
#  'evidence-38': "Being a national law of the People 's Republic of China, the Basic Law was adopted on 4 April 1990 by the Seventh National People 's Congress and signed by President Yang Shangkun.",
#  'evidence-39': 'Some Italian motorcycle manufacturers, seeing their production fall due to the availability of low-cost utility cars, decided to enter the light motorcycle sector, creating economical models equipped with refined and robust four-stroke engines.',
#  'evidence-40': "It was built between 1922 and 1932 to house the Army Medical School, which became the Army Medical Center in 1923 when it -- under the name ``Medical Department Professional Service School'' (MDPSS) -- combined with the Walter Reed General Hospital.",
#  'evidence-41': 'European explorers were sent deep into the interior, discovering some pastoral land but mainly large tracts of desert terrain.',
#  'evidence-42': "The historical costume drama, the western and the war film had filled Fox 's production schedule and this all-black musical drama based on an established and popular opera would surely be a box-office success, as proved true.",
#  'evidence-43': 'Some of the key products including Freezer, Accelero, Alpine, Fusion and Silentium series are registered trademarks in the EU and the US.',
#  'evidence-44': "Michael ``Micky'' Block (born 28 January 1940) is an English former professional footballer who played as a right winger.",
#  'evidence-45': 'Even though Maltese is one of the national languages spoken by the people of the island, the young artists representing Malta have always chosen to sing in English hoping that this would grant them a better placing.',
#  'evidence-46': "The band made a hit recording with Marjorie Hughes on the vocal, entitled ``Oh, What It Seemed To Be.''",
#  'evidence-47': 'She was the daughter of Greek -- Syrian King Antiochus VIII Grypus and Greek Ptolemaic Princess Cleopatra Tryphaena (see Cleopatra VI of Egypt), a daughter of Ptolemy VIII Physcon.',
#  'evidence-48': "The stela 's findspot in an ancient source suggests that she is a water goddess.",
#  'evidence-49': "In 2000, the event was renamed ``Administrative Professionals Week'' to recognize people working in the administrative support field with other job titles such as receptionist, office manager, executive assistant, administrative coordinator, or administrative assistant.",
#  'evidence-50': 'There are 13 properties and districts listed on the National Register in the county.',
#  'evidence-51': 'Kjeld Toft-Christensen (born 10 March 1910 - died 27 November 1945) MC was a Special Operations Executive officer and Danish resistance fighter during the Second World War.',
#  'evidence-52': 'He is the founder of The Institute for Molecular Medicine at California, and he serves as the President, Chief Scientific Officer and Emeritus Professor of Molecular Pathology.',
#  'evidence-53': 'Jagger said at the time of its release, ``I had made out a very honest burden of mind before everyone had arrived one night.',
#  'evidence-54': "He is currently afternoon co-host (with Joe D'Ambrosio) on WTIC in Hartford, Connecticut.",
#  'evidence-55': 'In his Habilitation à diriger les recherches Lambda-Prolog de A à Z..',
#  'evidence-56': 'The term originates with the London Underground ; such layouts exist in other networks but are not commonly so named.',
#  'evidence-57': 'These issues are edited by a guest editor who is a specialist in their field.',
#  'evidence-58': 'Ilir Avdyli (born 20 May 1990) is an Albanian footballer who currently plays as an Goalkeeper for KF Tirana in the Albanian Superliga.',
#  'evidence-59': "The technique is often applied to pancreatic cysts, pilonidal cysts, and Bartholin 's cysts.",
#  'evidence-60': 'Thousands of prisoners were taken, and the Italian garrison now held out only in the northern and southernmost parts of the fortress.',
#  'evidence-61': 'KDIF-LP, a low-power radio station (102.9 FM) licensed to serve Phoenix, Arizona, United States',
#  'evidence-62': 'He is a member of the United States Hockey Hall of Fame.',
#  'evidence-63': 'Alan Ray Hacker OBE FRAM (30 September 1938 -- 16 April 2012) was an English clarinetist, conductor, and music professor.',
#  'evidence-64': 'It grows typically in warm, sheltered spots with moist soil.',
#  'evidence-65': 'In theory, these regions formed part of the greater Norwegian commonwealth.',
#  'evidence-66': 'Lower Machen (Machen Isaf) is a small hamlet of 19 houses on the A468 road at the very western edge of the city of Newport, South Wales.',
#  'evidence-67': 'Its current convener (2012-2016) is the Rev Sally Foster Fulton.',
#  'evidence-68': 'Vibia Sabina died before her husband, some time in 136 or early 137.',
#  'evidence-69': 'Its construction covers almost 100 years, mainly because of the lack of resources in the process, being strong impetus Mrs. Concepcion Sedas in its culmination in the year of 1950.',
#  'evidence-70': 'Silent Partner is a 2001 Australian film.',
#  'evidence-71': 'He generated 11 albums that combined electric and classical guitar but fell short of his long established goal of producing 30 albums during his lifetime.',
#  'evidence-72': "Famous works by Marioni include : ``One Second Sculpture'' 1969, ``The Act of Drinking Beer with Friends is the Highest Form of Art'' 1970",
#  'evidence-73': "He spent his childhood in Auckland and was educated at St Peter 's College.",
#  'evidence-74': 'However, as Crown Coach and Gillig both exited the school bus industry in the early 1990s, Thomas gained significant ground on the West Coast.',
#  'evidence-75': 'But, once working in securities law, she discovered she had a passion for it.',
#  'evidence-76': 'He studied physics at the California Institute of Technology.',
#  'evidence-77': 'Sine (album), a 2008 album by C418',
#  'evidence-78': 'A rework of the song was released in 2016 to celebrate its 20th anniversary.',
#  'evidence-79': 'Wainer also raised allegations of police corruption in protecting back-yard abortion rackets.',
#  'evidence-80': 'He is interred in Forest Park (Lawndale) Cemetery.',
#  'evidence-81': "Providence Regional Medical Center Everett, colloquially known as ``Prov Everett'', is a full-service medical center and the flagship hospital of Providence Health & Services, the largest faith-based healthcare system in the Northwestern United States.",
#  'evidence-82': 'Vytautas Vičiulis (October 16, 1951 in the Skuodas district -- March 3, 1989 in Klaipėda) was a Lithuanian painter and antiques restorer, better known for his self-immolation for political reasons.',
#  'evidence-83': "According to Evangelical theologian Charles C. Ryrie, modern liberal theology ``gives an exaggerated place to the abilities of people to decide their own fate and to effect their own salvation entirely apart from God 's grace.''",
#  'evidence-84': 'Pitchfork, a tool that farmers use to manually move hay',
#  'evidence-85': 'While living in Lithuania he completed pilot training.',
#  'evidence-86': 'Cecily Norden, South African author, horse judge, rider, and breeder',
#  'evidence-87': 'Giovanni Sala (born 23 November 1963) is an Italian enduro rider and a six-time World Enduro Champion (including the overall world championship title in 1998).',
#  'evidence-88': 'As an author and editor of many design books he is seen as a renowned expert on international design history.',
#  'evidence-89': 'Pollution produced from centralised generation of electricity is emitted at a distant power station, rather than "on site".',
#  'evidence-90': 'The same song was also used for the movie Casablanca in 1942.',
#  'evidence-91': "The actions, underway or being recommended, ranged from ``routine propaganda to lethal covert action in preparation for military attacks''.",
#  'evidence-92': 'It was formed by former Prime Minister Morihiro Hosokawa and four other legislators (Yoriko Madoka, Shinji Tarutoko, Kiyoshi Ueda and Takenori Emoto) who left the New Frontier Party in June 1997.',
#  'evidence-93': 'The original power station was built in 1915.',
#  'evidence-94': 'Although usually folksongs and classical choir songs are sung, with emphasis on a cappella singing, recently modern popular songs have been incorporated into the repertoire.',
#  'evidence-95': 'The magazine has since evolved into a monthly print and digital magazine.',
#  'evidence-96': 'BitTorrent trackers provide a list of files available for transfer, and allow the client to find peer users known as seeds who may transfer the files.',
#  'evidence-97': 'She is married to the English footballer and television pundit Jamie Redknapp.',
#  'evidence-98': 'Lavinia Agache, (born 1967), Romanian gymnast',
#  'evidence-99': 'Because it was later used to transport the dead from the Ljubljana hospital to the mortuary, it was nicknamed the Mortuary Bridge (Mrtvaški most), but has retained its beauty and technical perfection.',
#  'evidence-100': 'The sauce may be tomato-based, depending on where the Michigan is purchased.',
#  'evidence-101': 'Kaaterskill Falls (novel), a 1998 novel by Allegra Goodman',
#  'evidence-102': 'The increasing light pollution due to the growth of greater Los Angeles has limited the ability of the observatory to engage in deep space astronomy, but it remains a productive center, with the CHARA Array continuing important stellar research.',
#  'evidence-103': 'Aşk Kadın Ruhundan Anlamıyor is the third studio album by Turkish singer Hande Yener, first released on July 6, 2004 by Erol Köse Production.',
#  'evidence-104': 'All the homes in the neighbourhood are manufactured homes.',
#  'evidence-105': 'Blue Eyed is a 1996 documentary film by Bertram Verhaag in which Jane Elliott is teaching a workshop on racism.',
#  'evidence-106': 'Starring Jeetendra, Simple Kapadia in the lead roles and music composed by Rajesh Roshan.',
#  'evidence-107': 'His grandson Siddharth Tripathi is now carrying forward the legacy of his grandfather, he is member of BJP and active social worker.',
#  'evidence-108': 'At the time, it was known as the Year of the Consulship of Lascivius and Atilius (or, less frequently, year 938 Ab urbe condita).',
#  'evidence-109': 'This is a list of organizations for women in science and, more generally ; science, technology, engineering, and math.',
#  'evidence-110': 'She married into a distinguished family of London silversmiths.',
#  'evidence-111': "Freak Party made one demo ; an instrumental called ` Kraak Therapy ' in 1981.",
#  'evidence-112': 'Ingada sonja (Japanese : 因掲陀尊者) is one of the Sixteen Arhats or Rakan (Japanese : 十六羅漢, Juroku Rakan) of Buddhism, saintly men who were predecessors or disciples of the Buddha.',
#  'evidence-113': 'The Runner-up qualifies for the 2016 Copa Sudamericana.',
#  'evidence-114': 'Atong language (Grassfields Bantu), a Grassfields Bantu language of Cameroon',
#  'evidence-115': 'Chijoraji is the aboriginal Guanches name given to this representation of Christ.',
#  'evidence-116': 'In their first year under head coach Albert Barron, the Aggies compiled a 3 -- 5 record and were outscored by their opponents 126 to 68.',
#  'evidence-117': 'The Locusts, also known as the Peter Eltinge House, is a 19th-century brick Federal style house built in 1826 located on Plains Road in the Town of New Paltz, New York, United States, two miles (3 km) south of the village of New Paltz.',
#  'evidence-118': 'In 1928 he and his horse Pepita won the bronze medal in the individual jumping competition.',
#  'evidence-119': "This treaty came out of the Taif Agreement, which stipulated that ``Lebanon is linked to Syria by distinctive ties deriving strength from kinship, history, and common interests.''",
#  'evidence-120': "The word Sheriff evolved from ` shire-reeve '.",
#  'evidence-121': 'USS G-1 (SS-19 1/2) was the lead ship of her class of submarine of the United States Navy.',
#  'evidence-122': 'XHGBO-FM is a radio station on 92.1 FM in General Bravo, Nuevo León.',
#  'evidence-123': 'Cosby had been the target of a criminal sexual assault investigation in New York City in 2000, and was sued in 2005 by Temple University employee Andrea Constand over allegations that he drugged and assaulted her.',
#  'evidence-124': "The station is owned by Combined Communications and signed on the air with rhythmic contemporary as ``Wild 107.7'' on April 4, 2012.",
#  'evidence-125': 'Rich Owens (born 1972), American football defensive lineman',
#  'evidence-126': 'SUNY Poly is accredited by the Middle States Association of Colleges and Schools.',
#  'evidence-127': 'By 1940 the membership had fallen to 132, with a further sharp decline to 62 by 1945.',
#  'evidence-128': 'Other more exotic geomorphic processes might include periglacial (freeze-thaw) processes, salt-mediated action, changes to the seabed caused by marine currents, seepage of fluids through the seafloor or extraterrestrial impact.',
#  'evidence-129': 'After this more FM and web stations around the world followed.',
#  'evidence-130': 'For example, temperature and specific volume are always independent.',
#  'evidence-131': 'The Santos Basin is an 352260 km2 offshore pre-salt basin.',
#  'evidence-132': 'He competed for Portugal at the 2012 Summer Olympics.',
#  'evidence-133': "The foundation 's leading figure was long Marcello Pera, but later Quagliariello took over.",
#  'evidence-134': 'Overseas, he played for Arrayyan Sports Club for two seasons, and then Al-Wakrah Sports Club in Qatar.',
#  'evidence-135': 'In Tibetan Buddhist tradition the Chintamani is sometimes depicted as a luminous pearl and is in the possession of several of different forms of the Buddha.',
#  'evidence-136': 'The Belgium national football team qualified for the 1934 FIFA World Cup in Italy but they lost in the first round to Germany (2-5).',
#  'evidence-137': "Joyce Kilmer who was buried in France, is honored by a cenotaph erected in his family 's plot in the cemetery.",
#  'evidence-138': 'As a result, Muharrem İnce and Selahattin Demirtaş stood down.',
#  'evidence-139': 'He has presented the evening slot on BBC News 24 most weekdays alongside Carrie Gracie.',
#  'evidence-140': 'Francisco Javier López Díaz (born June 12, 1949) is a Spanish theologian and a priest of the Catholic Church incardinated in the personal prelature of Opus Dei.',
#  'evidence-141': 'Gerbrand Bakker (1771 -- 1828), Dutch physician',
#  'evidence-142': 'Among sixth (6th) graders, 60.7% were reading on grade level, while 39.7% demonstrated on grade level math skills.',
#  'evidence-143': 'Simpsonville is a small unincorporated community in northwestern Upshur County, Texas, United States.',
#  'evidence-144': 'Andrew Blair Tuke (born 25 July 1989) is a New Zealand sailor who won the gold medal at the 2016 Summer Olympics, and the silver medal at the 2012 Summer Olympics in the 49er class alongside Peter Burling.',
#  'evidence-145': "The 2002 Singer Sri Lankan Airlines Rugby 7 's was the fourth year of the Singer Sri Lankan Airlines Rugby 7 's tournament.",
#  'evidence-146': 'World War I and World War II service followed.',
#  'evidence-147': "He led the Tigers ' seconds to the 1954 and 1955 Seconds premierships.",
#  'evidence-148': "The 2016 -- 17 SMU Mustangs women 's basketball team represented Southern Methodist University in the 2016 -- 17 NCAA Division I women 's basketball season.",
#  'evidence-149': 'Anton Theodor Eberhard August Lubowski (3 February 1952 -- 12 September 1989) was a Namibian anti-apartheid activist and advocate.',
#  'evidence-150': "The Archives Hub has an ethos based on open access and ` making the data work harder '.",
#  'evidence-151': 'Control of the SECV was by a Board of Commissioners appointed by the Victorian Government, following the example of the Victorian Railways, and in contrast to the Departmental control that managed Australian postal and telephone services.',
#  'evidence-152': "Ragtime to Rock 'n' Roll is a BBC Radio 2 documentary chronicling the trends in popular music in the US and UK from 1900s to 1960s.",
#  'evidence-153': 'Club 3 Degrees is a branch of 3 Degrees Ministries.',
#  'evidence-154': 'By December 2007, this had grown to encompass 150 global businesses.',
#  'evidence-155': 'The film stars Silambarasan and Rakshitha in the lead roles, while Ashish Vidyarthi and S. S. Rajendran play pivotal roles.',
#  'evidence-156': 'He was Vice-Chairman of the Socialist Party parliamentary group from 1996 to 1999.',
#  'evidence-157': "The album also saw the release of ``Dream'' and the double A-side ``Off 2 Work'' / ``Graftin ''', which reached peaks of number fourteen and number forty-four in the UK, respectively.",
#  'evidence-158': 'Thomas Stewart (bass-baritone) (1928 -- 2006), American opera singer who specialized in Wagnerian roles',
#  'evidence-159': 'Forensics is another way for students to showcase their speech and intellectual abilities.',
#  'evidence-160': 'Irwin and Governor Peter Shumlin expressed concern about the discovery.',
#  'evidence-161': 'Ephysteris semiophanes is a moth in the Gelechiidae family.',
#  'evidence-162': 'Rosa Sucher (February 23, 1849 - April 16, 1927), née Hasselbeck, was a German operatic soprano renowned for her Wagnerian performances.',
#  'evidence-163': "Innovation Crush'' is a weekly podcast hosted by American innovation expert Chris Denson.",
#  'evidence-164': 'Heliobacteria and Christensenella are also members of the class Clostridia.',
#  'evidence-165': 'In the 19th century its main competitor was the "Plymouth Rock" newspaper.',
#  'evidence-166': 'Upon returning to Austria, Konti worked as an architectural modeler.',
#  'evidence-167': 'The species is found in montane habitats.',
#  'evidence-168': 'Holzmayer was also one of the founders of the local research society, and led the volunteer firefighter society.',
#  'evidence-169': 'Spill were a dance duo, whose members were William Orbit and Beth Orton.',
#  'evidence-170': 'The habitat consists of forest edges and gallery forests at altitudes ranging from 900 to 1,200 metres.',
#  'evidence-171': 'The buckyballs are fairly large molecules formed completely of carbon bonded trigonally, forming spheroids (the best-known and simplest is the soccerball-shaped C buckminsterfullerene).',
#  'evidence-172': 'It was posted to his channel again on August 11, 2016, where it received over 43 million views.',
#  'evidence-173': 'The solution may include pictures, diagrams, prose, or other media.',
#  'evidence-174': 'It is currently part of the Association of Tennis Professionals (ATP) Challenger Tour.',
#  'evidence-175': 'It is located along the B54 Road between Eldoret and Tenges, in the southern part of Kerio Valley and in the drainage basin area of the Kerio River.',
#  'evidence-176': 'They took place in Copenhagen, Denmark.',
#  'evidence-177': 'Heap Island is an island off the southeast coast of Renaud Island in the Biscoe Islands of the Graham Coast of Antarctica, between Jurva Point and Bates Island.',
#  'evidence-178': "Though, just as all of their Brazilian counterparts, Negaativa 's lyrics are open for interpretation by all who listen to them.",
#  'evidence-179': 'When ticket prices were regulated in the American domestic market, food was the primary means airlines differentiated themselves.',
#  'evidence-180': 'The sexes are almost identical in colour, pale grey-brown above with browner wings and tail, and whitish below ; the bill and legs are yellowish, and the eye has a yellow iris.',
#  'evidence-181': 'It includes the story of soldiers, a journalist, his father, and a real life priest, Josemaría Escrivá, the founder of Opus Dei who was canonized as a Roman Catholic saint.',
#  'evidence-182': "The result of the court 's approach has been that no court has ever ruled a law to be in contravention of Section 116, and the provision has played only a minor role in Australian constitutional history.",
#  'evidence-183': 'Henry Koerner (born Heinrich Sieghart Körner ; August 28, 1915 -- July 4, 1991) was an Austrian-born American painter and graphic designer best known for his early Magical Realist works of the late 1940s and his portrait covers for Time magazine.',
#  'evidence-184': 'A LAN-free backup is a backup of server data to a shared, central storage device without sending the data over the local area network (LAN).',
#  'evidence-185': 'This was the four Concert Tour of Mexican singer Belinda to promote her second Studio album Utopía.',
#  'evidence-186': 'The game targets a younger audience and is intended to teach spelling.',
#  'evidence-187': 'The Australian Conservation Foundation also began voicing concern about uranium mining and supporting the activities of the grass-roots organisations.',
#  'evidence-188': 'Three in Norway (by Two of Them) is a travelogue from the 19th century in Norway, written by J. A. Lees and W. J. Clutterbuck.',
#  'evidence-189': 'The Harlequin is characterized by his chequered costume.',
#  'evidence-190': 'Providing subject-related books and reference materials',
#  'evidence-191': 'The inscriptions other than the Bateshvar inscription, including those issued by Paramardi, suggest that Paramardi succeeded Madanvarman.',
#  'evidence-192': 't was released theatrically on a double bill in 1958 with the Vincent Price classic The Fly.',
#  'evidence-193': 'He had 36 starts in Formula One, mostly through two seasons with the Minardi team, with which he scored a sixth-place finish at the attrition-filled 1999 European Grand Prix.',
#  'evidence-194': 'The Quill (601 m ; in the Caribbean Netherlands)',
#  'evidence-195': 'Glutamate receptor, ionotropic, N-methyl D-aspartate-associated protein 1 (glutamate binding) is a protein in humans that is encoded by the GRINA gene.',
#  'evidence-196': 'It is most closely related to V. tricorpus and V. klebahnii.',
#  'evidence-197': 'He made many of the earliest recordings of pieces later to become standards of baroque countertenor repertoire - for example his Orphée Descendant aux Enfers of M.-A.',
#  'evidence-198': 'Brodie had loan spells with Morecambe and Grimsby Town over 2012 -- 13, and after being released by Crawley joined Gateshead.',
#  'evidence-199': "This was America 's first album that failed to chart.",
#  'evidence-200': 'In March 2011, Cyberdyne presented a legs-only HAL version for the disabled, health care professionals and factory workers.',
#  'evidence-201': 'JAR Pictures is an Indian motion picture production company based in Mumbai.',
#  'evidence-202': 'Locations closing in late September 2016, include, in Florida, two in Kissimmee, two in Orlando, and one each in Mary Esther, Tampa, and Tallahassee ; one in Macon, Georgia ; one in Houston, Texas ; on in Lafayette, Louisiana and one in Waynesboro, Virginia.',
#  'evidence-203': 'Chah Anjir-e Olya (چاه انجيرعليا, also Romanized as Chāh Ānjīr-e ` Olyā ; also known as Chāh Anjīr) is a village in Horgan Rural District, in the Central District of Neyriz County, Fars Province, Iran.',
#  'evidence-204': 'It is a comune in Itria Valley, the borderline with north Salento.',
#  'evidence-205': 'Due to this location it is vulnerable for flash floods, which can easily occur during the rainy season.',
#  'evidence-206': "The firm 's notable EGD work includes Washington, D.C. 's citywide pedestrian wayfinding system (Washington Post feature) ; branded signage for Amtrak 's Acela train service, which received a gold IDEA award from the Industrial Designers Society of America (IDSA) ; signage for New York City 's Second Avenue Subway, under construction ; and signage for the Rock and Roll Hall of Fame and Museum (in partnership with Alexander Isley).",
#  'evidence-207': 'Jan Knutzen (born 29 June 1943) is a Norwegian documentary filmmaker from Oslo.',
#  'evidence-208': 'The 519 serves both its local neighbourhood and the broader lesbian, gay, bisexual and transgender (LGBT) communities in the Toronto area.',
#  'evidence-209': "The song was featured as the closing track to the Stones ' 1975 compilation album Made in the Shade.",
#  'evidence-210': "She also holds the Israeli national records in the Women 's 50 m backstroke, 50 m breaststroke, 100 m breaststroke, 200 m Individual Medley, and 4 × 100 m medley relay.",
#  'evidence-211': "the Ordinary Level (``O Level'') ;",
#  'evidence-212': 'Kentucky Route 121 (KY 121) is a 63.410 mi state highway in Kentucky.',
#  'evidence-213': 'Grasslands are in the lower elevations and forests in the higher elevations.',
#  'evidence-214': 'The most senior African American Senator at his time, he held a number of leadership roles during his time.',
#  'evidence-215': "This allows Earth's surface to be warm enough to have liquid water and support life.",
#  'evidence-216': 'The Pârâul Popii is a tributary of the Pârâul Ursului in Romania.',
#  'evidence-217': "The A39 autoroute, also known as the L'Autoroute Verte, is a motorway in eastern France.",
#  'evidence-218': 'He was educated at Radley and Durham University and ordained in 1969.',
#  'evidence-219': 'Incredible Story Studios (formerly Incredible Story Studio) was a Canadian television series which aired worldwide.',
#  'evidence-220': 'The single was released in February 2005 and peaked at number 22 on the Billboard Hot 100, giving him his first and only top 40 hit on that chart as a solo artist.',
#  'evidence-221': 'By 1328 he had completed philosophic commentaries on the Pentateuch (especially the story of the Creation), the Book of Job, and Canticles.',
#  'evidence-222': 'The OpenFlight file format is still widely used today in the high end real-time visual simulation industry as the standard interchange format between different IG systems, and is currently administrated by Presagis.',
#  'evidence-223': "Exxon was a founding member, and a founding member of the GCC's board of directors.",
#  'evidence-224': 'Harry Fischel House, also known as Fairlawn, is a historic home located at Hunter in Greene County, New York.',
#  'evidence-225': 'Mohammad Firdaus bin Kasman (born 24 January 1988) is a Singapore international footballer who plays as a midfielder for Warriors in the S.League.',
#  'evidence-226': 'Their distribution patterns in surface waters are closely related to physical characteristics of the water bodies, and nearshore assemblages can also be distinguished from oceanic assemblages.',
#  'evidence-227': "The men 's 1000 metres in speed skating at the 1994 Winter Olympics took place on 18 February, at the Hamar Olympic Hall.",
#  'evidence-228': 'Khatayan (خطايان, also Romanized as Khāţāyān) is a village in Tus Rural District, in the Central District of Mashhad County, Razavi Khorasan Province, Iran.',
#  'evidence-229': "His acting credits include Barry Levinson 's Tin Men (1987), Woody Allen 's Broadway Danny Rose (1984) and Warren Beatty 's Bulworth (1998), among others.",
#  'evidence-230': 'In 1980 he was awarded a doctorate in meteorology from the University of Reading in Reading, England.',
#  'evidence-231': 'The Mainamati War Cemetery (alternatively : Comilla War Cemetery) is a war cemetery and a memorial in Comilla, Bangladesh, for Second World War graves from nearby areas during the Second World War.',
#  'evidence-232': 'Nguyen managed to recapture Saigon by 1788 and later ascended as Emperor Gia Long in 1802.',
#  'evidence-233': "The Sound Dues remained the most important source of income for the Danish Crown for several centuries, thus making Danish kings relatively independent of Denmark 's Privy Council and aristocracy.",
#  'evidence-234': 'Gumerovo, Ishimbaysky District, Republic of Bashkortostan, a village in Petrovsky Selsoviet of Ishimbaysky District',
#  'evidence-235': 'Copăcele is situated in the historical region of Banat.',
#  'evidence-236': 'In animals with bony tails, it is known as tailhead or dock, in bird anatomy as tailfan.',
#  'evidence-237': 'Avian reoviruses can withstand a pH range of 3.0 -- 9.0.',
#  'evidence-238': 'Jefferson-Morgan School District received more than $ 7.4 million in state funding in 2007-2008.',
#  'evidence-239': 'Cerithium bayeri is a species of sea snail, a marine gastropod mollusk in the family Cerithiidae.',
#  'evidence-240': 'John Harmar (ca. 1555 -- 1613) was an English classical scholar and headmaster of Winchester College.',
#  'evidence-241': 'Al was attuned to the power of networking much more than any of his elective colleagues.',
#  'evidence-242': "In still photography, Kodak 's Kodacolor brand has been associated with various color negative films (i.e., films that produce negatives for making color prints on paper) since 1942.",
#  'evidence-243': 'At The Geysers in California, after the first thirty years of power production, the steam supply had depleted and generation was substantially reduced.',
#  'evidence-244': 'Although the manuscripts were dedicated to the government of Dresden, the surviving documents surfaced in Cöthen in the 19th century.',
#  'evidence-245': 'Another related species is Eupatorium lancifolium, which is found in Alabama, Arkansas, Louisiana, and Texas, and which has sometimes been classified as part of E. semiserratum.',
#  'evidence-246': 'Hathliodes grammicus is a species of beetle in the family Cerambycidae.',
#  'evidence-247': 'The pair have also hosted numerous live shows, and started the advice podcast If I Were You in 2013.',
#  'evidence-248': '1993 -- 94 Alpenliga was the third season of the multi-national ice hockey league.',
#  'evidence-249': 'He was one of the original founders of Japanese Scouting in 1922.',
#  'evidence-250': 'Nowlan Park is the principal Gaelic Athletic Association stadium in Kilkenny, Ireland.',
#  'evidence-251': "Horace first appeared as Mickey 's plow horse in the cartoon The Plow Boy in 1929.",
#  'evidence-252': 'On November 1, 2011, Hudgins announced his candidacy for the office of the Secretary of State of Washington in the 2012 general election.',
#  'evidence-253': 'Estimates of direct costs for climate engineering implementation vary widely.',
#  'evidence-254': 'He was the backfield coach under McMillin at Indiana from 1938 to 1945.',
#  'evidence-255': 'Alexander Ivanovich Mikhailov, or A. I. Mikhailov (December 6, 1905, Russian Empire -- February 6, 1988, Moscow) was a Russian/Soviet Engineer and Information Scientist.',
#  'evidence-256': 'As a result, Minto proposed building a single tall but slim tower, and city council approved the necessary rezoning.',
#  'evidence-257': 'Fahd Faraj al-Juwair (1969 -- 28 February 2006) was a high-ranking member of al-Qaeda who was the highest member of that organization in Saudi Arabia at the point of his death.',
#  'evidence-258': 'Appeals from the District of Nebraska are taken to the United States Court of Appeals for the Eighth Circuit (except for patent claims and claims against the U.S. government under the Tucker Act, which are appealed to the Federal Circuit).',
#  'evidence-259': 'The Jordan River Pathway is an 18 mi loop trail located in Michigan in Antrim County, next to the Jordan River and the Jordan River hatchery.',
#  'evidence-260': 'The film features a scene where the characters perform a choreographed sequence using their office chairs.',
#  'evidence-261': 'The notion of resilience in energy was detailed in the 1982 book "Brittle Power: Energy Strategy for National Security".',
#  'evidence-262': 'David Lightfoot, Australian film producer',
#  'evidence-263': 'A further exhibition of the work was staged at Metropolis Group studios.',
#  'evidence-264': 'The interchange previously had an electronic destination display for both bus and rail services although this has been disabled.',
#  'evidence-265': 'Sulfur in calcined petroleum coke is a crucial element, for sulfur impacts the quality of steel.',
#  'evidence-266': 'Henrico County is included in the Greater Richmond Region.',
#  'evidence-267': 'Pakistan won the T20I series 2 -- 0 and won the ODI series 2 -- 0 after the third match finished as a no result.',
#  'evidence-268': 'Nadata is a genus of moths of the Notodontidae family.',
#  'evidence-269': 'The population of the district was 71,379 at the 2011 census.',
#  'evidence-270': 'Palloseura Kemi Kings or PS Kemi for short is a Finnish football team based in the town of Kemi, who are currently playing in the Finnish first division, the Ykkönen.',
#  'evidence-271': 'Her best achievement was fifth place in the 4 × 100 m medley relay.',
#  'evidence-272': 'But by cutting taxes now, Republicans have moved the starting point for any future negotiations.',
#  'evidence-273': 'Set in the 24th century, the series follows the adventures of the crew of the Starfleet starship USS Enterprise-D.',
#  'evidence-274': 'Until recently, it was known as Lala Geł, then Lali Gyuł.',
#  'evidence-275': 'Delcho Stoilov (born 1981), Bulgarian footballer',
#  'evidence-276': 'She moved to the Rochester Democrat and Chronicle in 1987 covering Eastman Kodak Co..',
#  'evidence-277': 'It expanded in to the south of England during the 1970s and 1980s, and acquired Allied Carpets, 61 large Gateway Supermarkets and other businesses, such as MFI, then during the 1990s, sold off its acquisitions to concentrate on the supermarkets.',
#  'evidence-278': 'It is also known by the nickname the TNA Asylum due to the venue hosting Total Nonstop Action Wrestling (TNA, now known as Impact Wrestling) events for two years in the early 2000s.',
#  'evidence-279': "The Sam Wanamaker Playhouse is an indoor theatre forming part of Shakespeare 's Globe, along with the Globe Theatre on Bankside, London.",
#  'evidence-280': 'On May 27, 2017, Cory Godbolt allegedly shot and killed eight people at three different houses in Lincoln County, Mississippi.',
#  'evidence-281': 'Kozhevnikova Bay is 23 km wide and 48 km in length and it is circled by lowlands.',
#  'evidence-282': 'Erdafitinib is being evaluated for safety and efficacy in phase II clinical trials for cholangiocarcinoma, gastric cancer, non-small cell lung cancer, and esophageal cancer.',
#  'evidence-283': 'Category : Educational institutions established in 1894',
#  'evidence-284': 'Altogether the defensive system of the gord was some 30 meter wide.',
#  'evidence-285': 'It was restored in 1907, only to be devastated by fire in 1914.',
#  'evidence-286': "Every album they have released since Sails has had at least one song written by band members, and Back in Line and Bloody Men were predominantly the band 's material.",
#  'evidence-287': 'Prominent examples of commutative rings include polynomial rings, rings of algebraic integers, including the ordinary integers, and p-adic integers.',
#  'evidence-288': 'The Transnationality Index was developed by the United Nations Conference on Trade and Development.',
#  'evidence-289': 'Eva Elizabeth Rodgerson (born June 21, 1945) is a Canadian politician, who was a member of the Legislative Assembly of Prince Edward Island from 2000 to 2007.',
#  'evidence-290': 'One for Justin Long for Best Actor and Tim Skousen Best Director.',
#  'evidence-291': 'Each of the following alumni, faculty, and former students of Auburn University is presumed to be notable, as he or she has received significant coverage in multiple published, secondary sources which are reliable, intellectually independent of each other, and independent of the subject.',
#  'evidence-292': 'An EP was also being recorded with three new songs.',
#  'evidence-293': 'Nemesbikk is a village in Borsod-Abaúj-Zemplén county, Hungary.',
#  'evidence-294': 'The 2007 Mobil 1 12 Hours of Sebring was the 55th running of this event and the opening round of the 2007 American Le Mans Series season.',
#  'evidence-295': 'Arantza or Arantxa is a Basque feminine given name, meaning "thornbush".',
#  'evidence-296': 'Two Arabic words stand out: "Scirocco" (SE) from "al-Sharq" (الشرق – east in Arabic) and the variant "Garbino" (SW), from "al-Gharb" (الغرب – west in Arabic).',
#  'evidence-297': 'It was released on April 26, 2010 as the lead-off single from their self-titled debut album, which was released on February 1, 2011.',
#  'evidence-298': 'A global warming conspiracy theory invokes claims that the scientific consensus on global warming is based on conspiracies to produce manipulated data or suppress dissent.',
#  'evidence-299': 'The organization is also focused on creating healthy living and working environments.',
#  'evidence-300': 'The Council expressed its willingness to consider all appropriate measures to enforce the arms embargoes by way of border controls or investigations into arms trafficking.',
#  'evidence-301': 'The binding between a ligand immobilized on the biosensor tip surface and an analyte in solution produces an increase in optical thickness at the biosensor tip, which results in a wavelength shift, Δλ (Figure 3), which is a direct measure of the change in thickness of the biological layer.',
#  'evidence-302': 'The movie stars Anil Kapoor, Ashok Kumar, Padmini Kolhapure, Anita Raj.',
#  'evidence-303': 'The Blues finished the season with a record of 26 wins, 40 losses and 12 ties for 64 points, placing them in sixth place.',
#  'evidence-304': 'The Kampala -- Mpigi Expressway is a proposed four-lane, dual carriage highway in the Central Region of Uganda, connecting, Kampala, the capital city, and Mpigi, the headquarters of Mpigi District.',
#  'evidence-305': 'His father was William John Morrell, Chancellor of Otago University, Dunedin.',
#  'evidence-306': 'Accordingly, steles were erected at two locations as statements to curry political favor with the priesthood, and possibly the populace.',
#  'evidence-307': 'Alexandra was the last Tsarina of Russia and one of the most famous royal carriers of the haemophilia disease that descended from Queen Victoria.',
#  'evidence-308': "This is a list of video games that are set in the franchise 's various timelines, and are segregated by the console systems they were released for.",
#  'evidence-309': 'In the Catalogue of Named Galaxies, it is called Xiphophorus Ursae Majoris, or the sword-bearer galaxy, after its resemblance to the green swordtail fish.',
#  'evidence-310': 'Its people were known to be very polite.',
#  'evidence-311': 'He, once again, played for Suffolk during the 2008 season.',
#  'evidence-312': 'Further exploration took place in 1975-1976 by members of the same group to reach the current limit.',
#  'evidence-313': "The turacos make up the bird family Musophagidae (literally ``banana-eaters''), which includes plantain-eaters and go-away-birds.",
#  'evidence-314': 'The story behind each mission is accurate to the novels, though taking place during the two-year span in the 1965 novel Dune when Paul gains the trust of the Fremen.',
#  'evidence-315': 'As El Niño conditions started to develop during early 2014, sea levels in western Micronesia including in waters surrounding the island nations of Palau and Guam dropped by 6–9 feet (1.8–2.7\xa0m).',
#  'evidence-316': 'It was originally released in 1973, and in 2006 was the nineteenth Schulze album reissued by Revisited Records.',
#  'evidence-317': 'Adams partnered with her husband and furniture designer, Sherwood Hamill, to launch angela adams designs, dedicated to the creation of custom rugs and custom furniture in Portland, Maine.',
#  'evidence-318': 'Coupons are then inspected to ensure proper layer alignment, electrical connectivity, and cross sectioned to inspect internal structures.',
#  'evidence-319': "They finished the season 22 -- 15, 9 -- 9 in Big East play and lost in the quarterfinals of the 2011 Big East Men 's Basketball Tournament to Louisville.",
#  'evidence-320': 'Concerns about genetic diversity are therefore especially important with large mammals due to their small population size and high levels of human-caused population effects.',
#  'evidence-321': "TRT International April 23 Children 's Festival is a festival which is celebrated on April 23 each year in Turkey.",
#  'evidence-322': 'His work has been used and applied in biomedical, household care and cosmetic industries.',
#  'evidence-323': 'Responsible exogenous solutes include sucrose-containing IVIg, mannitol, dextran, contrast dye, and hydroxyethyl starch.',
#  'evidence-324': "James Trick ``Jimmy'' Jose (1881 -- 1963) was a Cornish rugby union player who competed in the 1908 Summer Olympics at White City Stadium, London.",
#  'evidence-325': 'He played for the Cleveland Indians from 1927 to 1928 and the Philadelphia Phillies in 1930.',
#  'evidence-326': "The Monkey 's Bum is a variation of the Modern Defense, a chess opening.",
#  'evidence-327': 'Martin Luther Hampton (August 3, 1890 in Laurens, South Carolina -- 1950 in Dade County) was an architect in Florida.',
#  'evidence-328': 'Via natural selection, these birds adapted rapidly and converged based on the different environments of the Hawaiian islands.',
#  'evidence-329': 'Voice of Han Broadcasting Station also known as Voice of Han Chinese Broadcasting Station was founded in 1942 by the Ministry of National Defense.',
#  'evidence-330': 'Airports that are part of the National Airports System are emphasised.',
#  'evidence-331': 'Concern mounted year by year along with the rise of the "Keeling Curve" of atmospheric .',
#  'evidence-332': 'Gustav Horn, Count of Pori (1592 -- 1657), Swedish/Finnish soldier and politician',
#  'evidence-333': "Richard Alphonsus O'Connor (13 January 1838 -- 23 January 1913) was a Canadian priest and Bishop of Peterborough, Ontario.",
#  'evidence-334': 'He has won the Lila Ray award of the Government of West Bengal in 2008 and the Derozio bicentenary award in 2010.',
#  'evidence-335': 'The Sioux Falls Arena remains and hosts smaller concerts and events, while the Denny Sanford Premier Center hosts large scale concerts and sporting events.',
#  'evidence-336': 'For his DePaul career, Bradshaw scored 1,102 points and left the program as its all-time assist leader.',
#  'evidence-337': 'The U.S. had its warmest March–May on record in 2012.',
#  'evidence-338': "Lida has some remorse because of society and their views on premarital sex, but then comes to the realization that it is her life saying ``I wanted to do it and I did it ; and I felt so happy''.",
#  'evidence-339': 'St. Gregory of Tours (De Gloria martyrum, xxx : Patrologia Latina, LXXI, 730) testifies that a certain substance like flour emanated from the sepulchre of John the Evangelist.',
#  'evidence-340': 'As of the 2010 census, the population of the CDP was 380, compared to 3,393 for the entire town of Hartland.',
#  'evidence-341': 'With Yokefleet and Bellasize, Faxfleet forms part of the civil parish of Blacktoft.',
#  'evidence-342': 'In 2007, BP paid $303 million in restitution and fines as part of an agreement to defer prosecution.',
#  'evidence-343': 'Miller Creek (Marin County, California), a stream',
#  'evidence-344': 'Nowadays, a reform is made in this school.',
#  'evidence-345': 'Terry and Linda Fuller Track & Field Complex is a multi-use stadium in Lubbock, Texas on the campus of Texas Tech University where it serves as home to Red Raider track and field.',
# ...
#  'evidence-887': 'Because of the unusual shape and associated magnetic anomalies, Paasselkä was suspected to have an impact origin long until it was confirmed after a deep drilling in 1999 making it the ninth known impact crater in Finland.',
#  'evidence-888': 'Flavius Strategius Apion Strategius Apion (died between 577 and 579) was a patrician and jurist of the Byzantine Empire, and the consul ordinarius of 539.',
#  'evidence-889': 'Flynn later joined Buckinghamshire, making his debut for the county in the 1980 Minor Counties Championship against Bedfordshire.',
#  'evidence-890': 'As colorfulness, chroma and saturation are defined as attributes of perception they can not be physically measured as such, but they can be quantified in relation to psychometric scales intended to be perceptually even, for example the chroma scales of the Munsell system.',
#  'evidence-891': 'It is located along the main Kumasi-Techiman highway which is a first class road and which links Southern part of the country to its northern parts as well as neighbouring countries such as Burkina Faso, Mali, Niger and northern Togo.',
#  'evidence-892': 'The Action of 31 March 1800 was a naval engagement of the French Revolutionary Wars fought between a Royal Navy squadron and a French Navy ship of the line off Malta in the Mediterranean Sea.',
#  'evidence-893': 'Led by their powerful defense, the Bucks beat the #2 Wisconsin Badgers and their eventual Heisman Trophy winner Alan Ameche on an 88-yard interception return by Howard "Hopalong" Cassady, who won the award the following year.',
#  'evidence-894': 'It is also within the Town of Georgina and in the Regional Municipality of York.',
#  'evidence-895': 'He won his first title in 2016 at the Japan Golf Tour Championship.',
#  'evidence-896': 'An organism can recover to normal weight without additional time.',
#  'evidence-897': "Novo Santo Antônio (Portuguese for ``New Saint Anthony'') is a Brazilian municipality of the state of Piauí.",
#  'evidence-898': 'Roger Miller (baseball) (1954 -- 1993), MLB baseball player',
#  'evidence-899': 'The 1934 Vanderbilt Commodores football team represented Vanderbilt University during the 1935 college football season.',
#  'evidence-900': 'The ecoregion of the Solimões river drainage basin is entirely tropical rainforest.',
#  'evidence-901': 'The Royal Navy found him, gave him food, and offered him a passage to England on board the Serapis.',
#  'evidence-902': 'As a result, the episode focuses on the differences between Starbuck and Kat and how their personalities come into conflict rather than on space combat.',
#  'evidence-903': "While many of the songs were performed by professional musicians, others featured wrestlers on vocals, such as ``Bow Wow Wow.''",
#  'evidence-904': 'hydroxymalonate + NAD + oxomalonate + NADH + H +',
#  'evidence-905': 'Johan Andersson (21 February 1889 -- 1 July 1965) was a Swedish wrestler.',
#  'evidence-906': 'He usually plays in the defensive midfielder position.',
#  'evidence-907': 'Darleys Gregorio Pérez Ballesta (born September 14, 1983) is a Colombian pro boxer who fought at the 2008 Summer Olympics as a lightweight.',
#  'evidence-908': 'The A179 is the major link road between the A19 and Hartlepool via Hart Village.',
#  'evidence-909': 'Sarab (سراب, also Romanized as Sarāb ; also known as Sūrab) is a village in Afriz Rural District, Sedeh District, Qaen County, South Khorasan Province, Iran.',
#  'evidence-910': "The script, by Thea von Harbou, includes elements of Puccini 's opera Turandot and Friedrich Schiller 's adaptation of Carlo Gozzi 's 1762 play Turandot.",
#  'evidence-911': 'Frank Maher, who later played in the NFL for the Philadelphia Eagles, was the team captain.',
#  'evidence-912': "Killed in action during the Battle of Falaise, he was posthumously awarded the Silver Cross of Virtuti Militari, Poland 's highest military decoration.",
#  'evidence-913': 'Corbie Abbey is a former Benedictine monastery in Corbie, Picardy, France, dedicated to Saint Peter.',
#  'evidence-914': 'The party favours a variety of complementary currencies.',
#  'evidence-915': "``Fire Water Burn'' was remixed for the CD single by God Lives Underwater.",
#  'evidence-916': "``The Doors Of Paris'' (from the musical Notre-Dame De Paris)",
#  'evidence-917': 'His concert was briefly delayed while local security forces quelled instances of civil unrest in the city.',
#  'evidence-918': 'Aurat is a 1940 social Hindi movie directed by N. R. Acharya and produced by Bombay Talkies.',
#  'evidence-919': 'Once established, stunting and its effects typically become permanent.',
#  'evidence-920': 'Propagermanium (INN), also known by a variety of other names including bis (2-carboxyethylgermanium) sesquioxide and 2-carboxyethylgermasesquioxane, is an organometallic compound of germanium that is sold as an alternative medicine.',
#  'evidence-921': 'The mountains that surround the cove are part of the southern fringe of the Cumberland Mountains.',
#  'evidence-922': 'The tallest one is 3.3 m ; the shortest - 1.4 m.',
#  'evidence-923': 'He was the New Zealand representative in the 2005 Prague Biennale and his work was included in the 17th Biennale of Sydney 2010.',
#  'evidence-924': 'John Dahl (born 1956) is an American film and television director and writer, best known for his work in the neo-noir genre.',
#  'evidence-925': 'Following the March 2011 Fukushima nuclear disaster, Germany has permanently shut down eight of its 17 reactors.',
#  'evidence-926': 'It is situated near Hallingskarvet National Park and 20 min from the ski resorts of Geilo.',
#  'evidence-927': 'Sextus Otto Lindberg (1835 -- 1889), Swedish physician and bryologist',
#  'evidence-928': 'The term was coined by John Ioannidis and Thomas A. Trikalinos in 2005 named after the Greek god Proteus who could rapidly change his appearance.',
#  'evidence-929': 'He was out for five runs in the first innings, but made 69 not out in the second, opening the batting with Junie Mitchum.',
#  'evidence-930': 'Wright has been very doubtfully credited with several religious tracts, which are said to have been published anonymously, but he has been much confused by bibliographers with other writers of the time of his name, and no list of his works can be given with confidence.',
#  'evidence-931': 'Hetauda city is located at a distance of 76 km from the capital city, Kathmandu, via the fast track, at a distance of 132 km via Daman Tribhuvan Highway and 224 km via Narayanghat.',
#  'evidence-932': 'This song has appeared on the videogame Dance Dance Revolution Hottest Party.',
#  'evidence-933': 'The last few sub chapters deal with high altitude performance adjustments, motor vehicle compliance program fees, prohibition on production of engines requiring leaded gasoline and urban bus standards.',
#  'evidence-934': 'He was a right-handed batsman and right-arm fast-medium bowler.',
#  'evidence-935': 'The 2.x versions of the standards, which support clinical practice and the management, delivery, and evaluation of health services, are the most commonly used in the world.',
#  'evidence-936': 'She was the 13th Queen mother of the Ashanti Kingdom.',
#  'evidence-937': 'On his death Émile Masqueray rejoined the fight for the rights of the Algerians against the repressive behavior of the colonists.',
#  'evidence-938': 'When the band began playing, the excessive bass knocked the liquor bottles off the shelf behind the bar.',
#  'evidence-939': 'CLG Ógra Colmcille is a Gaelic Athletic Association club based in Drummullan, County Londonderry, Northern Ireland.',
#  'evidence-940': 'Thond-angi or Tond-angi is a village and a Mandal in East Godavari district in the state of Andhra Pradesh in India.',
#  'evidence-941': 'In the Massachusetts House of Representatives, Brackett rose to become Speaker in 1885, and was elected Lieutenant Governor of Massachusetts under Governor Oliver Ames.',
#  'evidence-942': 'Unlike intravenous lines, which usually need to be placed in an inpatient environment and require special formulation of sterile medications, a specialized rectal catheter can be placed by a clinician, such as a hospice nurse or home health nurse, in the home.',
#  'evidence-943': 'The study, further, has been very critical and exhaustive as can well be seen from the scholarly examination of the views of the different systems of Indian Philosophy like the Carvakas, the Nyaya-Vaisesikas, the Samkhyas, the Jainas, the different schools of Buddhism and the Advaita Vedanta, so laboriously culled from the poem.',
#  'evidence-944': 'Świerczynki may refer to various places in Poland :',
#  'evidence-945': 'USS Wahneta has been the name of more than United States Navy ship, and may refer to :',
#  'evidence-946': "After the release of Orcastrated (1995), the band 's bassist John ``K'Cee'' Casey left the band and was replaced with Gary ``Gary Fun'' Dunn.",
#  'evidence-947': "Andrew Baird (11 June 1866 in Irvine -- 1916) was a Scottish footballer, who played for Queen 's Park and Scotland.",
#  'evidence-948': "Alexander Scriabin 's Fantasie in B minor, Op. 28, was written in 1900.",
#  'evidence-949': 'It was published in several foreign territories and as an audiobook.',
#  'evidence-950': 'In 1658 he was elected an alderman of the City of London for Queenhithe ward.',
#  'evidence-951': 'Preventive laws and measures (related to zoning, deforestation, and so forth) are not enforced and there is no reliable early warning system.',
#  'evidence-952': 'Johnny Brenner (born 1971), Irish hurler',
#  'evidence-953': 'The SEI was organized in 2007 and formally recognized by SUNY in 2009.',
#  'evidence-954': 'Scott Baker (born March 4, 1964) is an American journalist, commentator, blogger, online talk show host, educator, and political campaign worker.',
#  'evidence-955': 'Like his father, and several other members of his family, he was Member of Parliament (MP) for the borough constituency of Wenlock.',
#  'evidence-956': 'International organizations invited by Argentina are the Caribbean Community (represented by Jamaica), the Inter-American Development Bank, and the Development Bank of Latin America (CAF).',
#  'evidence-957': 'He played the lead in the 1921 silent horror film The Grinning Face (1921).',
#  'evidence-958': 'The Mongolian government agency recorded a 45% increase in the rate of respiratory illness in the past five years (reported in September 2014).',
#  'evidence-959': 'The majority of the films were distributed through Warner Bros..',
#  'evidence-960': "This means that, for detailed scenes, the painter's algorithm can overly tax the computer hardware.",
#  'evidence-961': 'Everlight (album), an album by German progressive metal band Dreamscape',
#  'evidence-962': 'The company is headquartered in Princeton, New Jersey.',
#  'evidence-963': "She led an Indian clean sweep in the women 's discus final on 11 October 2010, winning the Delhi Commonwealth Games gold medal with a throw of 61.51 metres.",
#  'evidence-964': 'He was first elected in 2014 to succeed Evan Jenkins who chose to run for Congress.',
#  'evidence-965': "Like its parent series, GHI was a reality series that followed a team of paranormal investigators ; whereas, the original series primarily covers only locations within the United States, the GHI team traveled around the world and documented some of the world 's most legendary haunted locations.",
#  'evidence-966': "It was Villa 's first major trophy for 37 years.",
#  'evidence-967': 'Liberty Village is a neighbourhood in Toronto, Ontario, Canada.',
#  'evidence-968': "The Akyem ethnic group make up between 3-9 percent of Ghana 's population depending on how one defines the group and are very prominent in all aspects of Ghanaian life.",
#  'evidence-969': 'Papers on alchemy were found after his death.',
#  'evidence-970': 'General elections were held in Kenya between 18 and 26 May 1963, the last before independence later in the year.',
#  'evidence-971': 'Chapple was first elected in the general election in 1959 and but was defeated in the general elections in 1963.',
#  'evidence-972': 'The Lady Tigers, meanwhile, captured their eleventh consecutive title, and, ultimately, the last of the eleven straight titles they claimed between 1987 and 1997.',
#  'evidence-973': "Founded by Josh Kopelman, the firm 's investment team now includes Chris Fralic, Rob Hayes, Howard L. Morgan, Bill Trenchard, and Phineas Barnes.",
#  'evidence-974': "When Isma'il Pasha ascended the throne in 1863, she was elevated to the rank of first Kadinefendi, literally meaning first consort, or wife.",
#  'evidence-975': 'During his two decades at the Salpêtrière, Albert Londe developed into arguably the most outstanding scientific photographer of his time.',
#  'evidence-976': 'Chyby [` hyby] is a village in the administrative district of Gmina Mniów, within Kielce County, Świętokrzyskie Voivodeship, in south-central Poland.',
#  'evidence-977': 'Clarke specialized in future-war fiction and his 1966 work Voices Prophesying War is recognized as a major contribution.',
#  'evidence-978': 'It was established in 1996 by Ms. Molly Pradeep, late wife of the present Director Mr. Pradeep Kuriakose.',
#  'evidence-979': 'Third-generation renewable energy technologies are still under development and include advanced biomass gasification, biorefinery technologies, hot-dry-rock geothermal power, and ocean energy.',
#  'evidence-980': 'Healesville was at the furthest point coaches could travel along the route from Melbourne.',
#  'evidence-981': 'It comprises several similar all-blue and black subspecies that were originally considered separate species.',
#  'evidence-982': 'He is married to voice actress Rikako Aikawa.',
#  'evidence-983': 'Frazier Glenn Miller Jr. (born November 23, 1940), commonly known as Glenn Miller, is a former leader of the defunct North Carolina-based White Patriot Party (formerly known as the Carolina Knights of the Ku Klux Klan).',
#  'evidence-984': 'Bertrand won the bronze medal in the Finn competition at the 1976 Summer Olympics in Montreal.',
#  'evidence-985': 'Tetracaine, also known as amethocaine, is a local anesthetic used to numb the eyes, nose, or throat.',
#  'evidence-986': "Initial nominations are made by members in January through March, while voting on the ballot of five nominations is performed roughly in April through July, subject to change depending on when that year 's Worldcon is held.",
#  'evidence-987': 'This was a result of the Spanish Penal Code of 1870, which was adopted due to the country having been a Spanish colony until 1898.',
#  'evidence-988': 'The competition comprised a preliminary round and four rounds proper followed by quarter-finals, semi-finals, and a final.',
#  'evidence-989': 'Gymnastics was the sport in which Germany excelled.',
#  'evidence-990': "The information paper also identified him as ``Ahnad Adil''.",
#  'evidence-991': 'Category : Municipalities of the La Unión Department',
#  'evidence-992': "In 1997 Chiara returned to Italy to produce the compact disc ``Nei Tuoi Occhi'', as a tribute to Massimo Troisi.",
#  'evidence-993': 'The Pink Doll is an animated film of Russian director Valentin Olshvang, produced in 1997.',
#  'evidence-994': 'Mulangoor was lost to the Muslim invaders, and nothing much was left of the fort after the battle.',
#  'evidence-995': 'Like all species within the genus Conus, these snails are predatory and venomous.',
#  'evidence-996': 'The film goes so far as to put in doubt the nature of Rick Deckard and forces the audience to reevaluate what it means to be human.',
#  'evidence-997': 'The Australian government has published a best practice guide for in situ leach mining of uranium, which is being revised to take account of international differences.',
#  'evidence-998': 'Ahmad Mahir Pasha (1888 -- 1945), Egyptian prime minister 1944 -- 1945',
#  'evidence-999': "From 2002 to 2004, he attended Southeastern Community College in Iowa where he averaged 11.6 points with 7.4 rebounds and 2.7 assists, both years he won the NJCAA national championships under head coach Joe O'Brien.",
#  ...}

# %%
len(evidence)
# Out:
# 1208827

# %% [markdown]
# ### Have a look at structure of test_claims unlabelled (which we will later refer to as 'future' because we will make our own test set) and how many there are

# %%
test_claims_unlabelled
# Out:
# {'claim-2967': {'claim_text': 'The contribution of waste heat to the global climate is 0.028 W/m2.'},
#  'claim-979': {'claim_text': '“Warm weather worsened the most recent five-year drought, which included the driest four-year period on record in terms of statewide precipitation.'},
#  'claim-1609': {'claim_text': 'Greenland has only lost a tiny fraction of its ice mass.'},
#  'claim-1020': {'claim_text': '“The global reef crisis does not necessarily mean extinction for coral species.'},
#  'claim-2599': {'claim_text': 'Small amounts of very active substances can cause large effects.'},
#  'claim-2110': {'claim_text': "They changed the name from 'global warming' to 'climate change'"},
#  'claim-1135': {'claim_text': 'Scientists confirm a mass bleaching event on the Great Barrier Reef this year has killed more corals than ever before, with more than two thirds destroyed across large swathes of the biodiverse site.'},
#  'claim-712': {'claim_text': '“Instead of a three-foot increase in ocean levels by the end of the century, six feet was more likely, according to DeConto and Pollard’s findings.'},
#  'claim-1307': {'claim_text': 'a new study by scientists at the Australian Research Council finds that the ongoing bleaching event is mainly due to human-caused global warming, and that if global warming proceeds as currently expected, “large parts” of the Great Barrier Reef could die by the mid-2030s.'},
#  'claim-148': {'claim_text': 'Previous IPCC reports tended to assume that clouds would have a neutral impact because the warming and cooling feedbacks would cancel each other out.'},
#  'claim-903': {'claim_text': 'Growers regularly pump CO2 into greenhouses, raising levels to three times that of the natural environment, to produce stronger, greener, healthier plants.”'},
#  'claim-2942': {'claim_text': 'It’s usually taken to be the fact that as carbon dioxide concentrations in the atmosphere increase, the 1 per cent of CO2 that’s the heavier carbon isotope ratio c13 declines in proportion.'},
#  'claim-1001': {'claim_text': '‘This study goes beyond statistical correlations and explores a specific process that can plausibly explain how enhanced high-latitude warming trends may trigger remote weather impacts,’ he said.'},
#  'claim-1034': {'claim_text': 'Your odds of correctly guessing the outcome of a flipped coin are 1 in 2, but your odds of guessing correctly twice in a row are only 1 in 4 —'},
#  'claim-1009': {'claim_text': '‘Arctic ice conditions have been tracking at record low conditions since October, persisting for six consecutive months’'},
#  'claim-770': {'claim_text': '[CO2] has increased 43 percent above the pre-industrial level so far'},
#  'claim-3074': {'claim_text': 'Fourth Assessment Report (AR4), in which the likely range is given as 2.0°C to 4.5°C, with a best estimate of 3.0°C" (Pat Michaels)'},
#  'claim-1761': {'claim_text': 'Multiple lines of evidence make it very clear that the rise in atmospheric CO2 is due to human emissions.'},
#  'claim-1475': {'claim_text': "More than 500 scientists and professionals in climate and related fields have sent a 'European Climate Declaration' to the Secretary-General of the United Nations."},
#  'claim-477': {'claim_text': 'Scientists say halting deforestation ‘just as urgent’ as reducing emissions'},
#  'claim-1378': {'claim_text': 'Antarctica is gaining land-based ice, according to a new study by NASA scientists published in the Journal of Glaciology'},
#  'claim-503': {'claim_text': '“During the sunless winter, a heatwave raised concerns that the polar vortex may be eroding.'},
#  'claim-2751': {'claim_text': 'The argument that solving the global warming problem by reducing human greenhouse gas emissions is "too hard" generally stems from the belief that (i) our technology is not sufficiently advanced to achieve significant emissions reductions,'},
#  'claim-2575': {'claim_text': 'Over the last 30-40 years 80% of coral in the Caribbean have been destroyed and 50% in Indonesia and the Pacific.'},
#  'claim-30': {'claim_text': "the bushfires [in Australia] were caused by arsonists and a series of lightning strikes, not 'climate change'"},
#  'claim-2994': {'claim_text': "'Mauna Loa has been producing a readout which supports Manning's predetermined goal by showing steady growth in atmospheric CO2 concentrations since 1959."},
#  'claim-55': {'claim_text': '[T]he raw data, the actual thermometer data[...] shows that the US has been cooling for 80 to 90 years.'},
#  'claim-1271': {'claim_text': 'Greenland ice sheet … would balloon sea levels by around 7m should it disintegrate'},
#  'claim-2248': {'claim_text': 'Climate sensitivity can be calculated empirically by comparing past temperature change to natural forcings at the time.'},
#  'claim-532': {'claim_text': 'Never mind that the emissions of carbon dioxide to make and maintain a wind or solar industrial complex are far greater than they will ever save.'},
#  'claim-556': {'claim_text': 'The April low temperatures here are now about 6 degrees Fahrenheit warmer than they used to be.'},
#  'claim-1173': {'claim_text': '[…]until we develop a practical, cost-competitive alternative to fossil fuels, it is unlikely that renewable energy will ever make up more than 15-20% of global energy requirements.'},
#  'claim-539': {'claim_text': 'We note that the Earth has never in its history had a quasi-stable state that is around 2C warmer than the preindustrial and suggest that there is substantial risk that the system, itself, will ‘want’ to continue warming because of all of these other processes – even if we stop emissions,” she said.'},
#  'claim-893': {'claim_text': 'While France and other G7 countries lamented the U.S. exit from the Paris climate accord, America’s air is already cleaner than that of any other country in the G7, except Canada with its scant population.'},
#  'claim-2857': {'claim_text': 'Weather is chaotic because air is light, it has low friction and viscosity, it expands strongly when in contact with hot surfaces and it conducts heat poorly.'},
#  'claim-109': {'claim_text': 'Local and regional sea levels continue to exhibit typical natural variability—in some places rising and in others falling.'},
#  'claim-2476': {'claim_text': "The global dimming trend reversed around 1990 - 15 years after the global warming trend began in the mid 1970's."},
#  'claim-3038': {'claim_text': 'Clearly, other factors besides atmospheric carbon influence earth temperatures and global warming."'},
#  'claim-3127': {'claim_text': '"Skeptics hope that Postma’s alternative thermal model will lead  to the birth of a new climatology, one that actually follows the laws of  physics and properly physical modeling techniques...'},
#  'claim-474': {'claim_text': 'Sea ice continued its declining trend, both in the Arctic and Antarctic.'},
#  'claim-2464': {'claim_text': 'While natural forcings can account for much of the early 20th Century warming, humans played a role as well.'},
#  'claim-2427': {'claim_text': 'By that time CO2 emissions had already risen from the expanded use  of coal that had powered the industrial revolution, and emissions only  increased slowly from 3.5gigatonnes in 1910 to under 4gigatonnes by the  end of the Second World War.'},
#  'claim-2167': {'claim_text': 'Royal Society embraces skepticism'},
#  'claim-812': {'claim_text': 'The human contribution can be up to 30 percent or so of the total rainfall coming out of the storm'},
#  'claim-2590': {'claim_text': "This argument originates from Angstrom's work in 1901."},
#  'claim-404': {'claim_text': 'Actual weather records over the past 100 years show no correlation between rising carbon dioxide levels and local temperatures.'},
#  'claim-2977': {'claim_text': 'According to the study, as carbon levels have risen, the cold air at high altitudes over the tropics has actually grown colder.'},
#  'claim-2673': {'claim_text': 'They changed the name from “global warming” to “climate change” after the term global warming just wasn’t working (it was too cold)!'},
#  'claim-2509': {'claim_text': 'In 1905, PDO switched to a warm phase.'},
#  'claim-138': {'claim_text': 'As a result, half of the people surveyed around the world last year said they thought climate change would make humanity extinct.'},
#  'claim-952': {'claim_text': 'The Alaskan tundra is warming so quickly it has become a net emitter of carbon dioxide ahead of schedule, a new study finds'},
#  'claim-1691': {'claim_text': 'Sea level rise is now increasing faster than predicted due to unexpectedly rapid ice melting.'},
#  'claim-1741': {'claim_text': 'Volcanoes have had no warming effect in recent global warming - if anything, a cooling effect.'},
#  'claim-1202': {'claim_text': '\xa0The discrepancy between model-predicted warming and (lower) real-world observations has inspired new respect for natural climate variability relative to greenhouse-gas forcing.\xa0'},
#  'claim-1028': {'claim_text': 'A second coat of paint has much less of an effect, while adding a third or fourth coat has almost no impact at all.”'},
#  'claim-28': {'claim_text': 'Volcanoes Melting West Antarctic Glaciers, Not Global Warming'},
#  'claim-275': {'claim_text': 'until temperature increases began to slow down after 1998 and remained relatively stable for a period of 15 years'},
#  'claim-350': {'claim_text': 'Since 1965, more parts of the U.S. have seen a decrease in flooding than have seen an increase.'},
#  'claim-2204': {'claim_text': 'All the indicators show that global warming is still happening.'},
#  'claim-1604': {'claim_text': 'CO2 increase is natural, not human-caused.'},
#  'claim-3119': {'claim_text': 'CO2 constitutes 80% of the non-condensing greenhouse gas forcing.'},
#  'claim-2150': {'claim_text': 'Adapting to global warming is cheaper than preventing it'},
#  'claim-21': {'claim_text': 'Sea level rise has been slow and a constant, pre-dating industrialization'},
#  'claim-2013': {'claim_text': 'U.S. Sen. Ron Johnson voted to let oil and gas companies emit "unlimited carbon pollution into our air"'},
#  'claim-467': {'claim_text': 'This is the South Pole ice, 90% of Earth’s ice, and it’s getting thicker.'},
#  'claim-2754': {'claim_text': '"There are many urgent priorities that need the attention of Congress, and it is not for me as an invited guest in your country to say what they are.'},
#  'claim-2797': {'claim_text': 'Global brightening is caused by changes in cloud cover, reflective aerosols and absorbing aerosols.'},
#  'claim-1771': {'claim_text': 'Peer-reviewed research, physics, and math all tell us that a grand solar minimum would have no more than a 0.3°C cooling effect, barely enough to put a dent in human-caused global warming.'},
#  'claim-1908': {'claim_text': 'In reality, gas produced by fracking is worse for the climate than coal.'},
#  'claim-2000': {'claim_text': 'There is not a single candidate in the Republican primary that thinks we should do anything about climate change.'},
#  'claim-2084': {'claim_text': "Hurricanes aren't linked to global warming"},
#  'claim-1237': {'claim_text': 'the last sea-level high point, … occurred between the last two ice ages, about 125,000 years ago.'},
#  'claim-400': {'claim_text': 'The idea that climate change is producing heat records across the Earth is among the most egregious manipulations of data in the absurd global warming debate.'},
#  'claim-1508': {'claim_text': 'global warming ceased around the end of the twentieth century and was followed (since 1997) by 19 years of stable temperature.'},
#  'claim-520': {'claim_text': 'Just 1.25 per cent of the carbon dioxide in the atmosphere-ocean system has been released by \xadhumans in the past 250 years.'},
#  'claim-3064': {'claim_text': 'No warming since at least 1995, no melting glaciers and now no rising sea levels.'},
#  'claim-1588': {'claim_text': "Melting ice isn't warming the Arctic."},
#  'claim-1488': {'claim_text': 'New Study Confirms EVs Considerably Worse For Climate Than Diesel Cars.'},
#  'claim-2733': {'claim_text': 'A number of independent studies using near-global satellite data find positive feedback and high climate sensitivity.'},
#  'claim-809': {'claim_text': 'In the early 20th century, state and federal governments began aggressively fighting wildfires and trying to keep them as small as possible.'},
#  'claim-763': {'claim_text': 'And some plants – like algae which use carbon for photosynthesis – may even benefit.'},
#  'claim-454': {'claim_text': 'Man-made greenhouse gases play only an insignificant role.”'},
#  'claim-1853': {'claim_text': 'Barack Obama supports proposals "to devote billions of dollars annually to state game and fish agencies and federal land management agencies to help them ensure that fish and wildlife survive the impacts of climate change."'},
#  'claim-2838': {'claim_text': "The data is being reported by the University of Illinois's Arctic Climate Research Center, and is derived from satellite observations of the Northern and Southern hemisphere polar regions (Daily Tech)."},
#  'claim-2028': {'claim_text': 'cutting speed limits could slow climate change'},
#  'claim-2434': {'claim_text': 'The IPCC blames human emissions of carbon dioxide for the last  warming.'},
#  'claim-298': {'claim_text': 'Only very few peer-reviewed papers even go so far as to say that recent warming is chiefly anthropogenic.'},
#  'claim-338': {'claim_text': 'Rapid assessment of average temperatures in France between 26-28 June showed a “substantial” increase in the likelihood of the heatwave happening as a result of human-caused global warming, experts at the World Weather Attribution group said.'},
#  'claim-1672': {'claim_text': 'Global temperature is still rising and 2010 was the hottest recorded.'},
#  'claim-2840': {'claim_text': 'Arctic sea ice is also falling at an accelerated rate.'},
#  'claim-1425': {'claim_text': 'Each year sees the disappearance of thousands of plant and animal species which we will never know, which our children will never see, because they have been lost for ever.'},
#  'claim-1985': {'claim_text': 'The North Pole is melting "a bit" but the South Pole is getting bigger.'},
#  'claim-1156': {'claim_text': 'The costs of emissions regulations, which will be paid by everyone, will be punishingly high and will provide no benefits to most people anywhere in the world.'},
#  'claim-2870': {'claim_text': "Ironically, it's those who are mispresenting Hulme's paper that are the ones being misleading."},
#  'claim-2898': {'claim_text': 'The report suggests significantly smaller overall  ice-mass losses than previous estimates.'},
#  'claim-2329': {'claim_text': 'We know the Northwest Passage had been open before."'},
#  'claim-1998': {'claim_text': 'There is a link between climate change and the NSW bushfires.'},
#  'claim-2209': {'claim_text': 'Surface temperatures can show short-term cooling when heat is exchanged between the atmosphere and the ocean, which has a much greater heat capacity than the air.'},
#  'claim-1582': {'claim_text': "Tuvalu sea level isn't rising."},
#  'claim-3072': {'claim_text': '"a paper...in Science magazine concludes that the climate sensitivity—how much the earth’s average temperature will rise as a result of a doubling of the atmospheric concentration of carbon dioxide—likely (that is, with a 66% probability) lies in the range 1.7°C to 2.6°C, with a median value of 2.3°C.'},
#  'claim-381': {'claim_text': '[subsidies for wind and solar] add to emissions because coal-fired elec\xadtricity needs to be on standby for when there is no wind or sunshine.'},
#  'claim-398': {'claim_text': 'nothing we can do to stop the Earth’s naturally occurring climate cycles.'},
#  'claim-1560': {'claim_text': 'Sea level rise predictions are exaggerated.'},
#  'claim-2246': {'claim_text': '"His [Dr Spencer\'s] latest research demonstrates that – in the short term, at any rate –  the temperature feedbacks that the IPCC imagines will greatly amplify  any initial warming caused by CO2 are net-negative, attenuating the  warming they are supposed to enhance.'},
#  'claim-2774': {'claim_text': 'Actual reconstructions "diverge" from the instrumental series in the last part of 20th century.'},
#  'claim-972': {'claim_text': '“Arctic land stores about twice as much carbon as the atmosphere.'},
#  'claim-1531': {'claim_text': 'Earth’s climate is now changing faster than at any point in the history of modern civilization, primarily as a result of human activities.'},
#  'claim-2592': {'claim_text': '"A July 6, 2007 study published in the journal Science about Greenland by an international team of scientists found DNA “evidence that suggests the frozen shield covering the immense island survived the Earth’s last period of global warming,” according to a Boston Globe Article. \xa0...'},
#  'claim-2468': {'claim_text': '"Satellite measurements indicate an absence of significant global warming since 1979, the very period that human carbon dioxide emissions have been increasing rapidly.'},
#  'claim-463': {'claim_text': '“So now we’re able to explain from natural factors how we’ve had the 20th Century warming.'},
#  'claim-616': {'claim_text': 'The effect of long-term warming is to make it harder to count on snowmelt runoff in wet times'},
#  'claim-1240': {'claim_text': '“Ice-free means the central basin of the Arctic will be ice-free'},
#  'claim-2951': {'claim_text': 'The two most cited composites are PMOD and ACRIM.'},
#  'claim-1977': {'claim_text': 'The climate-change agreement between the United States and China "requires the Chinese to do nothing at all for 16 years."'},
#  'claim-942': {'claim_text': '‘We could be decades too fast, or decades too slow,’said one of them, Robert M. DeConto of the University of Massachusetts, Amherst.'},
#  'claim-2755': {'claim_text': 'Global warming is an increasingly urgent problem.'},
#  'claim-1230': {'claim_text': 'On the Pacific Coast, a climate pattern that had pushed billions of gallons of water toward Asia is now ending, so that in coming decades the sea is likely to rise quickly off states like Oregon and California.'},
#  'claim-3123': {'claim_text': 'Given that a doubling of carbon dioxide would change the surface heat flux by only two watts per square meter, it is evident that a small change in cloud cover can strongly affect the response to carbon dioxide."'},
#  'claim-1684': {'claim_text': 'The 2nd law of thermodynamics is consistent with the greenhouse effect which is directly observed.'},
#  'claim-839': {'claim_text': '“Even if we meet the Paris goals of two degrees warming, cities like Karachi and Kolkata will become close to uninhabitable, annually encountering deadly heat waves like those that crippled them in 2015.'},
#  'claim-2423': {'claim_text': 'Arctic sea ice has been steadily thinning, even in the last few years while the surface ice (eg - sea ice extent) increased slightly.'},
#  'claim-1243': {'claim_text': 'by that I mean the central Arctic will be ice-free.'},
#  'claim-494': {'claim_text': 'The Massachusetts Bay Colony in 1635 experienced a Category 3 or 4 storm, with up to a 20-foot storm surge.'},
#  'claim-1458': {'claim_text': 'Glaciers are retreating almost everywhere around the world — including in the Alps, Himalayas, Andes, Rockies, Alaska and Africa.'},
#  'claim-461': {'claim_text': 'Temperatures cooled from about 1940 to 1975, and then they rose from about ’75 to about 2005 or so, and since then they’ve been flat or cooling.'},
#  'claim-1304': {'claim_text': 'in a letter to The Times from Lord Krebs and company, essentially telling the newspaper to stop reporting less-than-negative climate stories.'},
#  'claim-2564': {'claim_text': 'This small warming is  likely a result of the natural alterations in global ocean currents  which are driven by ocean salinity variations.'},
#  'claim-2121': {'claim_text': 'Infrared Iris will reduce global warming'},
#  'claim-2631': {'claim_text': 'The temperatures are expected to change by as much as 10 Fahrenheit degrees at different places of the globe.'},
#  'claim-1141': {'claim_text': '“While record low sea ice is nothing new in the Arctic, this is a surprising turn of events for the Antarctic.'},
#  'claim-2398': {'claim_text': 'While there are direct ways in which CO2 is a pollutant (acidification of the ocean), its primary impact is its greenhouse warming effect.'},
#  'claim-1048': {'claim_text': 'While transient weather variability is playing a key role here, the widespread record warmth across the U.S. so far this year is part of a long-term trend toward more warm temperature records versus cold ones.'},
#  'claim-2783': {'claim_text': 'The study indicates far less future global warming will occur than United Nations computer models have predicted, and supports prior studies indicating increases in atmospheric carbon dioxide trap far less heat than alarmists have claimed.'},
#  'claim-1003': {'claim_text': 'A recent study in Nature Geoscience, for instance, called into question whether the Arctic’s melting, and in particular its sea ice loss, has been causing winter cooling over Eurasia, another idea that has been swept up in the debate over the jet stream and weather extremes.”'},
#  'claim-1872': {'claim_text': 'Donald Trump claims Global Warming is a hoax'},
#  'claim-1842': {'claim_text': 'A video shows Koko the gorilla spontaneously using sign language to issue a warning about climate change.'},
#  'claim-2411': {'claim_text': 'Note that computer models are just concatenations of calculations you could do on a hand-held calculator, so they are theoretical and cannot be part of any evidence."'},
#  'claim-2428': {'claim_text': 'It was the post war  industrialization that caused the rapid rise in global CO2 emissions,  but by 1945 when this began, the Earth was already in a cooling phase  that started around 1942 and continued until 1975.'},
#  'claim-1198': {'claim_text': '” ‘You see, gas in America is incredibly cheap, because of fracking,’ he says.'},
#  'claim-678': {'claim_text': 'In the process, the cows will emit much greenhouse gas, and they will consume far more calories in beans than they will yield in meat, meaning far more clearcutting of forests to farm cattle feed than would be necessary if the beans above were simply eaten by people.”'},
#  'claim-2105': {'claim_text': 'Excess CO2 from human emissions has a long residence time of over 100 years'},
#  'claim-648': {'claim_text': '‘there will not be enough nitrogen available to sustain the high carbon uptake scenarios.’'},
#  'claim-822': {'claim_text': 'Climate policy must compete with other long-term threats for always-scarce resources.”'},
#  'claim-2561': {'claim_text': 'Observed sea levels are actually tracking at the upper range of the IPCC projections.'},
#  'claim-2219': {'claim_text': 'The increase in temperatures since 1975 is a consistent feature of all reconstructions.'},
#  'claim-1343': {'claim_text': 'roughly three-quarters of the tidal flood days now occurring in towns along the East Coast would not be happening in the absence of the rise in the sea level caused by human emissions.'},
#  'claim-1351': {'claim_text': 'a marginally significant warming trend in the data over the past several years, erasing the temperature plateau that vexed climate alarmists have found difficult to explain.'},
#  'claim-2347': {'claim_text': 'In truth, the overwhelming majority of climate-research funding comes from the federal government and left-wing foundations.'},
#  'claim-293': {'claim_text': 'When the measuring equipment gets old and needs replacing, it often requires re-calibration.'},
#  'claim-910': {'claim_text': 'The cement, iron and steel, and petroleum refining industries could see their production cut by 21% 19%, and 11% respectively.”'},
#  'claim-2815': {'claim_text': 'A new peer-reviewed study on Surface Warming and the Solar Cycle found that times of high solar activity are on average 0.2°C warmer than times of low solar activity, and that there is a polar amplification of the warming.'},
#  'claim-1652': {'claim_text': 'The strong CO2 effect has been observed by many different measurements.'},
#  'claim-1212': {'claim_text': '(In technical lingo, the so-called social cost of carbon would be negative.)”'}}

# %%
len(test_claims_unlabelled)
# Out:
# 153

# %% [markdown]
# ## Have a look at how long each of the claims are, because bert only allows 512 words (not to mention subword tokenisation eating up more positions)

# %%
sent_length = []
n = 0
max_len = 0

for claim in train_claims:
    n += 1
    sent_length.append(len(train_claims[claim]['claim_text']))

    if len(train_claims[claim]['claim_text']) > max_len:
        max_len = len(train_claims[claim]['claim_text'])
        print(train_claims[claim]['claim_text'], '\n')

print(sum(sent_length)/n)
print(max_len)
# Out:
# Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
#
# The last time the planet was even four degrees warmer, Peter Brannen points out in The Ends of the World, his new history of the planet’s major extinction events, the oceans were hundreds of feet higher.
#
# When stomata-derived CO2 (red) is compared to ice core-derived CO2 (blue), the stomata generally show much more variability in the atmospheric CO2 level and often show levels much higher than the ice cores.
#
# The research also revealed how large areas of the polar ice caps could collapse and significant changes to ecosystems could see the Sahara Desert become green and the edges of tropical forests turn into fire-dominated savanna.
#
# Study finds low probability of both very low and very high climate sensitivities, and its lower estimate (as compared to the IPCC) is based on a new temperature reconstruction of the Last Glacial Maximum that may or may not withstand the test of time.
#
# Over the three years from 1979 to 1982 when CO2 emissions were decreasing due to the rapid increase in the price of oil that drastically reduced consumption, there was no change in the rate of increase in atmospheric concentration of CO2 proving that humans were not the primary source for the increase in concentration.'
#
# Or the news from Antarctica this past May, when a crack in an ice shelf grew 11 miles in six days, then kept going; the break now has just three miles to go — by the time you read this, it may already have met the open water, where it will drop into the sea one of the biggest icebergs ever, a process known poetically as ‘calving.’
#
# 122.95521172638436
# 332

# %%
# look at the distribution of lengths
np.percentile(sent_length, [0, 5, 10, 25, 50, 75, 90, 95, 100])
# Out:
# array([ 26.  ,  44.35,  57.7 ,  82.  , 115.  , 156.  , 198.  , 233.  ,
#        332.  ])

# %% [markdown]
# ### Look at distribution of labels, so to have 0R to compare final classifier against

# %% [markdown]
# For train

# %%
from collections import defaultdict as dd

label_distribution = dd(int)
evidence_number = dd(int)

for claim in train_claims:
    n += 1
    label_distribution[train_claims[claim]['claim_label']] += 1

    evidence_number[len(train_claims[claim]['evidences'])] += 1

print(label_distribution)
print(evidence_number)
# Out:
# defaultdict(<class 'int'>, {'DISPUTED': 124, 'REFUTES': 199, 'SUPPORTS': 519, 'NOT_ENOUGH_INFO': 386})
# defaultdict(<class 'int'>, {3: 191, 2: 223, 5: 477, 1: 210, 4: 127})

# %% [markdown]
# For dev

# %%
## DISTRIBUTION OF LABELS


label_distribution = dd(int)
evidence_number = dd(int)

for claim in dev_claims:
    n += 1
    label_distribution[dev_claims[claim]['claim_label']] += 1

    evidence_number[len(dev_claims[claim]['evidences'])] += 1

print(label_distribution)
print(evidence_number)
# Out:
# defaultdict(<class 'int'>, {'SUPPORTS': 68, 'NOT_ENOUGH_INFO': 41, 'REFUTES': 27, 'DISPUTED': 18})
# defaultdict(<class 'int'>, {2: 29, 5: 52, 4: 16, 3: 26, 1: 31})

# %% [markdown]
# #### Have a look at how long each of the evidence are, because bert only allows 512 words (not to mention subword tokenisation eating up more positions)

# %%
## LENGTH of evidence

sent_length = []
n = 0
max_len = 0

for id in evidence:
    n += 1
    sent_length.append(len(evidence[id]))

    if len(evidence[id]) > max_len:
        max_len = len(evidence[id])
        print(evidence[id], '\n')

print(sum(sent_length)/n)
print(max_len)
# Out:
# John Bennet Lawes, English entrepreneur and agricultural scientist
#
# Lindberg began his professional career at the age of 16, eventually moving to New York City in 1977.
#
# Gerald Francis Goyer (born October 20, 1936) was a professional ice hockey player who played 40 games in the National Hockey League.
#
# He detected abnormalities of oxytocinergic function in schizoaffective mania, post-partum psychosis and how ECT modified oxytocin release.
#
# With peak winds of 110 mph (175 km/h) and a minimum pressure of 972 mbar (hPa ; 28.71 inHg), Florence was the strongest storm of the 1994 Atlantic hurricane season.
#
# He is best known as author of The Prize : The Epic Quest for Oil, Money, and Power (1991) and The Quest : Energy, Security, and the Remaking of the Modern World (2011).
#
# The Academic Chronicle (Московско-Академическая летопись, Moskovskaya akademicheskaya letopis) or Suzdal ' Chronicle (Суздальская летопись, Suzdalskaya Letopis) is a late 15th-century compilation of other Russian-language chronicles.
#
# Some Italian motorcycle manufacturers, seeing their production fall due to the availability of low-cost utility cars, decided to enter the light motorcycle sector, creating economical models equipped with refined and robust four-stroke engines.
#
# It was built between 1922 and 1932 to house the Army Medical School, which became the Army Medical Center in 1923 when it -- under the name ``Medical Department Professional Service School'' (MDPSS) -- combined with the Walter Reed General Hospital.
#
# In 2000, the event was renamed ``Administrative Professionals Week'' to recognize people working in the administrative support field with other job titles such as receptionist, office manager, executive assistant, administrative coordinator, or administrative assistant.
#
# The firm 's notable EGD work includes Washington, D.C. 's citywide pedestrian wayfinding system (Washington Post feature) ; branded signage for Amtrak 's Acela train service, which received a gold IDEA award from the Industrial Designers Society of America (IDSA) ; signage for New York City 's Second Avenue Subway, under construction ; and signage for the Rock and Roll Hall of Fame and Museum (in partnership with Alexander Isley).
#
# ``Shall E&B Corporation 's 34 well oil and gas drilling/production project at the City 's 555 Sixth Street maintenance yard be approved by 1) amending the General Plan and Municipal Code to exempt the project from the City 's oil drilling ban and repeal the restriction on City 's use of project royalties, 2) awarding a pipeline franchise to transport oil/gas underground, 3) approving a 34 year development agreement, and 4) determining that project financial benefits outweigh its unavoidable environmental impacts?''
#
# Frank Wisner, a well-known CIA operations executive said of the autobiography of Director of Central Intelligence Allen W. Dulles, that Dulles ``disposes of the popular misconception that counterintelligence is essentially a negative and responsive activity, that it moves only or chiefly in reaction to situations thrust upon it and in counter to initiatives mounted by the opposition'' Rather, he sees that can be most effective, both in information gathering and protecting friendly intelligence services, when it creatively but vigorously attacks the ``structure and personnel of hostile intelligence services.
#
# Several other broadcasters around the world use the VideoGuard system, including DirecTV (Colombia), DirecTV (LatinAmerica), Hot (Israel), Yes (Israel), Viasat (Scandinavia), SKY Italia (Italy), Sky Brazil (Brazil), Sky Network Television (New Zealand), Foxtel (Australia), Airtel DigitalTV (India), Tata Sky & Hathway (DVB-C) (India), Astro (Malaysia), TrueVisions (Thailand), D Smart (Turkey), TotalTV (Balkan), ONO (Spain), Canadian Broadcasting Corporation (Canada), China Central Television (China), SBB (Serbia), KabelBW (Germany), Vivacom (Bulgaria), Dolce (Romania), STAR TV/Fox International Channels (Asia), Cignal Digital TV (Philippines), Aora TV (Indonesia), Telecom Italia (Italy), OTAU TV (Kazakhstan), OTE TV (Greece), Oi TV (Brazil).
#
# Gruen made contributions in a broad range of topics in the chemistry of materials : the definitive establishment of the 5f character of the actinides by the measurement and ligand field interpretation of magnetic moments at low temperatures ; the creation of a solution chemistry in fused salts using spectroscopy to determine oxidation states, complex ions, and coordination equilibria of transition metal ions ; the elucidation of the interactions of reactive molecular and atomic species with noble gas matrixes ; the rational design of metal alloy hydrides for energy storage and heat pump applications ; the determination of the energetics and depth of origin of sputtered species ; ultrasensitive detection of atoms and molecules using laser Fluorescence and resonance ionization mass spectrometry ; the discovery and development of a new chemical vapor deposition process for the synthesis of phase-pure nanocrystalline diamond films.
#
# Moreover, the conditions contained in the foregoing Firman are, and remain always in force as heretofore ; each one of the conditions will be constantly observed, and the maintenance of the privileges which flow from these conditions will depend upon the integral observance of each one of the obligations which they impose.The pledges more recently accorded by my Imperial Government-General of Egypt to maintain 30,000 effective troops, to create a difference between the moneys coined in Egypt, in my Imperial name, and the other moneys of my Empire, to confer the civil grades of my Government as high as the rank of Sanié (second rank of the first class), are equally confirmed.The law which interdicts the succession of the male descendants of the daughters of the Governors will be maintained in future as in past.The tribute of 80,000 bourses, paid by Egypt into the Imperial Treasury, is increased to 150,000 bourses, commencing March, 1866.
#
# Since 1995 he has been actively involved in the world of baroque opera, having participated in major productions such as Semele (Handel) at the Berlin State Opera with the Akademie für Alte Musik Berlin, conducted by René Jacobs ; L'Orfeo (Monteverdi) at the Goldoni Theatre, Florence, the Théâtre de la Monnaie, Brussels, Covent Garden, London, the Grand Théâtre de Provence, Aix-en-Provence, the Théâtre des Champs-Élysées, Paris, and the BAM, New York City, again under René Jacobs but with Concerto Vocale ; L'Orfeo again, but with Le Concert des Nations and Jordi Savall at the Teatro Real, Madrid and the Liceu, Barcelona ; Solimano (Johann Adolph Hasse) at the Berlin and Dresden State Operas with Concerto Köln and René Jacobs ; La Serva Padrona (Pergolesi) at the Philharmonie, Berlin and Ludwigsburg Palace with the Balthasar-Neumann-Ensemble and Thomas Hengelbrock ; Dal Male il Bene (Marco Marazzoli and Antonio Maria Abbatini) at the Landestheater, Innsbruck with Concerto Vocale and Attilio Cremonesi ; Don Chisciote della Mancia in Sierra Morena (Francesco Bartolomeo Conti) with the University of Salamanca Baroque Orchestra and Wieland Kuijken.
#
# The School of Graduate Studies, that formally opened in 1962, offers the following courses: Master of Science in Accountancy; Master of Business Administration; Doctor of Philosophy in Commerce major in Management; Master of Arts in Education with majors in Educational Administration, Reading Education, Pedagogy, Religious Education, and Guidance and Counseling; Master of Arts in Physical Education; Doctor of Philosophy major in Educational Management; Master of Arts in Teaching with majors in: English, Secondary Biology, Secondary Mathematics, Physics, Chemistry; Master of Arts with majors in Language (English), Biology, Physics, Chemistry, Mathematics; Doctor of Philosophy in Science Education with majors in Biology, and Mathematics; Master of Public Administration; Doctor of Public Administration; Master of Science in Nursing with majors in Nursing Administration, Community Health Nursing (Primary Health Care), Adult Health Nursing (Medial-Surgical Nursing) and Maternal and Child Health Nursing; Master of Science in Management Engineering; Master in Engineering major in Civil Engineering; Master of Library and Information Science: Master in Information Technology; and Master of Developmental Arts and Design.
#
# And be it Enacted by this present Parliament, and by the authority of the same, That after due publication of this Act made, to the end that none may justly pretend ignorance, it shall and may be lawful to any the Fleet or Ships sent forth or imployed by the Parliament, or any private Men of War or Ships to be allowed or approved in that behalf by the immediate Power of Parliament, or the Council of State established by Parliament, to seize, surprize and take all and all maner of Ships, Vessels and Goods, of what nature or kinde soever, belonging to all persons whatsoever whether Foreiners or others, or of what Nation soever, that shall be found or met withal, Trading or going to Trade, or coming from Trading with the said Rebels, or in or at the said Island of Barbada 's, Bermudas, Virginia or Antego aforesaid, or any part or parts thereof, or that shall hold any Correspondency with the said Rebels, or yield them any assistance or relief for the supporting their said Rebellion : And the same Ships and Goods so surprized, to send in to be proceeded against in the Court of Admiralty by vertue of this Act ; and the Judges of that Court finding the same to be within the tenor and true meaning of this Act, to adjudge the same to be well taken, and to be good and lawful Prize.
#
# The college also contains the following centers and institutes : Center for Demography and Population Health (population research and training), Center for Disaster Risk Policy (technical assistance and system development related to emergency management), Claude Pepper Center (research and advocacy for public policy reform on issues related to senior citizens), DeVoe L. Moore Center for the Study of Critical Issues in Economic Policy and Government (studying the effect of government rules, regulations, and programs on individuals and the economy), Geographical Information Systems Laboratory (state-of-the-art facilities and training for professional planners and geographers), LeRoy Collins Institute (independent, nonpartisan statewide policy organization to study private and public issues facing Florida and the nation), Pepper Institute on Aging and Public Policy (coordinator and facilitator for multidisciplinary work in aging studies ; sponsors the Osher Lifelong Learning Institute, which encourages elders to return to campus to continue to learn), Stavros Center for Economic Education (promotes economics education in public schools through workshops and seminars, product development, and teacher training), Survey Research Laboratory (questionnaire and sample design, data collection, data entry and coding, data analysis for researchers, public agencies, and private organizations), William H. Kerr Intercultural Education and Dialogue Initiative (dedicated to expanding educational opportunities for underprivileged youth around the world and creating international dialogue).
#
# During 58 years of political life, has been arrested 17 times for participating in Gandhiji 's Satyagrahas and in Kisan, Mazdoor, Harijan and Students ; Movements and actually spent a total of 13 years in various jails on different occasions ; sentenced to 10 years rigorous imprisonment in Gorakhpur Conspiracy case during ``August 1942'' Movement, and kept in condemned cell for 26 months, 1942 -- 44 ; shot at during August rebellion on August 6, 1942 ; received bullet injury in Nepal Freedom Struggle on December 21, 1950 ; President, (i) Samajwadi Congress Party, Uttar Pradesh, (ii) ``No Tax Satyagraha Compaign Committee'', (iii) Kanpur District Congress Committee, 1930 -- 33, (iv) Gorakhpur District Congress Committee, 1937 -- 52 and (v) Kisan Mazdoor Praja Party, 1952 -- 60 ; Member, (i) Uttar Pradesh Congress Committee and All India Congress Committee, 1928 -- 51, (ii) Executive of the Uttar Pradesh, Pradesh Congress Committee, 1937 -- 52, (iii) Uttar Pradesh and Bihar Sugar Control Board for many years since 1937 (iv) Sugar Labour Inquiry Committee (Khaitan Committee), 1938 -- 40, (v) Executive Council of the Sanskrit University, Varanasi ; President, (i) All-India Sugarcane Growers ' Association, and (ii) United Chini Mill Mazdoor Federation ; Ex-President, (i) All-India Sugar and Distillery Workers ' Federation, (ii) All-India Food, Tobacco and Hotel Workers ' Federation, (iii) All-India Transport Workers ' Federation, (iv) All-India Dock and Port Workers ' Federation, (v) All-India Federation of Government Employees Unions, New Delhi, (vi) North-Eastern Railwaymen 's Union, 1937 -- 48, and (vii) Uttar Pradesh Kisan Sabha ; elected Vice-President, All-India Trade Union Congress in 1947, and Hind Mazdoor Sabha in 1948 ; Member of Presidium of United Trade Union Congress in 1950 ; established (i) Ganesh Shankar Vidyarthi Smarak Inter College, Maharajganj in 1940 and (ii) Jawaharlal Nehru Smarak Post Graduate College in 1966 in Maharajganj, (iii) Lal Bahadur Shastri Smarak Degree College, Anand Nagar in 1973, (iv) Choteylal Damodar Prasad Shibbanlal Degree College, Bisokdar, Sirwa Bazar, all in Gorakhpur District, Uttar Pradesh, and acting as President, Managing Committee of all the aforesaid colleges ; Member (i) Uttar Pradesh Legislative Assembly, 1937 -- 46 and 1964 -- 67, (ii) Constituent Assembly of India, 1946 -- 50, (iii) Provisional Parliament, 1950 -- 52, (iv) First Lok Sabha, 1954 -- 57, (v) Second Lok Sabha, 1957 -- 62, (vi) Fifth Lok Sabha, 1971 -- 77 ; several times Member, (i) Estimates Committee, (ii) Public Accounts Committee, (iii) Committee on Public Undertakings ; represented Indian Labour at numerous international labour conferences in various foreign countries, and in this connection, and otherwise visited several countries ; represented Sugar Workers ' Federation in International Conference in Moscow (USSR), 1954, in Sofia (Bulgaria), 1957, in Budapest (Hungary), 1960, and in Prague (Czechoslovakia), 1965 ; represented Transport Workers in International Conference in Bucharest (Romania), 1956 ; attended World Peace Council meetings, Berlin, 1954, and Stockholm, 1955.
#
# 119.51412319546138
# 3148

# %%
# look at the distribution of lengths
np.percentile(sent_length, [0, 5, 10, 25, 50, 75, 90, 95, 100])
# Out:
# array([1.000e+00, 4.600e+01, 5.400e+01, 7.400e+01, 1.060e+02, 1.500e+02,
#        2.000e+02, 2.370e+02, 3.148e+03])

# %% [markdown]
# ### Check used evidences in Original Train and Dev

# %%
seen_evidence = set()

for claim in train_claims:
    for evid in train_claims[claim]['evidences']:
        seen_evidence.add(evid)

for claim in dev_claims:
    for evid in dev_claims[claim]['evidences']:
        seen_evidence.add(evid)

# %%
len(seen_evidence)
# Out:
# 3443
